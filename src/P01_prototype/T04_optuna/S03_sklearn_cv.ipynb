# %% [markdown]
# # Optuna with SKLearn and Cross-Validation
#
# - Notice that the test data is not used during hyperparameter optimization. This is crucial to avoid data leakage and ensure that the model's performance is evaluated on unseen data.

# %%
import pandas as pd
import optuna

# %%
from sklearn.datasets import load_diabetes

dataset = load_diabetes()
_X = dataset.data
_y = dataset.target
print(_X.shape, _y.shape)
# Out:
# (442, 10) (442,)

# %%
from sklearn.model_selection import train_test_split

_X_train, _X_test, _y_train, _y_test = train_test_split(
    _X, _y, test_size=0.3, random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

scX = StandardScaler()
_X_train = scX.fit_transform(_X_train)
_X_test = scX.transform(_X_test)

scY = StandardScaler()
_y_train = scY.fit_transform(_y_train.reshape(-1, 1)).flatten()
_y_test = scY.transform(_y_test.reshape(-1, 1)).flatten()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score


def objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 10, 200)
    max_depth = trial.suggest_int("max_depth", 2, 32, log=True)
    forrest = RandomForestRegressor(
        n_estimators=n_estimators, max_depth=max_depth, random_state=42
    )
    scores = cross_val_score(
        forrest, _X_train, _y_train, cv=3, scoring="neg_mean_squared_error"
    )
    mse = -scores.mean()  # We want to minimize MSE
    return mse

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-12-24 11:52:25,041] A new study created in memory with name: no-name-d41e380a-f7ce-434f-8955-da93e6a44754
# [I 2025-12-24 11:52:25,513] Trial 0 finished with value: 0.5726719347723043 and parameters: {'n_estimators': 185, 'max_depth': 5}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:25,804] Trial 1 finished with value: 0.5812527284789675 and parameters: {'n_estimators': 161, 'max_depth': 2}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:26,332] Trial 2 finished with value: 0.5841166695412497 and parameters: {'n_estimators': 176, 'max_depth': 8}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:26,574] Trial 3 finished with value: 0.5820269339026526 and parameters: {'n_estimators': 136, 'max_depth': 2}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:26,862] Trial 4 finished with value: 0.5801491337668284 and parameters: {'n_estimators': 88, 'max_depth': 24}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:27,066] Trial 5 finished with value: 0.5765155608126967 and parameters: {'n_estimators': 99, 'max_depth': 3}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:27,292] Trial 6 finished with value: 0.5845049291366783 and parameters: {'n_estimators': 79, 'max_depth': 7}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:27,575] Trial 7 finished with value: 0.580651305148812 and parameters: {'n_estimators': 85, 'max_depth': 17}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:28,191] Trial 8 finished with value: 0.5814137266544509 and parameters: {'n_estimators': 191, 'max_depth': 22}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:28,267] Trial 9 finished with value: 0.5997078689463312 and parameters: {'n_estimators': 24, 'max_depth': 8}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:28,593] Trial 10 finished with value: 0.5772529513870538 and parameters: {'n_estimators': 144, 'max_depth': 4}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:28,853] Trial 11 finished with value: 0.5789120291777642 and parameters: {'n_estimators': 115, 'max_depth': 4}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:28,967] Trial 12 finished with value: 0.583581881015815 and parameters: {'n_estimators': 47, 'max_depth': 4}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:29,211] Trial 13 finished with value: 0.5754348243767214 and parameters: {'n_estimators': 117, 'max_depth': 3}. Best is trial 0 with value: 0.5726719347723043.
# [I 2025-12-24 11:52:29,612] Trial 14 finished with value: 0.570794829009074 and parameters: {'n_estimators': 199, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:30,253] Trial 15 finished with value: 0.5828429054885936 and parameters: {'n_estimators': 198, 'max_depth': 12}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:30,671] Trial 16 finished with value: 0.5745808092340507 and parameters: {'n_estimators': 170, 'max_depth': 5}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:31,151] Trial 17 finished with value: 0.5876264814795161 and parameters: {'n_estimators': 151, 'max_depth': 10}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:31,598] Trial 18 finished with value: 0.572243305485828 and parameters: {'n_estimators': 182, 'max_depth': 5}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:31,880] Trial 19 finished with value: 0.5743491786898918 and parameters: {'n_estimators': 137, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:32,237] Trial 20 finished with value: 0.5803899358795009 and parameters: {'n_estimators': 200, 'max_depth': 2}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:32,687] Trial 21 finished with value: 0.5726332406948916 and parameters: {'n_estimators': 180, 'max_depth': 5}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:33,136] Trial 22 finished with value: 0.5754527802543254 and parameters: {'n_estimators': 167, 'max_depth': 6}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:33,503] Trial 23 finished with value: 0.5712931011315917 and parameters: {'n_estimators': 182, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:33,834] Trial 24 finished with value: 0.5727744711136894 and parameters: {'n_estimators': 160, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:34,214] Trial 25 finished with value: 0.5716797333584664 and parameters: {'n_estimators': 185, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:34,448] Trial 26 finished with value: 0.5825574668981198 and parameters: {'n_estimators': 125, 'max_depth': 2}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:34,764] Trial 27 finished with value: 0.5737279978120063 and parameters: {'n_estimators': 155, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:35,206] Trial 28 finished with value: 0.5721460739276174 and parameters: {'n_estimators': 199, 'max_depth': 4}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:35,802] Trial 29 finished with value: 0.5835203776248655 and parameters: {'n_estimators': 185, 'max_depth': 12}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:35,973] Trial 30 finished with value: 0.5878429664273706 and parameters: {'n_estimators': 50, 'max_depth': 30}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:36,412] Trial 31 finished with value: 0.5721460739276174 and parameters: {'n_estimators': 199, 'max_depth': 4}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:36,756] Trial 32 finished with value: 0.5717974412324981 and parameters: {'n_estimators': 172, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:37,066] Trial 33 finished with value: 0.5805945687038475 and parameters: {'n_estimators': 173, 'max_depth': 2}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:37,568] Trial 34 finished with value: 0.5742681681523585 and parameters: {'n_estimators': 187, 'max_depth': 6}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:37,909] Trial 35 finished with value: 0.5725609526352567 and parameters: {'n_estimators': 167, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:38,186] Trial 36 finished with value: 0.5818603246424016 and parameters: {'n_estimators': 150, 'max_depth': 2}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:38,548] Trial 37 finished with value: 0.5713221360843869 and parameters: {'n_estimators': 177, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:39,046] Trial 38 finished with value: 0.5738445552696042 and parameters: {'n_estimators': 189, 'max_depth': 6}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:39,340] Trial 39 finished with value: 0.5775821935623996 and parameters: {'n_estimators': 132, 'max_depth': 4}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:39,676] Trial 40 finished with value: 0.580669670364383 and parameters: {'n_estimators': 180, 'max_depth': 2}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:40,008] Trial 41 finished with value: 0.5729338822442153 and parameters: {'n_estimators': 162, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:40,358] Trial 42 finished with value: 0.5715036662644107 and parameters: {'n_estimators': 175, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:40,780] Trial 43 finished with value: 0.5731938229989716 and parameters: {'n_estimators': 189, 'max_depth': 4}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:41,207] Trial 44 finished with value: 0.5733718498805228 and parameters: {'n_estimators': 176, 'max_depth': 5}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:41,625] Trial 45 finished with value: 0.584636604437904 and parameters: {'n_estimators': 144, 'max_depth': 7}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:41,850] Trial 46 finished with value: 0.5797101474325462 and parameters: {'n_estimators': 97, 'max_depth': 4}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:42,352] Trial 47 finished with value: 0.5857409872218128 and parameters: {'n_estimators': 161, 'max_depth': 9}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:42,998] Trial 48 finished with value: 0.5812110934105235 and parameters: {'n_estimators': 194, 'max_depth': 17}. Best is trial 14 with value: 0.570794829009074.
# [I 2025-12-24 11:52:43,152] Trial 49 finished with value: 0.5769901873760133 and parameters: {'n_estimators': 73, 'max_depth': 3}. Best is trial 14 with value: 0.570794829009074.

# %%
best_params = study.best_params
print("Best parameters:", best_params)
print("Best MSE:", study.best_value)
# Out:
# Best parameters: {'n_estimators': 199, 'max_depth': 3}
# Best MSE: 0.570794829009074

# %%
# Calculate Test Result
from sklearn.metrics import mean_squared_error

forrest = RandomForestRegressor(**best_params, random_state=42)
forrest.fit(_X_train, _y_train)
y_pred = forrest.predict(_X_test)
mse = mean_squared_error(_y_test, y_pred)
print("Test MSE:", mse)
# Out:
# Test MSE: 0.4436299555652864
