# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path
from P07_af_all.T00_lib.utils import check_jupyter

# %%
if check_jupyter():
    BASE_DIR = Path.cwd()  # Current directory of the running file
    DATA_DIR = BASE_DIR.parent / "T02_combine_features"
    CURRENT_DIR = BASE_DIR
else:
    BASE_DIR = Path.cwd()  # Base directory of the project
    DATA_DIR = BASE_DIR / "src/P07_af_all/T02_combine_features"
    CURRENT_DIR = Path(__file__).resolve().parent
# Out:
# Code is running in a Jupyter environment.

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performance.xlsx")

# %%
df
# Out:
#     random_state  test_size             model      Y  MSE Train (No Val)  \
# 0              1        0.3  GradientBoosting    Y-1            0.237223
# 1              1        0.3  GradientBoosting    Y-2            0.365497
# 2              1        0.3  GradientBoosting    Y-3            0.146593
# 3              1        0.3  GradientBoosting  Y-All            0.249771
# 4              2        0.3  GradientBoosting    Y-1            0.498870
# 5              2        0.3  GradientBoosting    Y-2            0.676488
# 6              2        0.3  GradientBoosting    Y-3            0.371104
# 7              2        0.3  GradientBoosting  Y-All            0.515487
# 8              3        0.3  GradientBoosting    Y-1            0.357393
# 9              3        0.3  GradientBoosting    Y-2            0.572413
# 10             3        0.3  GradientBoosting    Y-3            0.298283
# 11             3        0.3  GradientBoosting  Y-All            0.409363
# 12             4        0.3  GradientBoosting    Y-1            0.495511
# 13             4        0.3  GradientBoosting    Y-2            0.666456
# 14             4        0.3  GradientBoosting    Y-3            0.345677
# 15             4        0.3  GradientBoosting  Y-All            0.502548
# 16             5        0.3  GradientBoosting    Y-1            0.360693
# 17             5        0.3  GradientBoosting    Y-2            0.586317
# 18             5        0.3  GradientBoosting    Y-3            0.300862
# 19             5        0.3  GradientBoosting  Y-All            0.415957
# 20             1        0.3      RandomForest    Y-1            0.455151
# 21             1        0.3      RandomForest    Y-2            0.648776
# 22             1        0.3      RandomForest    Y-3            0.313673
# 23             1        0.3      RandomForest  Y-All            0.472533
# 24             2        0.3      RandomForest    Y-1            0.426277
# 25             2        0.3      RandomForest    Y-2            0.606899
# 26             2        0.3      RandomForest    Y-3            0.324142
# 27             2        0.3      RandomForest  Y-All            0.452439
# 28             3        0.3      RandomForest    Y-1            0.436245
# 29             3        0.3      RandomForest    Y-2            0.672559
# 30             3        0.3      RandomForest    Y-3            0.337456
# 31             3        0.3      RandomForest  Y-All            0.482087
# 32             4        0.3      RandomForest    Y-1            0.519322
# 33             4        0.3      RandomForest    Y-2            0.713209
# 34             4        0.3      RandomForest    Y-3            0.361135
# 35             4        0.3      RandomForest  Y-All            0.531222
# 36             5        0.3      RandomForest    Y-1            0.400081
# 37             5        0.3      RandomForest    Y-2            0.620050
# 38             5        0.3      RandomForest    Y-3            0.313405
# 39             5        0.3      RandomForest  Y-All            0.444512
#
#     MSE Test  MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0   0.918945             1.235791   1.736199           0.762777  0.281141
# 1   0.926954             1.024049   4.588296           0.634503 -0.130397
# 2   0.467939             0.760103   1.153687           0.853407  0.451415
# 3   0.771279             1.006648   2.492727           0.750229  0.200720
# 4   0.597220             1.688697   1.743463           0.501130  0.315517
# 5   0.983304             1.743027   1.621097           0.323512 -0.099203
# 6   0.586374             1.674087   1.318774           0.628896  0.468799
# 7   0.722299             1.701937   1.561111           0.484513  0.228371
# 8   0.980072             1.259860   2.384505           0.642607  0.129047
# 9   0.994319             2.424410   4.392015           0.427587 -0.078973
# 10  0.424290             1.187708   1.109919           0.701717  0.422220
# 11  0.799560             1.623993   2.628813           0.590637  0.157431
# 12  0.786753             1.089179   3.686356           0.504489  0.304362
# 13  0.959487             2.707492   1.150411           0.333544  0.037416
# 14  0.472642             1.046505   1.152613           0.654323  0.440244
# 15  0.739628             1.614392   1.996460           0.497452  0.260674
# 16  0.961079            39.209503   1.571682           0.639307  0.175887
# 17  0.972605             1.423569   3.167793           0.413683 -0.270353
# 18  0.502327             1.180870   1.212885           0.699138  0.471491
# 19  0.812004            13.937981   1.984120           0.584043  0.125675
# 20  0.971505             1.958224   1.863020           0.544849  0.240025
# 21  0.905590             1.352238   4.486803           0.351224 -0.104344
# 22  0.511014             1.179088   1.396566           0.686327  0.400916
# 23  0.796036             1.496517   2.582130           0.527467  0.178866
# 24  0.632374             1.474576   1.803218           0.573723  0.275227
# 25  1.039175             1.783804   1.748433           0.393101 -0.161658
# 26  0.640249             1.465631   1.505969           0.675858  0.419994
# 27  0.770599             1.574670   1.685873           0.547561  0.177854
# 28  0.956628             1.325572   2.359185           0.563755  0.149881
# 29  0.937789             2.159439   3.621070           0.327441 -0.017631
# 30  0.402113             1.216114   1.141010           0.662544  0.452419
# 31  0.765510             1.567042   2.373755           0.517913  0.194890
# 32  0.768030             1.209122   3.948508           0.480678  0.320916
# 33  0.920157             3.137676   1.132504           0.286791  0.076873
# 34  0.476180             1.158714   1.175011           0.638865  0.436054
# 35  0.721456             1.835171   2.085341           0.468778  0.277948
# 36  0.957079            42.059594   1.564381           0.599919  0.179317
# 37  0.929659             1.297881   3.013779           0.379950 -0.214261
# 38  0.467796             1.160544   1.124382           0.686595  0.507822
# 39  0.784845            14.839340   1.900847           0.555488  0.157626

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
