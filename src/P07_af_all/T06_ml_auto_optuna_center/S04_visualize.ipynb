# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path
from P07_af_all.T00_lib.utils import check_jupyter

# %%
if check_jupyter():
    BASE_DIR = Path.cwd()  # Current directory of the running file
    DATA_DIR = BASE_DIR.parent / "T02_combine_features"
    CURRENT_DIR = BASE_DIR
else:
    BASE_DIR = Path.cwd()  # Base directory of the project
    DATA_DIR = BASE_DIR / "src/P07_af_all/T02_combine_features"
    CURRENT_DIR = Path(__file__).resolve().parent
# Out:
# Code is running in a Jupyter environment.

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performance.xlsx")

# %%
df
# Out:
#     random_state  test_size             model      Y  MSE Train (No Val)  \
# 0              1        0.3  GradientBoosting    Y-1            0.923932
# 1              1        0.3  GradientBoosting    Y-2            0.966714
# 2              1        0.3  GradientBoosting    Y-3            0.900961
# 3              1        0.3  GradientBoosting  Y-All            0.930536
# 4              2        0.3  GradientBoosting    Y-1            0.937667
# 5              2        0.3  GradientBoosting    Y-2            0.962203
# 6              2        0.3  GradientBoosting    Y-3            0.920415
# 7              2        0.3  GradientBoosting  Y-All            0.940095
# 8              3        0.3  GradientBoosting    Y-1            0.922792
# 9              3        0.3  GradientBoosting    Y-2            0.963370
# 10             3        0.3  GradientBoosting    Y-3            0.903278
# 11             3        0.3  GradientBoosting  Y-All            0.929814
# 12             4        0.3  GradientBoosting    Y-1            0.931971
# 13             4        0.3  GradientBoosting    Y-2            0.968651
# 14             4        0.3  GradientBoosting    Y-3            0.904224
# 15             4        0.3  GradientBoosting  Y-All            0.934949
# 16             5        0.3  GradientBoosting    Y-1            0.920364
# 17             5        0.3  GradientBoosting    Y-2            0.956599
# 18             5        0.3  GradientBoosting    Y-3            0.899810
# 19             5        0.3  GradientBoosting  Y-All            0.925591
# 20             1        0.3      RandomForest    Y-1            0.529131
# 21             1        0.3      RandomForest    Y-2            0.723161
# 22             1        0.3      RandomForest    Y-3            0.388835
# 23             1        0.3      RandomForest  Y-All            0.547042
# 24             2        0.3      RandomForest    Y-1            0.642973
# 25             2        0.3      RandomForest    Y-2            0.783005
# 26             2        0.3      RandomForest    Y-3            0.496373
# 27             2        0.3      RandomForest  Y-All            0.640784
# 28             3        0.3      RandomForest    Y-1            0.518345
# 29             3        0.3      RandomForest    Y-2            0.767917
# 30             3        0.3      RandomForest    Y-3            0.439050
# 31             3        0.3      RandomForest  Y-All            0.575104
# 32             4        0.3      RandomForest    Y-1            0.608278
# 33             4        0.3      RandomForest    Y-2            0.811549
# 34             4        0.3      RandomForest    Y-3            0.463494
# 35             4        0.3      RandomForest  Y-All            0.627773
# 36             5        0.3      RandomForest    Y-1            0.551466
# 37             5        0.3      RandomForest    Y-2            0.770237
# 38             5        0.3      RandomForest    Y-3            0.474701
# 39             5        0.3      RandomForest  Y-All            0.598801
#
#     MSE Test  MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0   1.247622             0.990483   0.966445           0.076068  0.024028
# 1   0.835705             0.962906   1.451527           0.033286 -0.019122
# 2   0.773634             0.932250   0.918954           0.099039  0.093035
# 3   0.952321             0.961880   1.112309           0.069464  0.032647
# 4   0.922628             0.950522   0.997618           0.062333 -0.057437
# 5   0.897035             0.988515   0.987434           0.037797 -0.002765
# 6   1.159416             1.160314   1.182184           0.079585 -0.050324
# 7   0.993026             1.033117   1.055745           0.059905 -0.036842
# 8   1.083968             0.953925   1.002563           0.077208  0.036719
# 9   0.912140             0.988957   1.088999           0.036630  0.010201
# 10  0.662746             0.971682   0.886527           0.096722  0.097500
# 11  0.886285             0.971522   0.992696           0.070186  0.048140
# 12  1.093682             0.924583   1.236509           0.068029  0.032979
# 13  0.987317             1.093487   1.008382           0.031349  0.009496
# 14  0.769865             0.906956   0.977862           0.095776  0.088240
# 15  0.950288             0.975009   1.074251           0.065051  0.043572
# 16  1.123771             4.992426   0.961992           0.079636  0.036380
# 17  0.791119             0.941066   1.144129           0.043401 -0.033309
# 18  0.874369             0.916748   0.968555           0.100190  0.080058
# 19  0.929753             2.283413   1.024892           0.074409  0.027710
# 20  0.909446             1.733883   1.491351           0.470869  0.288572
# 21  0.878409             1.209876   4.119863           0.276839 -0.071198
# 22  0.494379             1.168402   1.298705           0.611165  0.420418
# 23  0.760745             1.370720   2.303306           0.452958  0.212597
# 24  0.667774             1.464339   1.463309           0.357027  0.234654
# 25  0.943980             1.525391   1.427863           0.216995 -0.055244
# 26  0.696548             1.516605   1.246307           0.503627  0.368992
# 27  0.769434             1.502111   1.379160           0.359216  0.182801
# 28  0.900393             1.240452   2.113353           0.481655  0.199855
# 29  0.913174             1.331474   2.942988           0.232083  0.009080
# 30  0.423700             1.184849   1.065635           0.560950  0.423022
# 31  0.745756             1.252258   2.040658           0.424896  0.210652
# 32  0.790675             1.082819   3.585002           0.391722  0.300894
# 33  0.946042             2.053593   1.059671           0.188451  0.050905
# 34  0.505488             1.055807   1.146369           0.536506  0.401345
# 35  0.747402             1.397407   1.930347           0.372227  0.251048
# 36  0.927776            37.180046   1.320496           0.448534  0.204444
# 37  0.906474             1.357222   2.324447           0.229763 -0.183978
# 38  0.544087             1.260507   1.136770           0.525299  0.427554
# 39  0.792779            13.265925   1.593904           0.401199  0.149340

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
