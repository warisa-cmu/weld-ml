# %%
import re
from pathlib import Path
import pandas as pd

# %%
CURRENT_DIR = Path.cwd()
DATA_AF_DIR = CURRENT_DIR.parent.parent / "P02_data" / "T07_af_all"
DATA_COMBINED_DIR = CURRENT_DIR.parent.parent / "P03_run_diff_sigma" / "T02_combine_features"
DATA_FEATURES_DIR = CURRENT_DIR.parent / "T01_af_features"
print(DATA_AF_DIR)
print(DATA_COMBINED_DIR)
print(DATA_FEATURES_DIR)
# Out:
# c:\Users\admin\Coding\research\weld-ml\src\P02_data\T07_af_all
# c:\Users\admin\Coding\research\weld-ml\src\P03_run_diff_sigma\T02_combine_features
# c:\Users\admin\Coding\research\weld-ml\src\P07_af_all\T01_af_features

# %%
# Load selected features
features = pd.read_excel(DATA_FEATURES_DIR / "S05_af_selected_features.xlsx")
features
# Out:
#     sample_no  Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  \
# 0           1                                          1.910672
# 1           2                                          1.497020
# 2           3                                          0.999252
# 3           4                                          0.905469
# 4           5                                          8.439772
# 5           6                                          1.716892
# 6           7                                          1.590558
# 7           8                                          2.462299
# 8           9                                          3.983195
# 9          10                                          0.541280
# 10         11                                          0.765896
# 11         12                                          1.562738
# 12         13                                          6.331034
# 13         14                                          1.598170
# ...

# %%
# Load location info
locs = pd.read_excel(DATA_AF_DIR / "S01_info_locs.xlsx")
locs
# Out:
#      sample_no  Location        Fx        Fy        Fz        Mz  loc_idx  \
# 0            1         1 -0.077671  0.143026  1.244326  1.873865     5856
# 1            1         2 -0.027450  0.207481  1.625039  4.615337     7356
# 2            1         3 -0.038704  0.272508  1.799653  5.209334     8856
# 3            1         4 -0.023484  0.278517  1.882699  5.764727    10356
# 4            1         5 -0.038251  0.280276  1.955412  6.097497    11856
# ..         ...       ...       ...       ...       ...       ...      ...
# 373         54         3 -0.079764  0.196450  1.352393  5.512565     8631
# 374         54         4 -0.091477  0.259717  1.529089  6.898179     9756
# 375         54         5 -0.068128  0.241906  1.657737  7.940597    10881
# 376         54         6 -0.066880  0.261006  1.712860  8.849661    12006
# 377         54         7 -0.059665  0.232186  1.877377  9.613127    13131
#
#      loc_time
# 0       58.56
# 1       73.56
# 2       88.56
# 3      103.56
# ...

# %%
# Load combined data
_combined = pd.read_excel(DATA_COMBINED_DIR / "s02_data_combined_loc.xlsx")

# Only keep relevant columns
cols_keep = ["sample_no", "R", "W", "D", "position", "location", "stress_value_5052", "stress_value_6061", "stress_value_center"]
combined = _combined[cols_keep]
combined
# Out:
#      sample_no     R   W   D  position  location  stress_value_5052  \
# 0            1  1400  60  10  0.153846         1               28.0
# 1            2  1400  60  15  0.153846         1               14.0
# 2            3  1400  60  20  0.153846         1               10.0
# 3            4  1400  70  10  0.153846         1               10.0
# 4            5  1400  70  15  0.153846         1                6.0
# ..         ...   ...  ..  ..       ...       ...                ...
# 373         50  1600  70  15  0.846154         7                4.0
# 374         51  1600  70  20  0.846154         7                0.0
# 375         52  1600  80  10  0.846154         7               -2.0
# 376         53  1600  80  15  0.846154         7               10.0
# 377         54  1600  80  20  0.846154         7               15.0
#
#      stress_value_6061  stress_value_center
# 0                 51.0                 12.0
# 1                -21.0                 17.0
# ...

# %%
combined.merge(locs, on=["sample_no", "location"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11844\448949495.py in ?()
# ----> 1 combined.merge(locs, on=["sample_no", "location"])
#
# c:\Users\admin\Coding\research\weld-ml\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# c:\Users\admin\Coding\research\weld-ml\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...
