# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path
from P07_af_all.T00_lib.utils import check_jupyter

# %%
if check_jupyter():
    BASE_DIR = Path.cwd()  # Current directory of the running file
    DATA_DIR = BASE_DIR.parent / "T02_combine_features"
    CURRENT_DIR = BASE_DIR
else:
    BASE_DIR = Path.cwd()  # Base directory of the project
    DATA_DIR = BASE_DIR / "src/P07_af_all/T02_combine_features"
    CURRENT_DIR = Path(__file__).resolve().parent
# Out:
# Code is running in a Jupyter environment.

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performance.xlsx")

# %%
df
# Out:
#     random_state  test_size             model      Y  MSE Train (No Val)  \
# 0              1        0.3  GradientBoosting    Y-1            0.575419
# 1              1        0.3  GradientBoosting    Y-2            0.743392
# 2              1        0.3  GradientBoosting    Y-3            0.426445
# 3              1        0.3  GradientBoosting  Y-All            0.581752
# 4              2        0.3  GradientBoosting    Y-1            0.660344
# 5              2        0.3  GradientBoosting    Y-2            0.807015
# 6              2        0.3  GradientBoosting    Y-3            0.574849
# 7              2        0.3  GradientBoosting  Y-All            0.680736
# 8              3        0.3  GradientBoosting    Y-1            0.678249
# 9              3        0.3  GradientBoosting    Y-2            0.852807
# 10             3        0.3  GradientBoosting    Y-3            0.598279
# 11             3        0.3  GradientBoosting  Y-All            0.709778
# 12             4        0.3  GradientBoosting    Y-1            0.663415
# 13             4        0.3  GradientBoosting    Y-2            0.836316
# 14             4        0.3  GradientBoosting    Y-3            0.505502
# 15             4        0.3  GradientBoosting  Y-All            0.668411
# 16             5        0.3  GradientBoosting    Y-1            0.687563
# 17             5        0.3  GradientBoosting    Y-2            0.831700
# 18             5        0.3  GradientBoosting    Y-3            0.603740
# 19             5        0.3  GradientBoosting  Y-All            0.707668
# 20             1        0.3      RandomForest    Y-1            0.635472
# 21             1        0.3      RandomForest    Y-2            0.813704
# 22             1        0.3      RandomForest    Y-3            0.507126
# 23             1        0.3      RandomForest  Y-All            0.652100
# 24             2        0.3      RandomForest    Y-1            0.761808
# 25             2        0.3      RandomForest    Y-2            0.860593
# 26             2        0.3      RandomForest    Y-3            0.574304
# 27             2        0.3      RandomForest  Y-All            0.732235
# 28             3        0.3      RandomForest    Y-1            0.740951
# 29             3        0.3      RandomForest    Y-2            0.894455
# 30             3        0.3      RandomForest    Y-3            0.699157
# 31             3        0.3      RandomForest  Y-All            0.778188
# 32             4        0.3      RandomForest    Y-1            0.764851
# 33             4        0.3      RandomForest    Y-2            0.887837
# 34             4        0.3      RandomForest    Y-3            0.551473
# 35             4        0.3      RandomForest  Y-All            0.734720
# 36             5        0.3      RandomForest    Y-1            0.706480
# 37             5        0.3      RandomForest    Y-2            0.834152
# 38             5        0.3      RandomForest    Y-3            0.632783
# 39             5        0.3      RandomForest  Y-All            0.724472
#
#     MSE Test  MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0   0.944692             1.782832   1.561174           0.424581  0.261001
# 1   0.868634             1.398219   5.382839           0.256608 -0.059278
# 2   0.475726             1.257726   1.194506           0.573555  0.442286
# 3   0.763017             1.479592   2.712840           0.418248  0.214669
# 4   0.648699             1.709603   1.651252           0.339656  0.256517
# 5   0.886074             1.460337   1.296782           0.192985  0.009488
# 6   0.732516             1.709620   1.203150           0.425151  0.336408
# 7   0.755763             1.626520   1.383728           0.319264  0.200804
# 8   0.930663             1.010751   1.545035           0.321751  0.172955
# 9   0.889800             1.512125   2.158182           0.147193  0.034444
# 10  0.453977             1.041719   0.819814           0.401721  0.381793
# 11  0.758147             1.188198   1.507677           0.290222  0.196397
# 12  0.806710             1.308516   3.126917           0.336585  0.286717
# 13  0.895277             2.636570   1.055681           0.163684  0.101833
# 14  0.543960             1.240243   1.131002           0.494498  0.355782
# 15  0.748649             1.728443   1.771200           0.331589  0.248111
# 16  0.962644            16.881713   1.127738           0.312437  0.174545
# 17  0.823062             1.136087   1.699418           0.168300 -0.075030
# 18  0.680615             1.056336   1.061805           0.396260  0.283910
# 19  0.822107             6.358045   1.296320           0.292332  0.127808
# 20  0.985874             1.706290   1.391608           0.364528  0.228785
# 21  0.802367             1.163106   4.128357           0.186296  0.021533
# 22  0.501531             1.141143   1.142884           0.492874  0.412034
# 23  0.763258             1.336847   2.220950           0.347900  0.220784
# 24  0.743086             1.714745   1.535278           0.238192  0.148338
# 25  0.917797             1.482084   1.229537           0.139407 -0.025974
# 26  0.667301             1.652709   1.145131           0.425696  0.395487
# 27  0.776061             1.616513   1.303315           0.267765  0.172617
# 28  0.960882             1.158346   1.499451           0.259049  0.146100
# 29  0.871639             1.385580   1.600577           0.105545  0.054150
# 30  0.540833             1.092520   0.902232           0.300843  0.263516
# 31  0.791118             1.212149   1.334086           0.221812  0.154589
# 32  0.886431             1.359770   2.314588           0.235149  0.216227
# 33  0.901327             2.255785   1.009106           0.112163  0.095764
# 34  0.540715             1.287594   1.119278           0.448527  0.359625
# 35  0.776158             1.634383   1.480990           0.265280  0.223872
# 36  0.966962            25.545183   1.165172           0.293520  0.170842
# 37  0.807507             1.279280   1.793927           0.165848 -0.054714
# 38  0.684886             1.104191   1.019606           0.367217  0.279416
# 39  0.819785             9.309552   1.326235           0.275528  0.131848

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
