# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path
from P07_af_all.T00_lib.utils import check_jupyter

# %%
if check_jupyter():
    BASE_DIR = Path.cwd()  # Current directory of the running file
    DATA_DIR = BASE_DIR.parent / "T02_combine_features"
    CURRENT_DIR = BASE_DIR
else:
    BASE_DIR = Path.cwd()  # Base directory of the project
    DATA_DIR = BASE_DIR / "src/P07_af_all/T02_combine_features"
    CURRENT_DIR = Path(__file__).resolve().parent
# Out:
# Code is running in a Jupyter environment.

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performance.xlsx")

# %%
df
# Out:
#     random_state  test_size             model      Y  MSE Train (No Val)  \
# 0              1        0.3  GradientBoosting    Y-1            0.477494
# 1              1        0.3  GradientBoosting    Y-2            0.668206
# 2              1        0.3  GradientBoosting    Y-3            0.346926
# 3              1        0.3  GradientBoosting  Y-All            0.497542
# 4              2        0.3  GradientBoosting    Y-1            0.570067
# 5              2        0.3  GradientBoosting    Y-2            0.764912
# 6              2        0.3  GradientBoosting    Y-3            0.491574
# 7              2        0.3  GradientBoosting  Y-All            0.608851
# 8              3        0.3  GradientBoosting    Y-1            0.417017
# 9              3        0.3  GradientBoosting    Y-2            0.648228
# 10             3        0.3  GradientBoosting    Y-3            0.340434
# 11             3        0.3  GradientBoosting  Y-All            0.468560
# 12             4        0.3  GradientBoosting    Y-1            0.527054
# 13             4        0.3  GradientBoosting    Y-2            0.756588
# 14             4        0.3  GradientBoosting    Y-3            0.394328
# 15             4        0.3  GradientBoosting  Y-All            0.559323
# 16             5        0.3  GradientBoosting    Y-1            0.310669
# 17             5        0.3  GradientBoosting    Y-2            0.516849
# 18             5        0.3  GradientBoosting    Y-3            0.287063
# 19             5        0.3  GradientBoosting  Y-All            0.371527
# 20             1        0.3      RandomForest    Y-1            0.533583
# 21             1        0.3      RandomForest    Y-2            0.715953
# 22             1        0.3      RandomForest    Y-3            0.372906
# 23             1        0.3      RandomForest  Y-All            0.540814
# 24             2        0.3      RandomForest    Y-1            0.494126
# 25             2        0.3      RandomForest    Y-2            0.659135
# 26             2        0.3      RandomForest    Y-3            0.369738
# 27             2        0.3      RandomForest  Y-All            0.507666
# 28             3        0.3      RandomForest    Y-1            0.446725
# 29             3        0.3      RandomForest    Y-2            0.670776
# 30             3        0.3      RandomForest    Y-3            0.350872
# 31             3        0.3      RandomForest  Y-All            0.489458
# 32             4        0.3      RandomForest    Y-1            0.525031
# 33             4        0.3      RandomForest    Y-2            0.719621
# 34             4        0.3      RandomForest    Y-3            0.373796
# 35             4        0.3      RandomForest  Y-All            0.539483
# 36             5        0.3      RandomForest    Y-1            0.388344
# 37             5        0.3      RandomForest    Y-2            0.613592
# 38             5        0.3      RandomForest    Y-3            0.322241
# 39             5        0.3      RandomForest  Y-All            0.441392
#
#     MSE Test  MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0   0.918335             1.583933   1.779777           0.522506  0.281618
# 1   0.861334             1.310569   5.843529           0.331794 -0.050376
# 2   0.454060             1.161147   1.202346           0.653074  0.467686
# 3   0.744576             1.351883   2.941884           0.502458  0.232976
# 4   0.623846             1.670300   1.569317           0.429933  0.285000
# 5   0.905496             1.576494   1.536661           0.235088 -0.012223
# 6   0.719592             1.612000   1.187254           0.508426  0.348116
# 7   0.749645             1.619598   1.431077           0.391149  0.206964
# 8   0.940246             0.903174   2.098022           0.582983  0.164439
# 9   1.054709             1.173452   4.134073           0.351772 -0.144506
# 10  0.419703             0.973679   1.039596           0.659566  0.428466
# 11  0.804886             1.016768   2.423897           0.531440  0.149467
# 12  0.796326             1.264466   4.532831           0.472946  0.295897
# 13  0.926021             3.309340   1.208681           0.243412  0.070990
# 14  0.526321             1.298136   1.224298           0.605672  0.376672
# 15  0.749556             1.957314   2.321937           0.440677  0.247853
# 16  0.952540            20.950501   1.492126           0.689331  0.183209
# 17  1.035007             0.778544   2.743277           0.483151 -0.351859
# 18  0.527873             0.790455   1.216928           0.712937  0.444614
# 19  0.838473             7.506500   1.817444           0.628473  0.091988
# 20  0.935933             1.802845   1.859639           0.466417  0.267852
# 21  0.853035             1.185355   4.395667           0.284047 -0.040255
# 22  0.478154             1.203550   1.309628           0.627094  0.439440
# 23  0.755707             1.397250   2.521645           0.459186  0.222346
# 24  0.609760             1.576698   1.582329           0.505874  0.301145
# 25  1.003678             1.630033   1.669204           0.340865 -0.121977
# 26  0.682006             1.414786   1.366462           0.630262  0.382166
# 27  0.765148             1.540505   1.539332           0.492334  0.187111
# 28  0.907670             1.141180   2.236493           0.553275  0.193388
# 29  0.997623             1.439492   4.118798           0.329224 -0.082559
# 30  0.418543             1.119290   1.146064           0.649128  0.430045
# 31  0.774612             1.233321   2.500452           0.510542  0.180291
# 32  0.795452             1.173266   4.292589           0.474969  0.296670
# 33  0.962567             3.059471   1.240837           0.280379  0.034326
# 34  0.493561             1.138731   1.173306           0.626204  0.415470
# 35  0.750527             1.790489   2.235577           0.460517  0.248822
# 36  0.986489            37.477741   1.534582           0.611656  0.154098
# 37  0.975518             1.461249   3.668643           0.386408 -0.274159
# 38  0.510409             1.148917   1.139326           0.677759  0.462987
# 39  0.824139            13.362636   2.114184           0.558608  0.114309

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
