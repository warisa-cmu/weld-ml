# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
from pathlib import Path

# %%
CURRENT_DIR = Path.cwd()

# %%
filepath_pre = os.path.join(CURRENT_DIR, "S01_residual_stress_pre_weld.xlsx")
filepath_post = os.path.join(CURRENT_DIR, "S02_residual_stress_post_weld.xlsx")
pre = pd.read_excel(filepath_pre).rename(columns={"Sigma(x)": "sigma_x_pre", "FWHM": "FWHM_pre"})
post = pd.read_excel(filepath_post).rename(columns={"Sigma(x)": "sigma_x_post", "FWHM": "FWHM_post"})

# %%
dfm = post.merge(
    pre, how="outer", on=["location", "section", "sample_no", "R", "W", "D"]
).fillna(0)
dfm
# Out:
#      section  sample_no  location     R   W   D  sigma_x_post  FWHM_post  \
# 0     AA5052          1         1  1400  60  10          13.0       2.55
# 1     AA5052          2         1  1400  60  15          16.0       2.51
# 2     AA5052          3         1  1400  60  20          19.0       2.47
# 3     AA5052          4         1  1400  70  10          20.0       2.45
# 4     AA5052          5         1  1400  70  15           6.0       2.47
# ...      ...        ...       ...   ...  ..  ..           ...        ...
# 1142  Center         50         7  1600  70  15           2.0       2.45
# 1143  Center         51         7  1600  70  20           2.0       2.45
# 1144  Center         52         7  1600  80  10           5.0       2.54
# 1145  Center         53         7  1600  80  15           1.0       2.41
# 1146  Center         54         7  1600  80  20           4.0       2.42
#
#       sigma_x_pre  FWHM_pre
# 0           -15.0      2.50
# 1             2.0      2.47
# 2             9.0      2.48
# 3            10.0      2.48
# 4             0.0      2.49
# ...           ...       ...
# 1142          0.0      0.00
# 1143          0.0      0.00
# 1144          0.0      0.00
# 1145          0.0      0.00
# 1146          0.0      0.00
#
# [1147 rows x 10 columns]

# %%
dfm['diff_sigma_x'] = dfm['sigma_x_post'] - dfm['sigma_x_pre']

# %%
dfm.to_excel("S03_residual_stress_merge.xlsx", index=False)
