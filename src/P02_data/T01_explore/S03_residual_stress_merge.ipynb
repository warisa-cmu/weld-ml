# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
from pathlib import Path

# %%
CURRENT_DIR = Path.cwd()

# %%
filepath_pre = os.path.join(CURRENT_DIR, "S01_residual_stress_pre_weld.xlsx")
filepath_post = os.path.join(CURRENT_DIR, "S02_residual_stress_post_weld.xlsx")
pre = pd.read_excel(filepath_pre).rename(columns={"Sigma(x)": "sigma_x_pre", "FWHM": "FWHM_pre", "idx_excel": "idx_excel_pre"})
post = pd.read_excel(filepath_post).rename(columns={"Sigma(x)": "sigma_x_post", "FWHM": "FWHM_post", "idx_excel": "idx_excel_post"})

# %%
dfm = post.merge(
    pre, how="outer", on=["location", "section", "sample_no", "R", "W", "D"]
).fillna(0)
dfm
# Out:
#       idx_excel_post section  sample_no  location     R   W   D  sigma_x_post  \
# 0                4.0  AA5052          1         1  1400  60  10          13.0
# 1               25.0  AA5052          2         1  1400  60  15          16.0
# 2               46.0  AA5052          3         1  1400  60  20          19.0
# 3               67.0  AA5052          4         1  1400  70  10          20.0
# 4               88.0  AA5052          5         1  1400  70  15           6.0
# ...              ...     ...        ...       ...   ...  ..  ..           ...
# 1130          1050.0  Center         50         7  1600  70  15           2.0
# 1131          1071.0  Center         51         7  1600  70  20           2.0
# 1132          1092.0  Center         52         7  1600  80  10           5.0
# 1133          1113.0  Center         53         7  1600  80  15           1.0
# 1134          1134.0  Center         54         7  1600  80  20           4.0
#
#       FWHM_post  idx_excel_pre  sigma_x_pre  FWHM_pre
# 0          2.55            2.0        -15.0      2.50
# 1          2.51            9.0          2.0      2.47
# 2          2.47           16.0          9.0      2.48
# 3          2.45           23.0         10.0      2.48
# 4          2.47           30.0          0.0      2.49
# ...         ...            ...          ...       ...
# 1130       2.45            0.0          0.0      0.00
# 1131       2.45            0.0          0.0      0.00
# 1132       2.54            0.0          0.0      0.00
# 1133       2.41            0.0          0.0      0.00
# 1134       2.42            0.0          0.0      0.00
#
# [1135 rows x 12 columns]

# %%
dfm['diff_sigma_x'] = dfm['sigma_x_post'] - dfm['sigma_x_pre']

# %%
dfm.to_excel("S03_residual_stress_merge.xlsx", index=False)
