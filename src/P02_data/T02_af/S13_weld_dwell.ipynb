# %%
import os
import pickle
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.signal import find_peaks

# %%
with open("S10_af_time_series.pkl", "rb") as f:
    data = pickle.load(f)

afs = data["data"]
metas = pd.read_excel("S11_af_meta.xlsx")
weld_end = pd.read_excel("S12_1_af_weld_end.xlsx")

# %%
OUT_DIR = "S12_2"
os.makedirs(OUT_DIR, exist_ok=True)

# %%
metas
# Out:
#     sample_no         DynoWare                                   Path  \
# 0           1  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 1           2  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 2           3  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 3           4  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 4           5  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 5           6  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 6           7  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 7           8  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 8           9  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 9          10  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 10         11  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 11         12  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 12         13  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 13         14  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 14         15  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 15         16  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 16         17  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 17         18  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 18         19  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 19         20  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 20         21  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 21         22  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 22         23  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 23         24  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 24         25  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 25         26  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 26         27  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 27         28  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 28         29  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 29         30  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 30         31  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 31         32  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 32         33  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 33         34  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 34         35  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 35         36  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 36         37  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 37         38  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 38         39  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 39         40  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 40         41  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 41         42  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 42         43  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 43         44  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 44         45  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 45         46  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 46         47  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 47         48  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 48         49  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 49         50  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 50         51  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 51         52  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 52         53  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
# 53         54  Version 3.2.2.0  D:\Parn (paper ML Weld)\Post welding\
#
#          Filename      Config ID  Setup ID  Manipulated  Filename 1  \
# 0    Sample 1.dwd   Sample 1.cfg         0            0         NaN
# 1    Sample 2.dwd   Sample 2.cfg         0            0         NaN
# 2    Sample 3.dwd   Sample 3.cfg         0            0         NaN
# 3    Sample 4.dwd   Sample 4.cfg         0            0         NaN
# 4    Sample 5.dwd   Sample 5.cfg         0            0         NaN
# 5    Sample 6.dwd   Sample 6.cfg         0            0         NaN
# 6    Sample 7.dwd   Sample 7.cfg         0            0         NaN
# 7    Sample 8.dwd   Sample 8.cfg         0            0         NaN
# 8    Sample 9.dwd   Sample 9.cfg         0            0         NaN
# 9   Sample 10.dwd  Sample 10.cfg         0            0         NaN
# 10  Sample 11.dwd  Sample 11.cfg         0            0         NaN
# 11  Sample 12.dwd  Sample 12.cfg         0            0         NaN
# 12  Sample 13.dwd  Sample 13.cfg         0            0         NaN
# 13  Sample 14.dwd  Sample 14.cfg         0            0         NaN
# 14  Sample 15.dwd  Sample 15.cfg         0            0         NaN
# 15  Sample 16.dwd  Sample 16.cfg         0            0         NaN
# 16  Sample 17.dwd  Sample 17.cfg         0            0         NaN
# 17  Sample 18.dwd  Sample 18.cfg         0            0         NaN
# 18  Sample 19.dwd  Sample 19.cfg         0            0         NaN
# 19  Sample 20.dwd  Sample 20.cfg         0            0         NaN
# 20  Sample 21.dwd  Sample 21.cfg         0            0         NaN
# 21  Sample 22.dwd  Sample 22.cfg         0            0         NaN
# 22  Sample 23.dwd  Sample 23.cfg         0            0         NaN
# 23  Sample 24.dwd  Sample 24.cfg         0            0         NaN
# 24  Sample 25.dwd  Sample 25.cfg         0            0         NaN
# 25  Sample 26.dwd  Sample 26.cfg         0            0         NaN
# 26  Sample 27.dwd  Sample 27.cfg         0            0         NaN
# 27  Sample 28.dwd  Sample 28.cfg         0            0         NaN
# 28  Sample 29.dwd  Sample 29.cfg         0            0         NaN
# 29  Sample 30.dwd  Sample 30.cfg         0            0         NaN
# 30  Sample 31.dwd  Sample 31.cfg         0            0         NaN
# 31  Sample 32.dwd  Sample 32.cfg         0            0         NaN
# 32  Sample 33.dwd  Sample 33.cfg         0            0         NaN
# 33  Sample 34.dwd  Sample 34.cfg         0            0         NaN
# 34  Sample 35.dwd  Sample 35.cfg         0            0         NaN
# 35  Sample 36.dwd  Sample 36.cfg         0            0         NaN
# 36  Sample 37.dwd  Sample 37.cfg         0            0         NaN
# 37  Sample 38.dwd  Sample 38.cfg         0            0         NaN
# 38  Sample 39.dwd  Sample 39.cfg         0            0         NaN
# 39  Sample 40.dwd  Sample 40.cfg         0            0         NaN
# 40  Sample 41.dwd  Sample 41.cfg         0            0         NaN
# 41  Sample 42.dwd  Sample 42.cfg         0            0         NaN
# 42  Sample 43.dwd  Sample 43.cfg         0            0         NaN
# 43  Sample 44.dwd  Sample 44.cfg         0            0         NaN
# 44  Sample 45.dwd  Sample 45.cfg         0            0         NaN
# 45  Sample 46.dwd  Sample 46.cfg         0            0         NaN
# 46  Sample 47.dwd  Sample 47.cfg         0            0         NaN
# 47  Sample 48.dwd  Sample 48.cfg         0            0         NaN
# 48  Sample 49.dwd  Sample 49.cfg         0            0         NaN
# 49  Sample 50.dwd  Sample 50.cfg         0            0         NaN
# 50  Sample 51.dwd  Sample 51.cfg         0            0         NaN
# 51  Sample 52.dwd  Sample 52.cfg         0            0         NaN
# 52  Sample 53.dwd  Sample 53.cfg         0            0         NaN
# 53  Sample 54.dwd  Sample 54.cfg         0            0         NaN
#
#     Filename 2                           Date  ... Delay time [s]  \
# 0          NaN  Wednesday,  January 01,  2025  ...              0
# 1          NaN  Wednesday,  January 01,  2025  ...              0
# 2          NaN  Wednesday,  January 01,  2025  ...              0
# 3          NaN  Wednesday,  January 01,  2025  ...              0
# 4          NaN  Wednesday,  January 01,  2025  ...              0
# 5          NaN  Wednesday,  January 01,  2025  ...              0
# 6          NaN  Wednesday,  January 01,  2025  ...              0
# 7          NaN  Wednesday,  January 01,  2025  ...              0
# 8          NaN  Wednesday,  January 01,  2025  ...              0
# 9          NaN  Wednesday,  January 01,  2025  ...              0
# 10         NaN  Wednesday,  January 01,  2025  ...              0
# 11         NaN  Wednesday,  January 01,  2025  ...              0
# 12         NaN   Thursday,  January 02,  2025  ...              0
# 13         NaN   Thursday,  January 02,  2025  ...              0
# 14         NaN   Thursday,  January 02,  2025  ...              0
# 15         NaN   Thursday,  January 02,  2025  ...              0
# 16         NaN   Thursday,  January 02,  2025  ...              0
# 17         NaN   Thursday,  January 02,  2025  ...              0
# 18         NaN   Thursday,  January 02,  2025  ...              0
# 19         NaN   Thursday,  January 02,  2025  ...              0
# 20         NaN   Thursday,  January 02,  2025  ...              0
# 21         NaN   Thursday,  January 02,  2025  ...              0
# 22         NaN   Thursday,  January 02,  2025  ...              0
# 23         NaN   Thursday,  January 02,  2025  ...              0
# 24         NaN   Thursday,  January 02,  2025  ...              0
# 25         NaN   Thursday,  January 02,  2025  ...              0
# 26         NaN   Thursday,  January 02,  2025  ...              0
# 27         NaN   Thursday,  January 02,  2025  ...              0
# 28         NaN   Thursday,  January 02,  2025  ...              0
# 29         NaN   Thursday,  January 02,  2025  ...              0
# 30         NaN     Friday,  January 03,  2025  ...              0
# 31         NaN     Friday,  January 03,  2025  ...              0
# 32         NaN     Friday,  January 03,  2025  ...              0
# 33         NaN     Friday,  January 03,  2025  ...              0
# 34         NaN     Friday,  January 03,  2025  ...              0
# 35         NaN     Friday,  January 03,  2025  ...              0
# 36         NaN     Friday,  January 03,  2025  ...              0
# 37         NaN     Friday,  January 03,  2025  ...              0
# 38         NaN     Friday,  January 03,  2025  ...              0
# 39         NaN     Friday,  January 03,  2025  ...              0
# 40         NaN     Friday,  January 03,  2025  ...              0
# 41         NaN     Friday,  January 03,  2025  ...              0
# 42         NaN     Friday,  January 03,  2025  ...              0
# 43         NaN     Friday,  January 03,  2025  ...              0
# 44         NaN     Friday,  January 03,  2025  ...              0
# 45         NaN     Friday,  January 03,  2025  ...              0
# 46         NaN     Friday,  January 03,  2025  ...              0
# 47         NaN     Friday,  January 03,  2025  ...              0
# 48         NaN     Friday,  January 03,  2025  ...              0
# 49         NaN     Friday,  January 03,  2025  ...              0
# 50         NaN     Friday,  January 03,  2025  ...              0
# 51         NaN     Friday,  January 03,  2025  ...              0
# 52         NaN     Friday,  January 03,  2025  ...              0
# 53         NaN     Friday,  January 03,  2025  ...              0
#
#     Cycle time [s]  Cycles  Samples per channel  Cycle interval  Cycle No  \
# 0                0       1                18001               0         1
# 1                0       1                18001               0         1
# 2                0       1                18001               0         1
# 3                0       1                18001               0         1
# 4                0       1                18001               0         1
# 5                0       1                18001               0         1
# 6                0       1                18001               0         1
# 7                0       1                18001               0         1
# 8                0       1                18001               0         1
# 9                0       1                18001               0         1
# 10               0       1                18001               0         1
# 11               0       1                18001               0         1
# 12               0       1                18001               0         1
# 13               0       1                18001               0         1
# 14               0       1                18001               0         1
# 15               0       1                18001               0         1
# 16               0       1                18001               0         1
# 17               0       1                18001               0         1
# 18               0       1                18001               0         1
# 19               0       1                18001               0         1
# 20               0       1                18001               0         1
# 21               0       1                18001               0         1
# 22               0       1                18001               0         1
# 23               0       1                18001               0         1
# 24               0       1                18001               0         1
# 25               0       1                18001               0         1
# 26               0       1                18001               0         1
# 27               0       1                18001               0         1
# 28               0       1                18001               0         1
# 29               0       1                18001               0         1
# 30               0       1                18001               0         1
# 31               0       1                18001               0         1
# 32               0       1                18001               0         1
# 33               0       1                18001               0         1
# 34               0       1                18001               0         1
# 35               0       1                18001               0         1
# 36               0       1                18001               0         1
# 37               0       1                18001               0         1
# 38               0       1                18001               0         1
# 39               0       1                18001               0         1
# 40               0       1                18001               0         1
# 41               0       1                18001               0         1
# 42               0       1                18001               0         1
# 43               0       1                18001               0         1
# 44               0       1                18001               0         1
# 45               0       1                18001               0         1
# 46               0       1                18001               0         1
# 47               0       1                18001               0         1
# 48               0       1                18001               0         1
# 49               0       1                18001               0         1
# 50               0       1                18001               0         1
# 51               0       1                18001               0         1
# 52               0       1                18001               0         1
# 53               0       1                18001               0         1
#
#          filename     R   D   W
# 0    Sample 1.csv  1400  10  60
# 1    Sample 2.csv  1400  15  60
# 2    Sample 3.csv  1400  20  60
# 3    Sample 4.csv  1400  10  70
# 4    Sample 5.csv  1400  15  70
# 5    Sample 6.csv  1400  20  70
# 6    Sample 7.csv  1400  10  80
# 7    Sample 8.csv  1400  15  80
# 8    Sample 9.csv  1400  20  80
# 9   Sample 10.csv  1500  10  60
# 10  Sample 11.csv  1500  15  60
# 11  Sample 12.csv  1500  20  60
# 12  Sample 13.csv  1500  10  70
# 13  Sample 14.csv  1500  15  70
# 14  Sample 15.csv  1500  20  70
# 15  Sample 16.csv  1500  10  80
# 16  Sample 17.csv  1500  15  80
# 17  Sample 18.csv  1500  20  80
# 18  Sample 19.csv  1600  10  60
# 19  Sample 20.csv  1600  15  60
# 20  Sample 21.csv  1600  20  60
# 21  Sample 22.csv  1600  10  70
# 22  Sample 23.csv  1600  15  70
# 23  Sample 24.csv  1600  20  70
# 24  Sample 25.csv  1600  10  80
# 25  Sample 26.csv  1600  15  80
# 26  Sample 27.csv  1600  20  80
# 27  Sample 28.csv  1400  10  60
# 28  Sample 29.csv  1400  15  60
# 29  Sample 30.csv  1400  20  60
# 30  Sample 31.csv  1400  10  70
# 31  Sample 32.csv  1400  15  70
# 32  Sample 33.csv  1400  20  70
# 33  Sample 34.csv  1400  10  80
# 34  Sample 35.csv  1400  15  80
# 35  Sample 36.csv  1400  20  80
# 36  Sample 37.csv  1500  10  60
# 37  Sample 38.csv  1500  15  60
# 38  Sample 39.csv  1500  20  60
# 39  Sample 40.csv  1500  10  70
# 40  Sample 41.csv  1500  15  70
# 41  Sample 42.csv  1500  20  70
# 42  Sample 43.csv  1500  10  80
# 43  Sample 44.csv  1500  15  80
# 44  Sample 45.csv  1500  20  80
# 45  Sample 46.csv  1600  10  60
# 46  Sample 47.csv  1600  15  60
# 47  Sample 48.csv  1600  20  60
# 48  Sample 49.csv  1600  10  70
# 49  Sample 50.csv  1600  15  70
# 50  Sample 51.csv  1600  20  70
# 51  Sample 52.csv  1600  10  80
# 52  Sample 53.csv  1600  15  80
# 53  Sample 54.csv  1600  20  80
#
# [54 rows x 23 columns]

# %%
weld_end
# Out:
#     sample_no  drop_idx_chosen  drop_threshold  weld_time_end_idx  \
# 0           1               -1              -3              16856
# 1           2               -1              -3              17262
# 2           3               -1              -3              17824
# 3           4               -1              -3              14807
# 4           5               -1              -3              15388
# 5           6               -1              -3              15509
# 6           7               -1              -3              13199
# 7           8               -1              -3              13840
# 8           9               -1              -3              14537
# 9          10               -1              -3              16532
# 10         11               -1              -3              17281
# 11         12               -1              -3              17280
# 12         13               -1              -3              14953
# 13         14               -1              -3              15462
# 14         15               -1              -3              15931
# 15         16               -1              -3              13096
# 16         17               -1              -3              14136
# 17         18               -1              -3              14337
# 18         19               -1              -3              16729
# 19         20               -1              -3              17170
# 20         21               -1              -3              17753
# 21         22               -1              -3              15021
# 22         23               -1              -3              15209
# 23         24               -1              -3              15977
# 24         25               -1              -3              13502
# 25         26               -1              -3              14065
# 26         27               -1              -3              14596
# 27         28               -1              -3              16848
# 28         29               -1              -3              17283
# 29         30               -1              -3              17861
# 30         31               -1              -3              14985
# 31         32               -1              -3              15525
# 32         33               -1              -3              16029
# 33         34               -1              -3              13511
# 34         35               -1              -3              14117
# 35         36               -1              -3              14618
# 36         37               -1              -3              16775
# 37         38               -1              -3              17383
# 38         39               -1              -3              17885
# 39         40               -1              -3              15020
# 40         41               -1              -3              15517
# 41         42               -1              -3              16043
# 42         43               -1              -3              13609
# 43         44               -1              -3              14137
# 44         45               -1              -3              14633
# 45         46               -1              -3              16831
# 46         47               -1              -3              17386
# 47         48               -1              -3              17887
# 48         49               -1              -3              14961
# 49         50               -1              -3              15471
# 50         51               -1              -3              16043
# 51         52               -1              -3              13549
# 52         53               -1              -3              14131
# 53         54               -1              -3              14631
#
#     weld_time_end
# 0          168.56
# 1          172.62
# 2          178.24
# 3          148.07
# 4          153.88
# 5          155.09
# 6          131.99
# 7          138.40
# 8          145.37
# 9          165.32
# 10         172.81
# 11         172.80
# 12         149.53
# 13         154.62
# 14         159.31
# 15         130.96
# 16         141.36
# 17         143.37
# 18         167.29
# 19         171.70
# 20         177.53
# 21         150.21
# 22         152.09
# 23         159.77
# 24         135.02
# 25         140.65
# 26         145.96
# 27         168.48
# 28         172.83
# 29         178.61
# 30         149.85
# 31         155.25
# 32         160.29
# 33         135.11
# 34         141.17
# 35         146.18
# 36         167.75
# 37         173.83
# 38         178.85
# 39         150.20
# 40         155.17
# 41         160.43
# 42         136.09
# 43         141.37
# 44         146.33
# 45         168.31
# 46         173.86
# 47         178.87
# 48         149.61
# 49         154.71
# 50         160.43
# 51         135.49
# 52         141.31
# 53         146.31

# %%
afs
# Out:
#           Time         Mz        Fz        Fy        Fx  sample_no
# 0         0.00   0.297328  0.044294  0.006714  0.004425          1
# 1         0.01   0.061471  0.029864  0.000741 -0.000011          1
# 2         0.02   0.296021  0.044425  0.006616  0.004381          1
# 3         0.03   0.061907  0.029253  0.000708  0.000011          1
# 4         0.04   0.301252  0.043509  0.006801  0.004469          1
# ...        ...        ...       ...       ...       ...        ...
# 972049  179.96  12.385800  0.244707 -0.010027 -0.015117          9
# 972050  179.97  12.677900  0.262844 -0.002616 -0.009668          9
# 972051  179.98  12.389700  0.245361 -0.010005 -0.015063          9
# 972052  179.99  12.678700  0.263192 -0.002638 -0.009635          9
# 972053  180.00  12.387100  0.245797 -0.010038 -0.015095          9
#
# [972054 rows x 6 columns]

# %% [markdown]
# ## Prototype

# %%
sample_no = 1
idx_start_chosen = None
idx_end_chosen = None
threshold = 0.1
peak_condition = dict(height=(1, None), threshold=(threshold, None))
zoom_level = 1

# Extract relevant data
dwell_time = metas.loc[metas["sample_no"] == sample_no, "D"].values[0]
# sampling_rate = metas.loc[
#     metas["sample_no"] == sample_no, "Sampling rate [Hz]"
# ].values[0]
_weld_speed = metas.loc[metas["sample_no"] == sample_no, "W"].values[0]  # mm/min
weld_speed = _weld_speed / 60  # Convert to mm/s
af = afs.loc[afs["sample_no"] == sample_no].reset_index(drop=True)
af.set_index("Time", inplace=True)
weld_time_end = weld_end.loc[
    weld_end["sample_no"] == sample_no, "weld_time_end"
].values[0]

# Weld time is calculated from the speed and length of sample which is 130 mm
weld_time = 130 / weld_speed

# Estimate dwell time checkpoints
dwell_time_end_approx = weld_time_end - weld_time

# Find peaks in axial force data
peak_idxes, props = find_peaks(af["Fz"], **peak_condition)

# Choose dwell time end based on peak indexes
if idx_end_chosen is None:  # Auto select based on dwell time
    dwell_time_end_idx = af.index.get_indexer(
        [dwell_time_end_approx], method="nearest"
    )[0]
else:
    if idx_end_chosen < 0:
        raise ValueError("idx_end_chosen must be non-negative integer.")
    else:
        dwell_time_end_idx = idx_end_chosen
dwell_time_end = af.index[dwell_time_end_idx]

# Choose dwell time start
if idx_start_chosen is None:  # Auto select based on dwell time
    dwell_time_start = dwell_time_end - dwell_time
    dwell_time_start_idx = af.index.get_indexer([dwell_time_start], method="nearest")[0]
else:  # Manual select
    if idx_start_chosen < 0:
        raise ValueError("idx_start_chosen must be non-negative integer.")
    elif idx_start_chosen <= 10:  # Select from peak indexes
        dwell_time_start_idx = peak_idxes[idx_start_chosen]
        dwell_time_start = af.index[dwell_time_start_idx]
    else:  # Directly specify index
        dwell_time_start_idx = idx_start_chosen
        dwell_time_start = af.index[dwell_time_start_idx]

# Actual dwell time
dwell_time_actual = dwell_time_end - dwell_time_start

# Determine the start of pre-dwell time for reference
pre_dwell_time = 2.90 / (10 / 60)  # 2.90 mm at 10 mm/min
pre_dwell_time_start = dwell_time_start - pre_dwell_time

pre_dwell_time_start_idx = af.index.get_indexer(
    [pre_dwell_time_start], method="nearest"
)[0]

# Summary printout
print(f"Sample No: {sample_no}, D: {dwell_time}s, W: {_weld_speed} mm/min")
print(f"Weld Time: {weld_time}s")
print(f"time_start: {dwell_time_start}s, time_end: {dwell_time_end}s")
print(f"time_start_idx: {dwell_time_start_idx}, time_end_idx: {dwell_time_end_idx}")
print(f"Dwell Time (actual): {dwell_time_actual}s")
print(f"Pre-dwell Time Start: {pre_dwell_time_start}s, Pre-dwell Time Start Index: {pre_dwell_time_start_idx}") 

# Plotting
fig, axes = plt.subplots(3, 1, figsize=(12, 8))
axes[0].plot(af.index, af["Fz"], label="Axial Force (Fz)")
axes[0].plot(af.index[peak_idxes], af["Fz"].iloc[peak_idxes], "o", label="Peaks")
axes[0].axvline(x=dwell_time_start, color="red", linestyle="--", label="Dwell Start")
axes[0].axvline(x=dwell_time_end, color="green", linestyle="--", label="Dwell End")
axes[0].axvline(x=weld_time_end, color="purple", linestyle="--", label="Weld Stop")
axes[0].axvline(x=pre_dwell_time_start, color="orange", linestyle="--", label="Pre-Dwell Start")
axes[0].set_ylabel("Axial Force (kN)")

# Zoomed-in plot around dwell time
axes[1].plot(af.index, af["Fz"], label="Axial Force (Fz)")
axes[1].axvline(x=dwell_time_start, color="red", linestyle="--", label="Dwell Start")
xlim_start = [
    dwell_time_start - dwell_time * zoom_level,
    dwell_time_start + dwell_time * zoom_level,
]
axes[1].set_xlim(xlim_start)
axes[1].plot(af.index[peak_idxes], af["Fz"].iloc[peak_idxes], "o", label="Peaks")
for peak_idx in peak_idxes:
    axes[1].text(
        af.index[peak_idx],
        af["Fz"].iloc[peak_idx],
        str(peak_idx),
        color="red",
        clip_on=True,
    )
axes[1].set_ylabel("Axial Force (kN)")

# Zoomed-in plot around dwell time
axes[2].plot(af.index, af["Fz"], label="Axial Force (Fz)")
axes[2].axvline(x=dwell_time_end, color="green", linestyle="--", label="Dwell End")
xlim_end = [
    dwell_time_end - dwell_time * zoom_level,
    dwell_time_end + dwell_time * zoom_level,
]
axes[2].set_xlim(xlim_end)
axes[2].plot(af.index[peak_idxes], af["Fz"].iloc[peak_idxes], "o", label="Peaks")
for peak_idx in peak_idxes:
    axes[2].text(
        af.index[peak_idx],
        af["Fz"].iloc[peak_idx],
        str(peak_idx),
        color="red",
        clip_on=True,
    )
axes[2].set_ylabel("Axial Force (kN)")
axes[2].set_xlabel("Time (s)")


xlim_all = [dwell_time_start - dwell_time * 0.5, dwell_time_end + dwell_time * 0.5]
filt = (af.index[peak_idxes] > xlim_all[0]) & (af.index[peak_idxes] < xlim_all[1])
peak_idxes_zoomed = peak_idxes[filt]
print(peak_idxes_zoomed)

fig.suptitle(
    f"Axial Force, Sample No: {sample_no}, Dwell Time: {dwell_time:.1f}s / {dwell_time_actual:.1f}s, W: {_weld_speed} mm/min"
)
fig.tight_layout()
# Out:
# Sample No: 1, D: 10s, W: 60 mm/min
# Weld Time: 130.0s
# time_start: 28.560000000000002s, time_end: 38.56s
# time_start_idx: 2856, time_end_idx: 3856
# Dwell Time (actual): 10.0s
# Pre-dwell Time Start: 11.16s, Pre-dwell Time Start Index: 1116
# [2464 2794 2862 2978 4283]

# %% [markdown]
# ## Function

# %%
def peak_detection(
    sample_no,
    threshold,
    idx_start_chosen,
    idx_end_chosen,
    file_prefix="S12_2_peak",
    zoom_level=1,
):
    # sample_no = 1
    # idx_start_chosen = None
    # idx_end_chosen = None
    # threshold = 0.1
    # zoom_level=1
    peak_condition = dict(height=(1, None), threshold=(threshold, None))

    # Extract relevant data
    dwell_time = metas.loc[metas["sample_no"] == sample_no, "D"].values[0]
    # sampling_rate = metas.loc[
    #     metas["sample_no"] == sample_no, "Sampling rate [Hz]"
    # ].values[0]
    _weld_speed = metas.loc[metas["sample_no"] == sample_no, "W"].values[0]  # mm/min
    weld_speed = _weld_speed / 60  # Convert to mm/s
    af = afs.loc[afs["sample_no"] == sample_no].reset_index(drop=True)
    af.set_index("Time", inplace=True)
    weld_time_end = weld_end.loc[
        weld_end["sample_no"] == sample_no, "weld_time_end"
    ].values[0]

    # Weld time is calculated from the speed and length of sample which is 130 mm
    weld_time = (130) / weld_speed

    # Estimate dwell time checkpoints
    dwell_time_end_approx = weld_time_end - weld_time

    # Find peaks in axial force data
    peak_idxes, props = find_peaks(af["Fz"], **peak_condition)

    # Choose dwell time end based on peak indexes
    if idx_end_chosen is None:  # Auto select based on dwell time
        dwell_time_end_idx = af.index.get_indexer(
            [dwell_time_end_approx], method="nearest"
        )[0]
    else:
        if idx_end_chosen < 0:
            raise ValueError("idx_end_chosen must be non-negative integer.")
        else:
            dwell_time_end_idx = idx_end_chosen
    dwell_time_end = af.index[dwell_time_end_idx]

    # Choose dwell time start
    if idx_start_chosen is None:  # Auto select based on dwell time
        dwell_time_start = dwell_time_end - dwell_time
        dwell_time_start_idx = af.index.get_indexer(
            [dwell_time_start], method="nearest"
        )[0]
    else:  # Manual select
        if idx_start_chosen < 0:
            raise ValueError("idx_start_chosen must be non-negative integer.")
        elif idx_start_chosen <= 10:  # Select from peak indexes
            dwell_time_start_idx = peak_idxes[idx_start_chosen]
            dwell_time_start = af.index[dwell_time_start_idx]
        else:  # Directly specify index
            dwell_time_start_idx = idx_start_chosen
            dwell_time_start = af.index[dwell_time_start_idx]

    # Actual dwell time
    dwell_time_actual = dwell_time_end - dwell_time_start


    # Determine the start of pre-dwell time for reference
    pre_dwell_time = 4.90 / (10 / 60)  # 2.90 mm at 10 mm/min
    pre_dwell_time_start = dwell_time_start - pre_dwell_time

    pre_dwell_time_start_idx = af.index.get_indexer(
        [pre_dwell_time_start], method="nearest"
    )[0]

    # Plotting
    fig, axes = plt.subplots(3, 1, figsize=(12, 8))
    axes[0].plot(af.index, af["Fz"], label="Axial Force (Fz)")
    axes[0].plot(af.index[peak_idxes], af["Fz"].iloc[peak_idxes], "o", label="Peaks")
    axes[0].axvline(
        x=dwell_time_start, color="red", linestyle="--", label="Dwell Start"
    )
    axes[0].axvline(x=dwell_time_end, color="green", linestyle="--", label="Dwell End")
    axes[0].axvline(x=weld_time_end, color="purple", linestyle="--", label="Weld Stop")
    axes[0].axvline(x=pre_dwell_time_start, color="orange", linestyle="--", label="Pre-Dwell Start")
    axes[0].set_ylabel("Axial Force (kN)")

    # Zoomed-in plot around dwell time
    axes[1].plot(af.index, af["Fz"], label="Axial Force (Fz)")
    axes[1].axvline(
        x=dwell_time_start, color="red", linestyle="--", label="Dwell Start"
    )
    xlim_start = [
        dwell_time_start - dwell_time * zoom_level,
        dwell_time_start + dwell_time * zoom_level,
    ]
    axes[1].set_xlim(xlim_start)
    axes[1].plot(af.index[peak_idxes], af["Fz"].iloc[peak_idxes], "o", label="Peaks")
    for peak_idx in peak_idxes:
        axes[1].text(
            af.index[peak_idx],
            af["Fz"].iloc[peak_idx],
            str(peak_idx),
            color="red",
            clip_on=True,
        )
    axes[1].set_ylabel("Axial Force (kN)")

    # Zoomed-in plot around dwell time
    axes[2].plot(af.index, af["Fz"], label="Axial Force (Fz)")
    axes[2].axvline(x=dwell_time_end, color="green", linestyle="--", label="Dwell End")
    xlim_end = [
        dwell_time_end - dwell_time * zoom_level,
        dwell_time_end + dwell_time * zoom_level,
    ]
    axes[2].set_xlim(xlim_end)
    axes[2].plot(af.index[peak_idxes], af["Fz"].iloc[peak_idxes], "o", label="Peaks")
    for peak_idx in peak_idxes:
        axes[2].text(
            af.index[peak_idx],
            af["Fz"].iloc[peak_idx],
            str(peak_idx),
            color="red",
            clip_on=True,
        )
    axes[2].set_ylabel("Axial Force (kN)")
    axes[2].set_xlabel("Time (s)")

    xlim_all = [dwell_time_start - dwell_time * 0.5, dwell_time_end + dwell_time * 0.5]
    filt = (af.index[peak_idxes] > xlim_all[0]) & (af.index[peak_idxes] < xlim_all[1])
    peak_idxes_zoomed = peak_idxes[filt]
    print(peak_idxes_zoomed)

    fig.suptitle(
        f"Axial Force, Sample No: {sample_no}, Dwell Time: {dwell_time:.1f}s / {dwell_time_actual:.1f}s, W: {_weld_speed} mm/min"
    )
    fig.tight_layout()
    fig.savefig(
        f"{OUT_DIR}/{file_prefix}_sample_{sample_no}.png", dpi=300, bbox_inches="tight"
    )
    plt.close(fig)

    return dict(
        dwell_time_start=dwell_time_start,
        dwell_time_end=dwell_time_end,
        dwell_time_start_idx=dwell_time_start_idx,
        dwell_time_end_idx=dwell_time_end_idx,
        dwell_time_actual=dwell_time_actual,
        pre_dwell_time_start=pre_dwell_time_start,
        pre_dwell_time_start_idx=pre_dwell_time_start_idx,
        pre_dwell_time=pre_dwell_time,
    )

# %%
default_idx_start_chosen = None
default_idx_end_chosen = None
default_threshold = 0.1
default_zoom_level = 1

_params = []
for sample_no in metas["sample_no"].unique():
    _params.append(
        dict(
            sample_no=sample_no,
            idx_start_chosen=default_idx_start_chosen,
            idx_end_chosen=default_idx_end_chosen,
            threshold=default_threshold,
            zoom_level=default_zoom_level,
        )
    )
params = pd.DataFrame.from_dict(_params)
display(params)
# Out:
#     sample_no idx_start_chosen idx_end_chosen  threshold  zoom_level
# 0           1             None           None        0.1           1
# 1           2             None           None        0.1           1
# 2           3             None           None        0.1           1
# 3           4             None           None        0.1           1
# 4           5             None           None        0.1           1
# 5           6             None           None        0.1           1
# 6           7             None           None        0.1           1
# 7           8             None           None        0.1           1
# 8           9             None           None        0.1           1
# 9          10             None           None        0.1           1
# 10         11             None           None        0.1           1
# 11         12             None           None        0.1           1
# 12         13             None           None        0.1           1
# 13         14             None           None        0.1           1
# 14         15             None           None        0.1           1
# 15         16             None           None        0.1           1
# 16         17             None           None        0.1           1
# 17         18             None           None        0.1           1
# 18         19             None           None        0.1           1
# 19         20             None           None        0.1           1
# 20         21             None           None        0.1           1
# 21         22             None           None        0.1           1
# 22         23             None           None        0.1           1
# 23         24             None           None        0.1           1
# 24         25             None           None        0.1           1
# 25         26             None           None        0.1           1
# 26         27             None           None        0.1           1
# 27         28             None           None        0.1           1
# 28         29             None           None        0.1           1
# 29         30             None           None        0.1           1
# 30         31             None           None        0.1           1
# 31         32             None           None        0.1           1
# 32         33             None           None        0.1           1
# 33         34             None           None        0.1           1
# 34         35             None           None        0.1           1
# 35         36             None           None        0.1           1
# 36         37             None           None        0.1           1
# 37         38             None           None        0.1           1
# 38         39             None           None        0.1           1
# 39         40             None           None        0.1           1
# 40         41             None           None        0.1           1
# 41         42             None           None        0.1           1
# 42         43             None           None        0.1           1
# 43         44             None           None        0.1           1
# 44         45             None           None        0.1           1
# 45         46             None           None        0.1           1
# 46         47             None           None        0.1           1
# 47         48             None           None        0.1           1
# 48         49             None           None        0.1           1
# 49         50             None           None        0.1           1
# 50         51             None           None        0.1           1
# 51         52             None           None        0.1           1
# 52         53             None           None        0.1           1
# 53         54             None           None        0.1           1

# %% [markdown]
# ## Override parameters

# %%
# Override parameters for specific samples if needed
# Example: dict(sample_no=1, idx_start_chosen=8, idx_end_chosen=None, threshold=0.1)

override = [
    # dict(sample_no=4, idx_end_chosen=2624),
]

for ov in override:
    for key, value in ov.items():
        if key != "sample_no":
            params.loc[params["sample_no"] == ov["sample_no"], key] = value

display(params)
# Out:
#     sample_no idx_start_chosen idx_end_chosen  threshold  zoom_level
# 0           1             None           None        0.1           1
# 1           2             None           None        0.1           1
# 2           3             None           None        0.1           1
# 3           4             None           None        0.1           1
# 4           5             None           None        0.1           1
# 5           6             None           None        0.1           1
# 6           7             None           None        0.1           1
# 7           8             None           None        0.1           1
# 8           9             None           None        0.1           1
# 9          10             None           None        0.1           1
# 10         11             None           None        0.1           1
# 11         12             None           None        0.1           1
# 12         13             None           None        0.1           1
# 13         14             None           None        0.1           1
# 14         15             None           None        0.1           1
# 15         16             None           None        0.1           1
# 16         17             None           None        0.1           1
# 17         18             None           None        0.1           1
# 18         19             None           None        0.1           1
# 19         20             None           None        0.1           1
# 20         21             None           None        0.1           1
# 21         22             None           None        0.1           1
# 22         23             None           None        0.1           1
# 23         24             None           None        0.1           1
# 24         25             None           None        0.1           1
# 25         26             None           None        0.1           1
# 26         27             None           None        0.1           1
# 27         28             None           None        0.1           1
# 28         29             None           None        0.1           1
# 29         30             None           None        0.1           1
# 30         31             None           None        0.1           1
# 31         32             None           None        0.1           1
# 32         33             None           None        0.1           1
# 33         34             None           None        0.1           1
# 34         35             None           None        0.1           1
# 35         36             None           None        0.1           1
# 36         37             None           None        0.1           1
# 37         38             None           None        0.1           1
# 38         39             None           None        0.1           1
# 39         40             None           None        0.1           1
# 40         41             None           None        0.1           1
# 41         42             None           None        0.1           1
# 42         43             None           None        0.1           1
# 43         44             None           None        0.1           1
# 44         45             None           None        0.1           1
# 45         46             None           None        0.1           1
# 46         47             None           None        0.1           1
# 47         48             None           None        0.1           1
# 48         49             None           None        0.1           1
# 49         50             None           None        0.1           1
# 50         51             None           None        0.1           1
# 51         52             None           None        0.1           1
# 52         53             None           None        0.1           1
# 53         54             None           None        0.1           1

# %%
reses = []
for param in params.to_dict(orient="records")[:]:
    print(param)
    res = peak_detection(**param)
    res = {**param, **res}
    reses.append(res)
    print("----------")

dfpeak = pd.DataFrame.from_dict(reses)
# Out:
# {'sample_no': 1, 'idx_start_chosen': None, 'idx_end_chosen': None, 'threshold': 0.1, 'zoom_level': 1}
# [2464 2794 2862 2978 4283]
# ----------
# {'sample_no': 2, 'idx_start_chosen': None, 'idx_end_chosen': None, 'threshold': 0.1, 'zoom_level': 1}
# [