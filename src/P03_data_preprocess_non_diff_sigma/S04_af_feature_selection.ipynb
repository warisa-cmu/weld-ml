# %%
import os
import pickle
import re
from pathlib import Path
import pandas as pd

# %%
rel_dwell = pd.read_excel("S03_af_feature_relevance.xlsx", sheet_name="af_dwell")
rel_weld = pd.read_excel("S03_af_feature_relevance.xlsx", sheet_name="af_weld")

# %%
rel_dwell
# Out:
#                                               feature      type   p_value  \
# 0         Fz__fft_coefficient__attr_"angle"__coeff_48      real  0.007726
# 1         Fz__fft_coefficient__attr_"angle"__coeff_73      real  0.028895
# 2                  Fz__ar_coefficient__coeff_10__k_10      real  0.030011
# 3          Fz__fft_coefficient__attr_"real"__coeff_72      real  0.031163
# 4      Fz__friedrich_coefficients__coeff_3__m_3__r_30      real  0.037511
# ...                                               ...       ...       ...
# 18763                   Fz__ratio_beyond_r_sigma__r_6  constant       NaN
# 18764                   Fz__ratio_beyond_r_sigma__r_7  constant       NaN
# 18765                  Fz__ratio_beyond_r_sigma__r_10  constant       NaN
# 18766                            Fz__count_above__t_0  constant       NaN
# 18767                            Fz__count_below__t_0  constant       NaN
#
#        relevant            y
# 0         False    AA5052_L1
# 1         False    AA5052_L1
# 2         False    AA5052_L1
# 3         False    AA5052_L1
# 4         False    AA5052_L1
# ...         ...          ...
# 18763     False  Center_mean
# 18764     False  Center_mean
# 18765     False  Center_mean
# 18766     False  Center_mean
# 18767     False  Center_mean
#
# [18768 rows x 5 columns]

# %%
rel_weld
# Out:
#                                                  feature      type   p_value  \
# 0              Fz__fft_coefficient__attr_"abs"__coeff_84      real  0.017338
# 1                     Fz__partial_autocorrelation__lag_7      real  0.024783
# 2      Fz__large_standard_deviation__r_0.150000000000...    binary  0.030048
# 3                        Fz__ratio_beyond_r_sigma__r_1.5      real  0.037511
# 4             Fz__fft_coefficient__attr_"real"__coeff_90      real  0.041825
# ...                                                  ...       ...       ...
# 18763                      Fz__ratio_beyond_r_sigma__r_6  constant       NaN
# 18764                      Fz__ratio_beyond_r_sigma__r_7  constant       NaN
# 18765                     Fz__ratio_beyond_r_sigma__r_10  constant       NaN
# 18766                               Fz__count_above__t_0  constant       NaN
# 18767                               Fz__count_below__t_0  constant       NaN
#
#        relevant            y
# 0         False    AA5052_L1
# 1         False    AA5052_L1
# 2         False    AA5052_L1
# 3         False    AA5052_L1
# 4         False    AA5052_L1
# ...         ...          ...
# 18763     False  Center_mean
# 18764     False  Center_mean
# 18765     False  Center_mean
# 18766     False  Center_mean
# 18767     False  Center_mean
#
# [18768 rows x 5 columns]

# %%
display(rel_dwell[rel_dwell["relevant"]])
# Out:
#                                                  feature  type   p_value  \
# 12512                Fz__approximate_entropy__m_2__r_0.7  real  0.000011
# 12513                         Fz__autocorrelation__lag_2  real  0.000026
# 12514                         Fz__autocorrelation__lag_1  real  0.000028
# 12515                 Fz__partial_autocorrelation__lag_1  real  0.000028
# 12516                         Fz__autocorrelation__lag_6  real  0.000028
# 12517                Fz__approximate_entropy__m_2__r_0.9  real  0.000030
# 12518  Fz__energy_ratio_by_chunks__num_segments_10__s...  real  0.000032
# 12519                     Fz__index_mass_quantile__q_0.3  real  0.000034
# 12520                     Fz__index_mass_quantile__q_0.2  real  0.000034
# 12521  Fz__energy_ratio_by_chunks__num_segments_10__s...  real  0.000044
# 12522                          Fz__variation_coefficient  real  0.000046
# 12523                     Fz__index_mass_quantile__q_0.1  real  0.000048
# 12524  Fz__energy_ratio_by_chunks__num_segments_10__s...  real  0.000060
# 12525                         Fz__cid_ce__normalize_True  real  0.000060
# 12526                     Fz__index_mass_quantile__q_0.4  real  0.000066
# 12527    Fz__agg_autocorrelation__f_agg_"var"__maxlag_40  real  0.000082
# 12528   Fz__agg_autocorrelation__f_agg_"mean"__maxlag_40  real  0.000087
# 12529                 Fz__partial_autocorrelation__lag_2  real  0.000119
# 12530  Fz__energy_ratio_by_chunks__num_segments_10__s...  real  0.000126
# 12531                     Fz__index_mass_quantile__q_0.6  real  0.000130
# 12532  Fz__agg_autocorrelation__f_agg_"median"__maxla...  real  0.000134
# 12533         Fz__fft_coefficient__attr_"real"__coeff_70  real  0.000151
# 12534                     Fz__index_mass_quantile__q_0.7  real  0.000204
# 12535             Fz__fft_aggregated__aggtype_"kurtosis"  real  0.000216
# 12536                Fz__approximate_entropy__m_2__r_0.5  real  0.000230
# 12537  Fz__energy_ratio_by_chunks__num_segments_10__s...  real  0.000230
# 12538                                Fz__quantile__q_0.2  real  0.000243
# 12539                 Fz__fft_aggregated__aggtype_"skew"  real  0.000258
# 12540                                Fz__quantile__q_0.1  real  0.000258
# 12541                  Fz__ar_coefficient__coeff_3__k_10  real  0.000290
# 12542                    Fz__spkt_welch_density__coeff_5  real  0.000290
#
#        relevant          y
# 12512      True  Center_L3
# 12513      True  Center_L3
# 12514      True  Center_L3
# 12515      True  Center_L3
# 12516      True  Center_L3
# 12517      True  Center_L3
# 12518      True  Center_L3
# 12519      True  Center_L3
# 12520      True  Center_L3
# 12521      True  Center_L3
# 12522      True  Center_L3
# 12523      True  Center_L3
# 12524      True  Center_L3
# 12525      True  Center_L3
# 12526      True  Center_L3
# 12527      True  Center_L3
# 12528      True  Center_L3
# 12529      True  Center_L3
# 12530      True  Center_L3
# 12531      True  Center_L3
# 12532      True  Center_L3
# 12533      True  Center_L3
# 12534      True  Center_L3
# 12535      True  Center_L3
# 12536      True  Center_L3
# 12537      True  Center_L3
# 12538      True  Center_L3
# 12539      True  Center_L3
# 12540      True  Center_L3
# 12541      True  Center_L3
# 12542      True  Center_L3

# %%
display(rel_weld[rel_weld["relevant"]])
# Out:
#                                                  feature  type   p_value  \
# 1564          Fz__fft_coefficient__attr_"imag"__coeff_32  real  0.000005
# 1565          Fz__fft_coefficient__attr_"imag"__coeff_34  real  0.000012
# 1566          Fz__fft_coefficient__attr_"imag"__coeff_31  real  0.000012
# 1567          Fz__fft_coefficient__attr_"imag"__coeff_91  real  0.000036
# 1568          Fz__fft_coefficient__attr_"imag"__coeff_43  real  0.000088
# ...                                                  ...   ...       ...
# 12664         Fz__fft_coefficient__attr_"imag"__coeff_18  real  0.001152
# 12665         Fz__fft_coefficient__attr_"imag"__coeff_77  real  0.001214
# 12666  Fz__cwt_coefficients__coeff_14__w_5__widths_(2...  real  0.001279
# 12667         Fz__fft_coefficient__attr_"real"__coeff_36  real  0.001347
# 12668        Fz__fft_coefficient__attr_"angle"__coeff_31  real  0.001347
#
#        relevant          y
# 1564       True  AA5052_L3
# 1565       True  AA5052_L3
# 1566       True  AA5052_L3
# 1567       True  AA5052_L3
# 1568       True  AA5052_L3
# ...         ...        ...
# 12664      True  Center_L3
# 12665      True  Center_L3
# 12666      True  Center_L3
# 12667      True  Center_L3
# 12668      True  Center_L3
#
# [400 rows x 5 columns]

# %%
def apply_select(df, num=5):
    # print(df.name)
    filt_p = (df["p_value"] <= 0.05) | df["relevant"]
    df_filt = df[filt_p]
    df_filt = df_filt.sort_values(by="p_value", ascending=True).reset_index(drop=True).head(num)
    return df_filt

# data = rel_dwell
# dfg = data.groupby("y")
# group_names = list(dfg.groups.keys())
# name = group_names[0]
# df = dfg.get_group(name)
# filt_p = (df["p_value"] <= 0.05) | df["relevant"]
# df_filt = df[filt_p]
# display(df_filt)

# %%
# Select features for dwell 
dfg = rel_dwell.groupby("y")
_select = dfg.apply(lambda df: apply_select(df, num=3), include_groups=False)
_select = _select.reset_index().drop(columns=["level_1"])
print(f"Selected features (1st round) for dwell: {_select.shape[0]}")
filt_dup = _select.duplicated(subset=["feature"])
print(f"Duplicated features: {_select[filt_dup].shape[0]}")
select = _select[~filt_dup]
print(f"Selected features: {select.shape[0]}")
display(_select[~filt_dup])
# Save selected features
select_dwell = select.copy()
# Out:
# Selected features (1st round) for dwell: 72
# Duplicated features: 11
# Selected features: 61
#               y                                            feature  type  \
# 0     AA5052_L1        Fz__fft_coefficient__attr_"angle"__coeff_48  real
# 1     AA5052_L1        Fz__fft_coefficient__attr_"angle"__coeff_73  real
# 2     AA5052_L1                 Fz__ar_coefficient__coeff_10__k_10  real
# 3     AA5052_L2                  Fz__ar_coefficient__coeff_6__k_10  real
# 4     AA5052_L2  Fz__cwt_coefficients__coeff_13__w_5__widths_(2...  real
# ..          ...                                                ...   ...
# 66    Center_L7         Fz__fft_coefficient__attr_"real"__coeff_35  real
# 67    Center_L7  Fz__change_quantiles__f_agg_"var"__isabs_True_...  real
# 68    Center_L7  Fz__agg_linear_trend__attr_"slope"__chunk_len_...  real
# 70  Center_mean                Fz__approximate_entropy__m_2__r_0.9  real
# 71  Center_mean                         Fz__cid_ce__normalize_True  real
#
#      p_value  relevant
# 0   0.007726     False
# 1   0.028895     False
# 2   0.030011     False
# 3   0.000306     False
# 4   0.001210     False
# ..       ...       ...
# 66  0.003132     False
# 67  0.005528     False
# 68  0.006637     False
# 70  0.001900     False
# 71  0.003431     False
#
# [61 rows x 5 columns]

# %%
# Select features for weld
dfg = rel_weld.groupby("y")
_select = dfg.apply(lambda df: apply_select(df, num=6), include_groups=False)
_select = _select.reset_index().drop(columns=["level_1"])
print(f"Selected features (1st round) for weld: {_select.shape[0]}")
filt_dup = _select.duplicated(subset=["feature"])
print(f"Duplicated features: {_select[filt_dup].shape[0]}")
select = _select[~filt_dup]
print(f"Selected features: {select.shape[0]}")
display(_select[~filt_dup])
# Save selected features
select_weld = select.copy()
# Out:
# Selected features (1st round) for weld: 144
# Duplicated features: 28
# Selected features: 116
#                y                                            feature    type  \
# 0      AA5052_L1          Fz__fft_coefficient__attr_"abs"__coeff_84    real
# 1      AA5052_L1                 Fz__partial_autocorrelation__lag_7    real
# 2      AA5052_L1  Fz__large_standard_deviation__r_0.150000000000...  binary
# 3      AA5052_L1                    Fz__ratio_beyond_r_sigma__r_1.5    real
# 4      AA5052_L1         Fz__fft_coefficient__attr_"real"__coeff_90    real
# ..           ...                                                ...     ...
# 133    Center_L7  Fz__change_quantiles__f_agg_"mean"__isabs_Fals...    real
# 137    Center_L7  Fz__change_quantiles__f_agg_"mean"__isabs_Fals...    real
# 140  Center_mean                    Fz__ratio_beyond_r_sigma__r_2.5    real
# 142  Center_mean                    Fz__binned_entropy__max_bins_10    real
# 143  Center_mean                                       Fz__kurtosis    real
#
#       p_value  relevant
# 0    0.017338     False
# 1    0.024783     False
# 2    0.030048     False
# 3    0.037511     False
# 4    0.041825     False
# ..        ...       ...
# 133  0.001636     False
# 137  0.004590     False
# 140  0.000254     False
# 142  0.000701     False
# 143  0.000918     False
#
# [116 rows x 5 columns]

# %%
with pd.ExcelWriter("S04_af_feature_selection.xlsx", engine="openpyxl") as writer:
    select_dwell.to_excel(writer, sheet_name="af_dwell", index=False)
    select_weld.to_excel(writer, sheet_name="af_weld", index=False)
