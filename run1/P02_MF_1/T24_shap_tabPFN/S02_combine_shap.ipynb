# %%
import os
import re
from pathlib import Path

import numpy as np
import pandas as pd
import shap

from run1.lib.utils import MyUtil

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file

# %%
OUTDIR = CURRENT_DIR / "S01"
os.makedirs(OUTDIR, exist_ok=True)

# %%
filenames = [f for f in os.listdir(OUTDIR)]
print(f"Found {len(filenames)} files:")
print(filenames)
# Out:
# Found 3 files:
# ['batch_0.pkl', 'batch_1.pkl', 'batch_2.pkl']

# %%
shap_values_list = []
for filename in os.listdir(OUTDIR):
    print(f"Loading {filename}...")
    data = MyUtil.load_data(OUTDIR / filename)
    shap_values_list.append(data["shap_values"])
# Out:
# Loading batch_0.pkl...
# Loading batch_1.pkl...
# Loading batch_2.pkl...

# %%
# Combine SHAP values
feature_names = shap_values_list[0].feature_names

# Combine values
combined_shape_values = np.vstack([sv.values for sv in shap_values_list])
combined_shape_values.shape

# Combine base values
combined_base_values = np.concatenate([sv.base_values for sv in shap_values_list])
combined_base_values.shape

# Combine data (feature values)
combined_data = np.vstack([sv.data for sv in shap_values_list])
combined_data.shape
# Out:
# (9, 32)

# %%
shap_values = shap.Explanation(
    values=combined_shape_values, 
    base_values=combined_base_values,
    data=combined_data,
    feature_names=shap_values_list[0].feature_names,
)

# %%
shap.plots.beeswarm(shap_values)

# %%
# Plot SHAP bar plot
shap.plots.bar(shap_values)

# %%
# Plot SHAP summary plot with feature names
shap.summary_plot(shap_values)

# %%
feature_names = shap_values.feature_names
shap_df = pd.DataFrame(shap_values.values, columns=feature_names)
vals = np.abs(shap_df.values).mean(0)
shap_importance = pd.DataFrame(list(zip(feature_names, vals)), columns=['col_name', 'feature_importance_vals'])
shap_importance.sort_values(by=['feature_importance_vals'], ascending=False, inplace=True)
shap_importance
# Out:
#                                              col_name  feature_importance_vals
# 0                                            position                 0.461386
# 28                Fz__weld__ratio_beyond_r_sigma__r_1                 0.096058
# 10          Fx__dwell__partial_autocorrelation__lag_6                 0.075008
# 1                                                   R                 0.072439
# 6                                         Fz_location                 0.045465
# 7                                         Mz_location                 0.043953
# 2                                                   W                 0.041142
# 25   Fy__weld__fft_coefficient__attr_"real"__coeff_51                 0.037606
# 4                                         Fx_location                 0.026595
# 8    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11                 0.022970
# 31    Mz__weld__fft_coefficient__attr_"abs"__coeff_58                 0.022556
# 22    Fx__weld__fft_coefficient__attr_"abs"__coeff_58                 0.020755
# 29                          Mz__weld__quantile__q_0.1                 0.015502
# 13  Fy__dwell__change_quantiles__f_agg_"mean"__isa...                 0.012865
# 23  Fy__weld__energy_ratio_by_chunks__num_segments...                 0.012634
# 3                                                   D                 0.012446
# 26  Fz__weld__change_quantiles__f_agg_"mean"__isab...                 0.012159
# 16         Fz__dwell__approximate_entropy__m_2__r_0.7                 0.012067
# 20  Fx__weld__change_quantiles__f_agg_"var"__isabs...                 0.011453
# 19  Mz__dwell__change_quantiles__f_agg_"mean"__isa...                 0.010336
# 18  Mz__dwell__fft_coefficient__attr_"real"__coeff_62                 0.009872
# 11  Fy__dwell__fft_coefficient__attr_"real"__coeff_71                 0.008442
# 27   Fz__weld__fft_coefficient__attr_"real"__coeff_84                 0.008386
# 30  Mz__weld__fft_coefficient__attr_"angle"__coeff_15                 0.008375
# 17  Mz__dwell__augmented_dickey_fuller__attr_"test...                 0.008199
# 9                          Fx__dwell__quantile__q_0.7                 0.008086
# 5                                         Fy_location                 0.006868
# 24   Fy__weld__fft_coefficient__attr_"imag"__coeff_61                 0.005771
# 21   Fx__weld__fft_coefficient__attr_"real"__coeff_31                 0.004850
# 15  Fz__dwell__fft_coefficient__attr_"angle"__coef...                 0.004498
# 12                Fy__dwell__last_location_of_minimum                 0.003729
# 14  Fz__dwell__fft_coefficient__attr_"angle"__coeff_4                 0.003184

# %%
ranking = shap_importance.rename(columns={"col_name": "feature", "feature_importance_vals": "value"})
ranking["measure"] = "SHAP_importance"
ranking["rank"] = np.arange(1, len(ranking) + 1)
ranking
# Out:
#                                               feature     value  \
# 0                                            position  0.461386
# 28                Fz__weld__ratio_beyond_r_sigma__r_1  0.096058
# 10          Fx__dwell__partial_autocorrelation__lag_6  0.075008
# 1                                                   R  0.072439
# 6                                         Fz_location  0.045465
# 7                                         Mz_location  0.043953
# 2                                                   W  0.041142
# 25   Fy__weld__fft_coefficient__attr_"real"__coeff_51  0.037606
# 4                                         Fx_location  0.026595
# 8    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  0.022970
# 31    Mz__weld__fft_coefficient__attr_"abs"__coeff_58  0.022556
# 22    Fx__weld__fft_coefficient__attr_"abs"__coeff_58  0.020755
# 29                          Mz__weld__quantile__q_0.1  0.015502
# 13  Fy__dwell__change_quantiles__f_agg_"mean"__isa...  0.012865
# 23  Fy__weld__energy_ratio_by_chunks__num_segments...  0.012634
# 3                                                   D  0.012446
# 26  Fz__weld__change_quantiles__f_agg_"mean"__isab...  0.012159
# 16         Fz__dwell__approximate_entropy__m_2__r_0.7  0.012067
# 20  Fx__weld__change_quantiles__f_agg_"var"__isabs...  0.011453
# 19  Mz__dwell__change_quantiles__f_agg_"mean"__isa...  0.010336
# 18  Mz__dwell__fft_coefficient__attr_"real"__coeff_62  0.009872
# 11  Fy__dwell__fft_coefficient__attr_"real"__coeff_71  0.008442
# 27   Fz__weld__fft_coefficient__attr_"real"__coeff_84  0.008386
# 30  Mz__weld__fft_coefficient__attr_"angle"__coeff_15  0.008375
# 17  Mz__dwell__augmented_dickey_fuller__attr_"test...  0.008199
# 9                          Fx__dwell__quantile__q_0.7  0.008086
# 5                                         Fy_location  0.006868
# 24   Fy__weld__fft_coefficient__attr_"imag"__coeff_61  0.005771
# 21   Fx__weld__fft_coefficient__attr_"real"__coeff_31  0.004850
# 15  Fz__dwell__fft_coefficient__attr_"angle"__coef...  0.004498
# 12                Fy__dwell__last_location_of_minimum  0.003729
# 14  Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  0.003184
#
#             measure  rank
# 0   SHAP_importance     1
# 28  SHAP_importance     2
# 10  SHAP_importance     3
# 1   SHAP_importance     4
# 6   SHAP_importance     5
# 7   SHAP_importance     6
# 2   SHAP_importance     7
# 25  SHAP_importance     8
# 4   SHAP_importance     9
# 8   SHAP_importance    10
# 31  SHAP_importance    11
# 22  SHAP_importance    12
# 29  SHAP_importance    13
# 13  SHAP_importance    14
# 23  SHAP_importance    15
# 3   SHAP_importance    16
# 26  SHAP_importance    17
# 16  SHAP_importance    18
# 20  SHAP_importance    19
# 19  SHAP_importance    20
# 18  SHAP_importance    21
# 11  SHAP_importance    22
# 27  SHAP_importance    23
# 30  SHAP_importance    24
# 17  SHAP_importance    25
# 9   SHAP_importance    26
# 5   SHAP_importance    27
# 24  SHAP_importance    28
# 21  SHAP_importance    29
# 15  SHAP_importance    30
# 12  SHAP_importance    31
# 14  SHAP_importance    32

# %%
ranking.to_excel("S02.xlsx", index=False)
