# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = BASE_DIR.parent.parent.parent
DATA_DIR = ROOT_DIR / "run1" / "data"
CURRENT_DIR = BASE_DIR

# %%
df = pd.read_excel(CURRENT_DIR / "S01_calculate_performance.xlsx")

# %%
df
# Out:
#     random_state  test_size   model      Y       MSE      MAPE        R2
# 0              1        0.3  TabPFN    Y-1  0.931094  1.638925  0.271638
# 1              1        0.3  TabPFN    Y-2  0.808430  3.341798  0.014140
# 2              1        0.3  TabPFN    Y-3  0.439000  1.213512  0.485341
# 3              1        0.3  TabPFN  Y-All  0.726174  2.064745  0.257040
# 4              2        0.3  TabPFN    Y-1  0.628294  1.649800  0.279903
# 5              2        0.3  TabPFN    Y-2  0.888766  1.291201  0.006479
# 6              2        0.3  TabPFN    Y-3  0.543111  1.222920  0.507991
# 7              2        0.3  TabPFN  Y-All  0.686724  1.387974  0.264791
# 8              3        0.3  TabPFN    Y-1  0.902839  2.292342  0.197681
# 9              3        0.3  TabPFN    Y-2  0.833931  2.020476  0.095070
# 10             3        0.3  TabPFN    Y-3  0.360647  1.004973  0.508886
# 11             3        0.3  TabPFN  Y-All  0.699139  1.772597  0.267212
# 12             4        0.3  TabPFN    Y-1  0.706113  3.328017  0.375663
# 13             4        0.3  TabPFN    Y-2  0.905452  1.059253  0.091625
# 14             4        0.3  TabPFN    Y-3  0.450968  1.201535  0.465913
# 15             4        0.3  TabPFN  Y-All  0.687511  1.862935  0.311067
# 16             5        0.3  TabPFN    Y-1  0.923880  1.399219  0.207785
# 17             5        0.3  TabPFN    Y-2  0.860281  2.472286 -0.123643
# 18             5        0.3  TabPFN    Y-3  0.479872  1.175822  0.495116
# 19             5        0.3  TabPFN  Y-All  0.754678  1.682442  0.193086

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
sns.boxplot(df_filt, x="model", y="R2", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
