# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performances.xlsx")

# %%
df
# Out:
#      random_state  test_size model      Y  MSE Train (No Val)  MSE Test  \
# 0               1        0.3   DTR    Y-1            0.639196  1.010521
# 1               1        0.3   DTR    Y-2            0.834381  0.850298
# 2               1        0.3   DTR    Y-3            0.520112  0.583230
# 3               1        0.3   DTR  Y-All            0.664563  0.814683
# 4               2        0.3   DTR    Y-1            0.798928  0.851671
# ..            ...        ...   ...    ...                 ...       ...
# 135             4        0.3  XGBR  Y-All            0.580442  0.715813
# 136             5        0.3  XGBR    Y-1            0.426076  0.948221
# 137             5        0.3  XGBR    Y-2            0.663532  0.869682
# 138             5        0.3  XGBR    Y-3            0.356283  0.515279
# 139             5        0.3  XGBR  Y-All            0.481964  0.777727
#
#      MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0               2.039946   1.729898           0.360804  0.209504
# 1               1.526361   5.318583           0.165619 -0.036917
# 2               1.480896   1.627730           0.479888  0.316254
# 3               1.682401   2.892070           0.335437  0.162947
# 4               1.979535   1.895466           0.201072  0.023887
# ..                   ...        ...                ...       ...
# 135             1.682360   1.783944           0.419558  0.282523
# 136            34.268290   1.368625           0.573924  0.186913
# 137             1.179533   2.812358           0.336468 -0.135922
# 138             1.110163   1.069253           0.643717  0.457864
# 139            12.185995   1.750079           0.518036  0.169618
#
# [140 rows x 10 columns]

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
