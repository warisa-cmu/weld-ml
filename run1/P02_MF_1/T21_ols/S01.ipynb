# %%
import re
from pathlib import Path

import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

from run1.lib.classes_ml import DataHandler

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = BASE_DIR.parent.parent.parent
DATA_DIR = ROOT_DIR / "run1" / "P02_MF_1" / "T01_af_features"
CURRENT_DIR = BASE_DIR

# %%
_df = pd.read_excel(DATA_DIR / "S01_combined_data.xlsx")
print(f"df.shape: {_df.shape}")
# Out:
# df.shape: (378, 37)

# %%
# Select columns for features and targets
colsY = [c for c in _df.columns if re.search(r"stress_value", c)]
colsX = [c for c in _df.columns if c not in ["sample_no", "location", *colsY]]

# Select feature columns based on predefined names
colsY = [c for c in colsY if c in ["stress_value_center"]]

_dfY = _df[colsY]
_dfX = _df[colsX]
print("Selected feature columns:", colsX)
print("Selected target columns:", colsY)
print(f"dfX.shape: {_dfX.shape}")
print(f"dfY.shape: {_dfY.shape}")
# Out:
# Selected feature columns: ['position', 'R', 'W', 'D', 'Fx_location', 'Fy_location', 'Fz_location', 'Mz_location', 'Fx__dwell__fft_coefficient__attr_"abs"__coeff_11', 'Fx__dwell__quantile__q_0.7', 'Fx__dwell__partial_autocorrelation__lag_6', 'Fy__dwell__fft_coefficient__attr_"real"__coeff_71', 'Fy__dwell__last_location_of_minimum', 'Fy__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Fz__dwell__fft_coefficient__attr_"angle"__coeff_4', 'Fz__dwell__fft_coefficient__attr_"angle"__coeff_68', 'Fz__dwell__approximate_entropy__m_2__r_0.7', 'Mz__dwell__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"', 'Mz__dwell__fft_coefficient__attr_"real"__coeff_62', 'Mz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2', 'Fx__weld__fft_coefficient__attr_"real"__coeff_31', 'Fx__weld__fft_coefficient__attr_"abs"__coeff_58', 'Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5', 'Fy__weld__fft_coefficient__attr_"imag"__coeff_61', 'Fy__weld__fft_coefficient__attr_"real"__coeff_51', 'Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4', 'Fz__weld__fft_coefficient__attr_"real"__coeff_84', 'Fz__weld__ratio_beyond_r_sigma__r_1', 'Mz__weld__quantile__q_0.1', 'Mz__weld__fft_coefficient__attr_"angle"__coeff_15', 'Mz__weld__fft_coefficient__attr_"abs"__coeff_58']
# Selected target columns: ['stress_value_center']
# dfX.shape: (378, 32)
# dfY.shape: (378, 1)

# %%
# %% Extract features and targets
_X = _dfX.values
_Y = _dfY.values
print(f"_X.shape: {_X.shape}")
print(f"_Y.shape: {_Y.shape}")
# Out:
# _X.shape: (378, 32)
# _Y.shape: (378, 1)

# %%
# Create DataHandler instance
data_handler = DataHandler(
    _X=_X,
    _Y=_Y,
    scalerX=StandardScaler(),
    scalerY=StandardScaler(),
    colsX=colsX,
    colsY=colsY,
)

# %%
idx = 1
random_state = 1
test_size = 0.0
data_handler.split_and_scale(random_state=random_state, test_size=test_size)
df_X_train, df_Y_train = data_handler.get_train(as_dataframe=True)
display(df_X_train.head())
display(df_Y_train.head())
# Out:
# No test set, using all data for training.
#        position         R         W         D  Fx_location  Fy_location  \
# 0 -5.000000e-01 -1.224745  0.000000 -1.224745    -0.777006    -0.464968
# 1 -4.810966e-16  1.224745  1.224745  0.000000    -0.032479    -0.377666
# 2 -1.000000e+00  0.000000 -1.224745 -1.224745     0.064000    -0.782369
# 3 -5.000000e-01  1.224745  1.224745  1.224745    -0.050435    -0.543303
# 4 -1.000000e+00  1.224745  0.000000 -1.224745    -0.117693    -0.393217
#
#    Fz_location  Mz_location  Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  \
# 0    -0.805576    -0.423257                                         -0.212769
# 1     0.320237    -0.355252                                         -0.525585
# 2    -2.024732    -0.465982                                          0.203409
# 3    -0.166273    -0.374813                                         -0.053910
# 4    -1.237342    -0.468396                                         -0.531406
#
#    Fx__dwell__quantile__q_0.7  ...  \
# 0                   -0.267954  ...
# 1                    0.190508  ...
# 2                    1.527986  ...
# 3                    0.267501  ...
# 4                   -0.342628  ...
#
#    Fx__weld__fft_coefficient__attr_"abs"__coeff_58  \
# 0                                         0.601824
# 1                                         0.002835
# 2                                        -0.032205
# 3                                        -1.123431
# 4                                         0.319822
#
#    Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5  \
# 0                                           0.102590
# 1                                          -0.302580
# 2                                           1.093932
# 3                                          -0.944348
# 4                                          -0.398962
#
#    Fy__weld__fft_coefficient__attr_"imag"__coeff_61  \
# 0                                         -1.971528
# 1                                          0.160638
# 2                                         -1.500800
# 3                                          0.233331
# 4                                          0.197916
#
#    Fy__weld__fft_coefficient__attr_"real"__coeff_51  \
# 0                                         -3.387790
# 1                                          0.536173
# 2                                          0.771406
# 3                                         -1.081930
# 4                                          0.044907
#
#    Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                           0.358393
# 1                                          -0.374696
# 2                                           0.329889
# 3                                          -0.163097
# 4                                           0.691684
#
#    Fz__weld__fft_coefficient__attr_"real"__coeff_84  \
# 0                                         -0.865086
# 1                                          2.500901
# 2                                          1.139794
# 3                                          2.072971
# 4                                         -0.271261
#
#    Fz__weld__ratio_beyond_r_sigma__r_1  Mz__weld__quantile__q_0.1  \
# 0                             0.527619                  -0.348236
# 1                            -1.234720                  -0.315047
# 2                             1.948740                  -0.536800
# 3                             0.615044                  -0.294181
# 4                             0.606539                  -0.318095
#
#    Mz__weld__fft_coefficient__attr_"angle"__coeff_15  \
# 0                                           1.361784
# 1                                           0.163715
# 2                                          -2.594135
# 3                                           0.100716
# 4                                          -0.064711
#
#    Mz__weld__fft_coefficient__attr_"abs"__coeff_58
# 0                                         0.104113
# 1                                         0.052008
# 2                                         0.540846
# 3                                         0.194849
# 4                                         1.326479
#
# [5 rows x 32 columns]
#    stress_value_center
# 0            -1.088213
# 1             0.678466
# 2            -0.499320
# 3            -0.057650
# 4            -0.646543

# %%
# Analyze model summary (all predictors)
X = sm.add_constant(df_X_train)
model = sm.OLS(df_Y_train, X).fit()

# Get and print model summary
model_summary = model.summary()
print(model_summary)

# Get p-values and sort features by significance
df_table = model.summary2().tables[1]
df_table = df_table.sort_values(by="P>|t|", ascending=True)
display(df_table)
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stress_value_center   R-squared:                       0.450
# Model:                             OLS   Adj. R-squared:                  0.399
# Method:                  Least Squares   F-statistic:                     8.811
# Date:                 Thu, 29 Jan 2026   Prob (F-statistic):           6.61e-29
# Time:                         14:07:58   Log-Likelihood:                -423.46
# No. Observations:                  378   AIC:                             912.9
# Df Residuals:                      345   BIC:                             1043.
# Df Model:                           32
# Covariance Type:             nonrobust
# =========================================================================================================================================
#                                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                   2.74e-15      0.040   6.86e-14      1.000      -0.079       0.079
# position                                                                 -0.8022      0.093     -8.606      0.000      -0.986      -0.619
# R                                                                        -0.1059      0.090     -1.177      0.240      -0.283       0.071
# W                                                                         0.0705      0.053      1.337      0.182      -0.033       0.174
# D                                                                        -0.0115      0.063     -0.184      0.854      -0.135       0.112
# Fx_location                                                               0.1284      0.069      1.864      0.063      -0.007       0.264
# Fy_location                                                              -0.1706      0.307     -0.555      0.579      -0.775       0.434
# Fz_location                                                               0.0961      0.093      1.034      0.302      -0.087       0.279
# Mz_location                                                               2.7515      0.673      4.090      0.000       1.428       4.075
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11                          0.0738      0.074      0.993      0.322      -0.072       0.220
# Fx__dwell__quantile__q_0.7                                                0.1127      0.090      1.248      0.213      -0.065       0.290
# Fx__dwell__partial_autocorrelation__lag_6                                 0.0372      0.086      0.431      0.667      -0.132       0.207
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71                         0.0159      0.070      0.226      0.821      -0.122       0.154
# Fy__dwell__last_location_of_minimum                                      -0.0396      0.072     -0.553      0.581      -0.180       0.101
# Fy__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2     0.2014      0.422      0.477      0.633      -0.628       1.031
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4                        -0.0758      0.086     -0.878      0.381      -0.246       0.094
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68                        0.0659      0.063      1.043      0.298      -0.058       0.190
# Fz__dwell__approximate_entropy__m_2__r_0.7                                0.1328      0.101      1.314      0.190      -0.066       0.331
# Mz__dwell__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"       -0.0921      0.065     -1.409      0.160      -0.221       0.036
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62                         0.0076      0.058      0.131      0.896      -0.107       0.122
# Mz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2    -0.1734      0.403     -0.430      0.667      -0.966       0.619
# Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2      -0.0503      0.080     -0.625      0.532      -0.208       0.108
# Fx__weld__fft_coefficient__attr_"real"__coeff_31                         -0.0912      0.081     -1.131      0.259      -0.250       0.067
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58                          -0.0903      0.072     -1.246      0.214      -0.233       0.052
# Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5       -0.0958      0.077     -1.238      0.216      -0.248       0.056
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61                         -0.0047      0.078     -0.061      0.951      -0.158       0.148
# Fy__weld__fft_coefficient__attr_"real"__coeff_51                         -0.1461      0.072     -2.041      0.042      -0.287      -0.005
# Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4     0.0515      0.076      0.675      0.500      -0.099       0.202
# Fz__weld__fft_coefficient__attr_"real"__coeff_84                         -0.1042      0.068     -1.530      0.127      -0.238       0.030
# Fz__weld__ratio_beyond_r_sigma__r_1                                      -0.2886      0.088     -3.276      0.001      -0.462      -0.115
# Mz__weld__quantile__q_0.1                                                -2.5913      0.650     -3.988      0.000      -3.869      -1.313
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15                         0.1343      0.076      1.765      0.078      -0.015       0.284
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58                           0.0666      0.077      0.867      0.387      -0.084       0.218
# ==============================================================================
# Omnibus:                        2.023   Durbin-Watson:                   2.163
# Prob(Omnibus):                  0.364   Jarque-Bera (JB):                2.106
# Skew:                           0.166   Prob(JB):                        0.349
# Kurtosis:                       2.848   Cond. No.                         51.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                                            Coef.  Std.Err.  \
# position                                           -8.022147e-01  0.093220
# Mz_location                                         2.751546e+00  0.672704
# Mz__weld__quantile__q_0.1                          -2.591277e+00  0.649716
# Fz__weld__ratio_beyond_r_sigma__r_1                -2.885729e-01  0.088090
# Fy__weld__fft_coefficient__attr_"real"__coeff_51   -1.460992e-01  0.071576
# Fx_location                                         1.283855e-01  0.068893
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15   1.343185e-01  0.076104
# Fz__weld__fft_coefficient__attr_"real"__coeff_84   -1.041619e-01  0.068073
# Mz__dwell__augmented_dickey_fuller__attr_"tests... -9.205889e-02  0.065319
# W                                                   7.053395e-02  0.052750
# Fz__dwell__approximate_entropy__m_2__r_0.7          1.327518e-01  0.101031
# Fx__dwell__quantile__q_0.7                          1.126703e-01  0.090266
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58    -9.029407e-02  0.072480
# Fy__weld__energy_ratio_by_chunks__num_segments_... -9.580820e-02  0.077364
# R                                                  -1.058553e-01  0.089961
# Fx__weld__fft_coefficient__attr_"real"__coeff_31   -9.117775e-02  0.080584
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68  6.586167e-02  0.063157
# Fz_location                                         9.612967e-02  0.093010
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11    7.377108e-02  0.074314
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  -7.582764e-02  0.086397
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58     6.655337e-02  0.076790
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...  5.149338e-02  0.076313
# Fx__weld__change_quantiles__f_agg_"var"__isabs_... -5.027619e-02  0.080387
# Fy_location                                        -1.706186e-01  0.307226
# Fy__dwell__last_location_of_minimum                -3.955863e-02  0.071592
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...  2.013790e-01  0.421783
# Fx__dwell__partial_autocorrelation__lag_6           3.717674e-02  0.086233
# Mz__dwell__change_quantiles__f_agg_"mean"__isab... -1.733859e-01  0.402905
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71   1.587466e-02  0.070196
# D                                                  -1.151122e-02  0.062562
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62   7.594516e-03  0.058039
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61   -4.742312e-03  0.077901
# const                                               2.739562e-15  0.039937
#
#                                                                t  \
# position                                           -8.605567e+00
# Mz_location                                         4.090277e+00
# Mz__weld__quantile__q_0.1                          -3.988326e+00
# Fz__weld__ratio_beyond_r_sigma__r_1                -3.275894e+00
# Fy__weld__fft_coefficient__attr_"real"__coeff_51   -2.041168e+00
# Fx_location                                         1.863558e+00
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15   1.764925e+00
# Fz__weld__fft_coefficient__attr_"real"__coeff_84   -1.530139e+00
# Mz__dwell__augmented_dickey_fuller__attr_"tests... -1.409374e+00
# W                                                   1.337146e+00
# Fz__dwell__approximate_entropy__m_2__r_0.7          1.313970e+00
# Fx__dwell__quantile__q_0.7                          1.248205e+00
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58    -1.245781e+00
# Fy__weld__energy_ratio_by_chunks__num_segments_... -1.238411e+00
# R                                                  -1.176682e+00
# Fx__weld__fft_coefficient__attr_"real"__coeff_31   -1.131457e+00
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68  1.042823e+00
# Fz_location                                         1.033545e+00
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11    9.926966e-01
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  -8.776623e-01
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58     8.666957e-01
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...  6.747620e-01
# Fx__weld__change_quantiles__f_agg_"var"__isabs_... -6.254249e-01
# Fy_location                                        -5.553513e-01
# Fy__dwell__last_location_of_minimum                -5.525573e-01
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...  4.774466e-01
# Fx__dwell__partial_autocorrelation__lag_6           4.311182e-01
# Mz__dwell__change_quantiles__f_agg_"mean"__isab... -4.303392e-01
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71   2.261486e-01
# D                                                  -1.839972e-01
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62   1.308527e-01
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61   -6.087608e-02
# const                                               6.859669e-14
#
#                                                            P>|t|    [0.025  \
# position                                            2.724742e-16 -0.985567
# Mz_location                                         5.367179e-05  1.428429
# Mz__weld__quantile__q_0.1                           8.127077e-05 -3.869179
# Fz__weld__ratio_beyond_r_sigma__r_1                 1.160189e-03 -0.461834
# Fy__weld__fft_coefficient__attr_"real"__coeff_51    4.199473e-02 -0.286880
# Fx_location                                         6.323315e-02 -0.007117
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15   7.846115e-02 -0.015368
# Fz__weld__fft_coefficient__attr_"real"__coeff_84    1.268986e-01 -0.238053
# Mz__dwell__augmented_dickey_fuller__attr_"tests...  1.596253e-01 -0.220532
# W                                                   1.820560e-01 -0.033217
# Fz__dwell__approximate_entropy__m_2__r_0.7          1.897294e-01 -0.065963
# Fx__dwell__quantile__q_0.7                          2.128023e-01 -0.064870
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58     2.136903e-01 -0.232852
# Fy__weld__energy_ratio_by_chunks__num_segments_...  2.164056e-01 -0.247972
# R                                                   2.401336e-01 -0.282796
# Fx__weld__fft_coefficient__attr_"real"__coeff_31    2.586485e-01 -0.249676
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68  2.977606e-01 -0.058360
# Fz_location                                         3.020728e-01 -0.086808
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11    3.215535e-01 -0.072394
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4   3.807378e-01 -0.245759
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58     3.867111e-01 -0.084482
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...  5.002789e-01 -0.098605
# Fx__weld__change_quantiles__f_agg_"var"__isabs_...  5.321057e-01 -0.208387
# Fy_location                                         5.790143e-01 -0.774891
# Fy__dwell__last_location_of_minimum                 5.809244e-01 -0.180370
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...  6.333464e-01 -0.628211
# Fx__dwell__partial_autocorrelation__lag_6           6.666517e-01 -0.132432
# Mz__dwell__change_quantiles__f_agg_"mean"__isab...  6.672176e-01 -0.965846
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71   8.212197e-01 -0.122191
# D                                                   8.541237e-01 -0.134562
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62   8.959681e-01 -0.106560
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61    9.514931e-01 -0.157963
# const                                               1.000000e+00 -0.078551
#
#                                                       0.975]
# position                                           -0.618863
# Mz_location                                         4.074663
# Mz__weld__quantile__q_0.1                          -1.313375
# Fz__weld__ratio_beyond_r_sigma__r_1                -0.115312
# Fy__weld__fft_coefficient__attr_"real"__coeff_51   -0.005318
# Fx_location                                         0.263888
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15   0.284005
# Fz__weld__fft_coefficient__attr_"real"__coeff_84    0.029729
# Mz__dwell__augmented_dickey_fuller__attr_"tests...  0.036415
# W                                                   0.174285
# Fz__dwell__approximate_entropy__m_2__r_0.7          0.331466
# Fx__dwell__quantile__q_0.7                          0.290211
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58     0.052264
# Fy__weld__energy_ratio_by_chunks__num_segments_...  0.056356
# R                                                   0.071085
# Fx__weld__fft_coefficient__attr_"real"__coeff_31    0.067321
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68  0.190083
# Fz_location                                         0.279067
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11    0.219936
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4   0.094104
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58     0.217588
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...  0.201591
# Fx__weld__change_quantiles__f_agg_"var"__isabs_...  0.107835
# Fy_location                                         0.433654
# Fy__dwell__last_location_of_minimum                 0.101253
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...  1.030969
# Fx__dwell__partial_autocorrelation__lag_6           0.206786
# Mz__dwell__change_quantiles__f_agg_"mean"__isab...  0.619074
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71   0.153940
# D                                                   0.111540
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62   0.121749
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61    0.148478
# const                                               0.078551
