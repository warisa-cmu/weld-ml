# %%
import pandas as pd
from pathlib import Path
import os
import shutil

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = BASE_DIR.parent.parent  # Adjust as necessary to reach the project root
WORK_DIR_SOURCE = ROOT_DIR / "src" / "P07_af_all" / "T01_af_features"
WORK_DIR_DEST = ROOT_DIR / "run1" / "P01_data"
print(WORK_DIR_SOURCE)
print(WORK_DIR_DEST)
# Out:
# c:\Users\admin\Coding\research\weld-ml\src\P07_af_all\T01_af_features
# c:\Users\admin\Coding\research\weld-ml\run1\P01_data

# %%
# Copy
filenames = [
    "S01_af_features_Fx.xlsx",
    "S01_af_features_Fy.xlsx",
    "S01_af_features_Fz.xlsx",
    "S01_af_features_Mz.xlsx",
]
for filename in filenames:
    source_file = WORK_DIR_SOURCE / filename
    destination_file = WORK_DIR_DEST / filename
    shutil.copy(source_file, destination_file)
