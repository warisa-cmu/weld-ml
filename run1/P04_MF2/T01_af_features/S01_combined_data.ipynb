# %%
import itertools
import os
import re
from pathlib import Path

import pandas as pd

# %%
# Set maximum number of features to select per group
MAX_FEATURES = 2

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = (
    BASE_DIR.parent.parent.parent
)  # Adjust as necessary to reach the project root
DATA_DIR = ROOT_DIR / "run1" / "data"

# %%
rels = pd.read_excel(DATA_DIR / "S03_af_feature_relevances.xlsx")
rels
# Out:
#                                            feature      type       p_value  \
# 0        Fx__fft_coefficient__attr_"abs"__coeff_11      real  1.565675e-10
# 1                Fx__ar_coefficient__coeff_0__k_10      real  2.866412e-08
# 2                        Fx__variation_coefficient      real  1.952901e-07
# 3        Fx__fft_coefficient__attr_"abs"__coeff_51      real  5.246075e-07
# 4      Fx__fft_coefficient__attr_"angle"__coeff_75      real  1.000460e-06
# ...                                            ...       ...           ...
# 18763                     Mz__value_count__value_1  constant           NaN
# 18764                    Mz__value_count__value_-1  constant           NaN
# 18765                Mz__ratio_beyond_r_sigma__r_6  constant           NaN
# 18766                Mz__ratio_beyond_r_sigma__r_7  constant           NaN
# 18767               Mz__ratio_beyond_r_sigma__r_10  constant           NaN
#
#        relevant phase_type measure_type          stress_type
# 0          True      dwell           Fx    stress_value_5052
# 1          True      dwell           Fx    stress_value_5052
# 2          True      dwell           Fx    stress_value_5052
# 3          True      dwell           Fx    stress_value_5052
# 4          True      dwell           Fx    stress_value_5052
# ...         ...        ...          ...                  ...
# 18763     False       weld           Mz  stress_value_center
# 18764     False       weld           Mz  stress_value_center
# 18765     False       weld           Mz  stress_value_center
# 18766     False       weld           Mz  stress_value_center
# 18767     False       weld           Mz  stress_value_center
#
# [18768 rows x 7 columns]

# %%
# Filter to only relevant features
rel = rels[rels["relevant"]]
print(f"Shape of relevant features: {rel.shape}")
rel.groupby(by=["stress_type", "measure_type", "phase_type"]).size()
# Out:
# Shape of relevant features: (717, 7)
# stress_type          measure_type  phase_type
# stress_value_5052    Fx            dwell         155
#                                    weld           71
#                      Fy            dwell         159
#                                    weld           86
#                      Fz            dwell          50
#                                    weld            6
#                      Mz            dwell          93
#                                    weld           90
# stress_value_center  Fz            weld            7
# dtype: int64

# %%
def rename_feature(cur_feature_name: str, phase_type: str) -> str:
    sp = cur_feature_name.split("__")
    sp.insert(1, phase_type)
    new_feature_name = "__".join(sp)
    return new_feature_name


# cur_feature_name = 'Fx__fft_coefficient__attr_"abs"__coeff_11'
# sp = cur_feature_name.split("__")
# sp.insert(1, "weld")
# new_feature_name = "__".join(sp)
# print(new_feature_name)

# %%
phase_types = ["dwell", "weld"]
measure_types = ["Fx", "Fy", "Fz", "Mz"]
stress_types = ["stress_value_5052", "stress_value_6061", "stress_value_center"]
iter_list = list(itertools.product(phase_types, measure_types, stress_types))
df_arr = []
for phase_type, measure_type, stress_type in iter_list:
    filt1 = rels["phase_type"] == phase_type
    filt2 = rels["measure_type"] == measure_type
    filt3 = rels["stress_type"] == stress_type
    rel = rels[filt1 & filt2 & filt3].sort_values(by="p_value", ascending=True)

    rel["feature_rename"] = rel["feature"].apply(
        lambda x: rename_feature(x, phase_type)
    )

    # Select top N features
    rel_top = rel.head(MAX_FEATURES)

    df_arr.append(rel_top)

rels_selected = pd.concat(df_arr, axis=0).reset_index(drop=True)
rels_selected
# Out:
#                                               feature  type       p_value  \
# 0           Fx__fft_coefficient__attr_"abs"__coeff_11  real  1.565675e-10
# 1                   Fx__ar_coefficient__coeff_0__k_10  real  2.866412e-08
# 2                                 Fx__quantile__q_0.7  real  5.089553e-04
# 3          Fx__fft_coefficient__attr_"real"__coeff_62  real  7.296259e-04
# 4                  Fx__partial_autocorrelation__lag_6  real  8.023118e-05
# 5   Fx__change_quantiles__f_agg_"mean"__isabs_True...  real  3.438416e-04
# 6          Fy__fft_coefficient__attr_"real"__coeff_71  real  2.016897e-08
# 7           Fy__fft_coefficient__attr_"abs"__coeff_59  real  5.597517e-08
# 8                        Fy__last_location_of_minimum  real  2.455827e-05
# 9                       Fy__first_location_of_minimum  real  2.455827e-05
# 10  Fy__change_quantiles__f_agg_"mean"__isabs_True...  real  3.033195e-04
# 11                         Fy__autocorrelation__lag_3  real  3.514339e-04
# 12         Fz__fft_coefficient__attr_"angle"__coeff_4  real  1.840083e-12
# 13          Fz__fft_coefficient__attr_"real"__coeff_4  real  2.398588e-07
# 14        Fz__fft_coefficient__attr_"angle"__coeff_68  real  7.103279e-03
# 15  Fz__change_quantiles__f_agg_"mean"__isabs_True...  real  1.027448e-02
# 16                Fz__approximate_entropy__m_2__r_0.7  real  8.385676e-05
# 17                Fz__approximate_entropy__m_2__r_0.9  real  9.504191e-05
# 18  Mz__augmented_dickey_fuller__attr_"teststat"__...  real  4.459153e-11
# 19  Mz__augmented_dickey_fuller__attr_"pvalue"__au...  real  4.459153e-11
# 20         Mz__fft_coefficient__attr_"real"__coeff_62  real  3.507448e-04
# 21         Mz__fft_coefficient__attr_"real"__coeff_42  real  1.641859e-03
# 22  Mz__change_quantiles__f_agg_"mean"__isabs_True...  real  4.528558e-04
# 23  Mz__change_quantiles__f_agg_"var"__isabs_False...  real  7.580492e-04
# 24  Fx__change_quantiles__f_agg_"var"__isabs_True_...  real  7.126935e-10
# 25           Fx__fft_coefficient__attr_"abs"__coeff_5  real  2.200460e-09
# 26         Fx__fft_coefficient__attr_"real"__coeff_31  real  6.693554e-04
# 27        Fx__fft_coefficient__attr_"angle"__coeff_31  real  7.604921e-04
# 28          Fx__fft_coefficient__attr_"abs"__coeff_58  real  1.984632e-04
# 29         Fx__fft_coefficient__attr_"imag"__coeff_21  real  5.689452e-04
# 30  Fy__energy_ratio_by_chunks__num_segments_10__s...  real  1.267167e-08
# 31  Fy__change_quantiles__f_agg_"mean"__isabs_True...  real  3.179828e-07
# 32         Fy__fft_coefficient__attr_"imag"__coeff_61  real  1.696179e-04
# 33          Fy__fft_coefficient__attr_"abs"__coeff_61  real  1.692935e-03
# 34         Fy__fft_coefficient__attr_"real"__coeff_51  real  1.848164e-04
# 35                  Fy__ar_coefficient__coeff_5__k_10  real  5.723905e-04
# 36  Fz__change_quantiles__f_agg_"mean"__isabs_Fals...  real  2.891292e-07
# 37  Fz__agg_linear_trend__attr_"rvalue"__chunk_len...  real  7.167726e-07
# 38         Fz__fft_coefficient__attr_"real"__coeff_84  real  5.143383e-03
# 39         Fz__fft_coefficient__attr_"real"__coeff_85  real  6.143012e-03
# 40                      Fz__ratio_beyond_r_sigma__r_1  real  3.404616e-07
# 41                      Fz__ratio_beyond_r_sigma__r_2  real  5.798335e-06
# 42                                Mz__quantile__q_0.1  real  7.393388e-09
# 43  Mz__energy_ratio_by_chunks__num_segments_10__s...  real  8.799121e-09
# 44        Mz__fft_coefficient__attr_"angle"__coeff_15  real  1.257684e-04
# 45                       Mz__last_location_of_maximum  real  7.449105e-04
# 46          Mz__fft_coefficient__attr_"abs"__coeff_58  real  5.592435e-05
# 47          Mz__fft_coefficient__attr_"abs"__coeff_83  real  1.120336e-04
#
#     relevant phase_type measure_type          stress_type  \
# 0       True      dwell           Fx    stress_value_5052
# 1       True      dwell           Fx    stress_value_5052
# 2      False      dwell           Fx    stress_value_6061
# 3      False      dwell           Fx    stress_value_6061
# 4      False      dwell           Fx  stress_value_center
# 5      False      dwell           Fx  stress_value_center
# 6       True      dwell           Fy    stress_value_5052
# 7       True      dwell           Fy    stress_value_5052
# 8      False      dwell           Fy    stress_value_6061
# 9      False      dwell           Fy    stress_value_6061
# 10     False      dwell           Fy  stress_value_center
# 11     False      dwell           Fy  stress_value_center
# 12      True      dwell           Fz    stress_value_5052
# 13      True      dwell           Fz    stress_value_5052
# 14     False      dwell           Fz    stress_value_6061
# 15     False      dwell           Fz    stress_value_6061
# 16     False      dwell           Fz  stress_value_center
# 17     False      dwell           Fz  stress_value_center
# 18      True      dwell           Mz    stress_value_5052
# 19      True      dwell           Mz    stress_value_5052
# 20     False      dwell           Mz    stress_value_6061
# 21     False      dwell           Mz    stress_value_6061
# 22     False      dwell           Mz  stress_value_center
# 23     False      dwell           Mz  stress_value_center
# 24      True       weld           Fx    stress_value_5052
# 25      True       weld           Fx    stress_value_5052
# 26     False       weld           Fx    stress_value_6061
# 27     False       weld           Fx    stress_value_6061
# 28     False       weld           Fx  stress_value_center
# 29     False       weld           Fx  stress_value_center
# 30      True       weld           Fy    stress_value_5052
# 31      True       weld           Fy    stress_value_5052
# 32     False       weld           Fy    stress_value_6061
# 33     False       weld           Fy    stress_value_6061
# 34     False       weld           Fy  stress_value_center
# 35     False       weld           Fy  stress_value_center
# 36      True       weld           Fz    stress_value_5052
# 37      True       weld           Fz    stress_value_5052
# 38     False       weld           Fz    stress_value_6061
# 39     False       weld           Fz    stress_value_6061
# 40      True       weld           Fz  stress_value_center
# 41      True       weld           Fz  stress_value_center
# 42      True       weld           Mz    stress_value_5052
# 43      True       weld           Mz    stress_value_5052
# 44     False       weld           Mz    stress_value_6061
# 45     False       weld           Mz    stress_value_6061
# 46     False       weld           Mz  stress_value_center
# 47     False       weld           Mz  stress_value_center
#
#                                        feature_rename
# 0    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11
# 1            Fx__dwell__ar_coefficient__coeff_0__k_10
# 2                          Fx__dwell__quantile__q_0.7
# 3   Fx__dwell__fft_coefficient__attr_"real"__coeff_62
# 4           Fx__dwell__partial_autocorrelation__lag_6
# 5   Fx__dwell__change_quantiles__f_agg_"mean"__isa...
# 6   Fy__dwell__fft_coefficient__attr_"real"__coeff_71
# 7    Fy__dwell__fft_coefficient__attr_"abs"__coeff_59
# 8                 Fy__dwell__last_location_of_minimum
# 9                Fy__dwell__first_location_of_minimum
# 10  Fy__dwell__change_quantiles__f_agg_"mean"__isa...
# 11                  Fy__dwell__autocorrelation__lag_3
# 12  Fz__dwell__fft_coefficient__attr_"angle"__coeff_4
# 13   Fz__dwell__fft_coefficient__attr_"real"__coeff_4
# 14  Fz__dwell__fft_coefficient__attr_"angle"__coef...
# 15  Fz__dwell__change_quantiles__f_agg_"mean"__isa...
# 16         Fz__dwell__approximate_entropy__m_2__r_0.7
# 17         Fz__dwell__approximate_entropy__m_2__r_0.9
# 18  Mz__dwell__augmented_dickey_fuller__attr_"test...
# 19  Mz__dwell__augmented_dickey_fuller__attr_"pval...
# 20  Mz__dwell__fft_coefficient__attr_"real"__coeff_62
# 21  Mz__dwell__fft_coefficient__attr_"real"__coeff_42
# 22  Mz__dwell__change_quantiles__f_agg_"mean"__isa...
# 23  Mz__dwell__change_quantiles__f_agg_"var"__isab...
# 24  Fx__weld__change_quantiles__f_agg_"var"__isabs...
# 25     Fx__weld__fft_coefficient__attr_"abs"__coeff_5
# 26   Fx__weld__fft_coefficient__attr_"real"__coeff_31
# 27  Fx__weld__fft_coefficient__attr_"angle"__coeff_31
# 28    Fx__weld__fft_coefficient__attr_"abs"__coeff_58
# 29   Fx__weld__fft_coefficient__attr_"imag"__coeff_21
# 30  Fy__weld__energy_ratio_by_chunks__num_segments...
# 31  Fy__weld__change_quantiles__f_agg_"mean"__isab...
# 32   Fy__weld__fft_coefficient__attr_"imag"__coeff_61
# 33    Fy__weld__fft_coefficient__attr_"abs"__coeff_61
# 34   Fy__weld__fft_coefficient__attr_"real"__coeff_51
# 35            Fy__weld__ar_coefficient__coeff_5__k_10
# 36  Fz__weld__change_quantiles__f_agg_"mean"__isab...
# 37  Fz__weld__agg_linear_trend__attr_"rvalue"__chu...
# 38   Fz__weld__fft_coefficient__attr_"real"__coeff_84
# 39   Fz__weld__fft_coefficient__attr_"real"__coeff_85
# 40                Fz__weld__ratio_beyond_r_sigma__r_1
# 41                Fz__weld__ratio_beyond_r_sigma__r_2
# 42                          Mz__weld__quantile__q_0.1
# 43  Mz__weld__energy_ratio_by_chunks__num_segments...
# 44  Mz__weld__fft_coefficient__attr_"angle"__coeff_15
# 45                 Mz__weld__last_location_of_maximum
# 46    Mz__weld__fft_coefficient__attr_"abs"__coeff_58
# 47    Mz__weld__fft_coefficient__attr_"abs"__coeff_83

# %%
# Check for duplicates
filt = rels_selected.duplicated(subset=["feature", "phase_type"])
display(rels_selected[filt])

# Remove duplicates if any
rels_selected = rels_selected[~filt]
# Out:
# Empty DataFrame
# Columns: [feature, type, p_value, relevant, phase_type, measure_type, stress_type, feature_rename]
# Index: []

# %%
# Summary of relevant features selected
display(rels_selected["relevant"].value_counts())
# Out:
# relevant
# False    30
# True     18
# Name: count, dtype: int64

# %% [markdown]
# ### Only use relevant features. This is different from previous feature selection

# %%
rels_selected = rels_selected[rels_selected["relevant"]]

# %%
# Load features
_filts = os.listdir(DATA_DIR)
files = [f for f in _filts if f.startswith("S01_af_features_") and f.endswith(".xlsx")]
_load = []
for file in files:
    measure = re.match(r"S01_af_features_(\w+)\.xlsx", file).group(1)
    _load.append(dict(filename=file, measure=measure))
    print(f"Loading features for: {measure}")
load = pd.DataFrame(_load)
load
# Out:
# Loading features for: Fx
# Loading features for: Fy
# Loading features for: Fz
# Loading features for: Mz
#                   filename measure
# 0  S01_af_features_Fx.xlsx      Fx
# 1  S01_af_features_Fy.xlsx      Fy
# 2  S01_af_features_Fz.xlsx      Fz
# 3  S01_af_features_Mz.xlsx      Mz

# %%
# Load features
features_dict = {}
for idx, row in load.iterrows():
    measure = row["measure"]
    file = row["filename"]
    filepath = DATA_DIR / file
    print(f"Loading features for: {measure}, file: {file}")

    ext_dwell = pd.read_excel(
        filepath,
        sheet_name="af_dwell",
    )
    ext_weld = pd.read_excel(filepath, sheet_name="af_weld")
    # Store in dictionary
    data = {
        "dwell": ext_dwell,
        "weld": ext_weld,
    }
    features_dict[measure] = data
# Out:
# Loading features for: Fx, file: S01_af_features_Fx.xlsx
# Loading features for: Fy, file: S01_af_features_Fy.xlsx
# Loading features for: Fz, file: S01_af_features_Fz.xlsx
# Loading features for: Mz, file: S01_af_features_Mz.xlsx

# %%
_selected_features = {}
for idx, row in rels_selected.iterrows():
    phase_type = row["phase_type"]
    measure_type = row["measure_type"]
    stress_type = row["stress_type"]
    feature_name = row["feature"]
    feature_rename = row["feature_rename"]
    # print(
    #     f"Phase: {phase_type}, Measure: {measure_type}, Stress: {stress_type}, Feature: {feature_name}"
    # )
    # Extract feature values
    features_value = features_dict[measure_type][phase_type][feature_name].values
    # Store in selected features dictionary
    _selected_features[feature_rename] = features_value

# Convert to DataFrame
selected_features = pd.DataFrame(_selected_features)

# Add sample number column
selected_features.insert(
    loc=0, column="sample_no", value=features_dict["Fx"]["dwell"]["sample_no"]
)

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(dfX: pd.DataFrame, threshold=10):
    # Add constant
    dfX_const = sm.add_constant(dfX)
    # Calculate VIF for each feature
    vif = pd.DataFrame()
    vif["feature_rename"] = dfX_const.columns
    vif["VIF"] = [
        variance_inflation_factor(dfX_const.values, i)
        for i in range(dfX_const.shape[1])
    ]
    # Sort by VIF descending
    vif = vif.sort_values(by="VIF", ascending=False)
    # Remove "const"
    vif = vif[vif["feature_rename"] != "const"]
    # Identify features to drop
    vif_to_drop = vif[vif["VIF"] > threshold]
    # Create drop list
    drop_list = vif_to_drop["feature_rename"].values.tolist()
    # Drop features from original DataFrame
    dfX_dropped = dfX.drop(columns=drop_list)
    return dfX_dropped, vif, drop_list

# %% [markdown]
# ### Prototype VIF

# %%
threshold_vif = 9
target_max_vif = 5

dfX = selected_features.iloc[:, 1:]

# Initial VIF calculation
print(f"Shape of selected features before VIF: {dfX.shape}")
dfX_dropped, vif, drop_list = calculate_vif(dfX, threshold=threshold_vif)
print(f"Shape of selected features after VIF: {dfX_dropped.shape}")
display(vif)
print(drop_list)

# Second VIF calculation after dropping high VIF features
dfX = dfX_dropped.copy()
dfX_dropped, vif, drop_list = calculate_vif(dfX, threshold=threshold_vif)
print(f"Shape of selected features after VIF: {dfX_dropped.shape}")
actual_max_vif = vif["VIF"].max()
display(vif)
print(actual_max_vif)
# Out:
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF: (54, 16)
#                                        feature_rename        VIF
# 18  Mz__weld__energy_ratio_by_chunks__num_segments...  11.134191
# 17                          Mz__weld__quantile__q_0.1   9.936420
# 15                Fz__weld__ratio_beyond_r_sigma__r_1   5.433270
# 16                Fz__weld__ratio_beyond_r_sigma__r_2   5.373560
# 9   Fx__weld__change_quantiles__f_agg_"var"__isabs...   3.697028
# 2            Fx__dwell__ar_coefficient__coeff_0__k_10   3.490421
# 12  Fy__weld__change_quantiles__f_agg_"mean"__isab...   3.255932
# 14  Fz__weld__agg_linear_trend__attr_"rvalue"__chu...   2.899069
# 1    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11   2.704902
# 5   Fz__dwell__fft_coefficient__attr_"angle"__coeff_4   2.582828
# 4    Fy__dwell__fft_coefficient__attr_"abs"__coeff_59   2.427553
# 6    Fz__dwell__fft_coefficient__attr_"real"__coeff_4   2.401562
# 7   Mz__dwell__augmented_dickey_fuller__attr_"test...   2.391598
# 13  Fz__weld__change_quantiles__f_agg_"mean"__isab...   2.088304
# 8   Mz__dwell__augmented_dickey_fuller__attr_"pval...   1.935123
# 10     Fx__weld__fft_coefficient__attr_"abs"__coeff_5   1.932495
# 11  Fy__weld__energy_ratio_by_chunks__num_segments...   1.550019
# 3   Fy__dwell__fft_coefficient__attr_"real"__coeff_71   1.541615
# ['Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4', 'Mz__weld__quantile__q_0.1']
# Shape of selected features after VIF: (54, 16)
#                                        feature_rename       VIF
# 15                Fz__weld__ratio_beyond_r_sigma__r_1  5.397359
# 16                Fz__weld__ratio_beyond_r_sigma__r_2  5.349838
# 9   Fx__weld__change_quantiles__f_agg_"var"__isabs...  3.185366
# 12  Fy__weld__change_quantiles__f_agg_"mean"__isab...  3.071974
# 14  Fz__weld__agg_linear_trend__attr_"rvalue"__chu...  2.768545
# 1    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  2.679633
# 5   Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  2.563320
# 4    Fy__dwell__fft_coefficient__attr_"abs"__coeff_59  2.348972
# 6    Fz__dwell__fft_coefficient__attr_"real"__coeff_4  2.300315
# 7   Mz__dwell__augmented_dickey_fuller__attr_"test...  2.293884
# 8   Mz__dwell__augmented_dickey_fuller__attr_"pval...  1.862562
# 2            Fx__dwell__ar_coefficient__coeff_0__k_10  1.821088
# 10     Fx__weld__fft_coefficient__attr_"abs"__coeff_5  1.757870
# 13  Fz__weld__change_quantiles__f_agg_"mean"__isab...  1.647822
# 11  Fy__weld__energy_ratio_by_chunks__num_segments...  1.515839
# 3   Fy__dwell__fft_coefficient__attr_"real"__coeff_71  1.512308
# 5.397359012172896

# %%
import numpy as np

threshold_vif = 20
target_max_vif = 5
actual_max_vif = np.inf

while actual_max_vif > target_max_vif:
    threshold_vif -= 1
    dfX = selected_features.iloc[:, 1:]

    # Initial VIF calculation
    print(f"Shape of selected features before VIF: {dfX.shape}")
    dfX_dropped, vif, drop_list = calculate_vif(dfX, threshold=threshold_vif)
    print(f"Shape of selected features after VIF(1): {dfX_dropped.shape}")

    # Second VIF calculation after dropping high VIF features
    dfX = dfX_dropped.copy()
    dfX_dropped, vif, drop_list = calculate_vif(dfX, threshold=threshold_vif)
    print(f"Shape of selected features after VIF(2): {dfX_dropped.shape}")
    actual_max_vif = vif["VIF"].max()
    print(f"Current max VIF: {actual_max_vif} at threshold: {threshold_vif}")

    print("-----")
# Out:
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 19
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 18
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 17
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 16
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 15
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 14
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 13
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 18)
# Shape of selected features after VIF(2): (54, 18)
# Current max VIF: 11.134190920720416 at threshold: 12
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 17)
# Shape of selected features after VIF(2): (54, 17)
# Current max VIF: 5.403560481878954 at threshold: 11
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 17)
# Shape of selected features after VIF(2): (54, 17)
# Current max VIF: 5.403560481878954 at threshold: 10
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 16)
# Shape of selected features after VIF(2): (54, 16)
# Current max VIF: 5.397359012172896 at threshold: 9
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 16)
# Shape of selected features after VIF(2): (54, 16)
# Current max VIF: 5.397359012172896 at threshold: 8
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 16)
# Shape of selected features after VIF(2): (54, 16)
# Current max VIF: 5.397359012172896 at threshold: 7
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 16)
# Shape of selected features after VIF(2): (54, 16)
# Current max VIF: 5.397359012172896 at threshold: 6
# -----
# Shape of selected features before VIF: (54, 18)
# Shape of selected features after VIF(1): (54, 14)
# Shape of selected features after VIF(2): (54, 14)
# Current max VIF: 3.0882829260069515 at threshold: 5
# -----

# %%
display(vif)
# Out:
#                                        feature_rename       VIF
# 9   Fx__weld__change_quantiles__f_agg_"var"__isabs...  3.088283
# 12  Fy__weld__change_quantiles__f_agg_"mean"__isab...  2.987018
# 14  Fz__weld__agg_linear_trend__attr_"rvalue"__chu...  2.555362
# 1    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  2.449630
# 7   Mz__dwell__augmented_dickey_fuller__attr_"test...  2.247095
# 4    Fy__dwell__fft_coefficient__attr_"abs"__coeff_59  2.208328
# 6    Fz__dwell__fft_coefficient__attr_"real"__coeff_4  2.204094
# 5   Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  2.153670
# 8   Mz__dwell__augmented_dickey_fuller__attr_"pval...  1.848237
# 10     Fx__weld__fft_coefficient__attr_"abs"__coeff_5  1.734066
# 2            Fx__dwell__ar_coefficient__coeff_0__k_10  1.720313
# 13  Fz__weld__change_quantiles__f_agg_"mean"__isab...  1.623811
# 3   Fy__dwell__fft_coefficient__attr_"real"__coeff_71  1.405891
# 11  Fy__weld__energy_ratio_by_chunks__num_segments...  1.331486

# %%
rels_selected_vif = vif.merge(
    rels_selected,
    left_on="feature_rename",
    right_on="feature_rename",
    how="left",
    suffixes=("", "_y"),
)
rels_selected_vif = rels_selected_vif.drop(
    columns=[c for c in vif.columns if c.endswith("_y")]
)
display(rels_selected_vif)
# Out:
#                                        feature_rename       VIF  \
# 0   Fx__weld__change_quantiles__f_agg_"var"__isabs...  3.088283
# 1   Fy__weld__change_quantiles__f_agg_"mean"__isab...  2.987018
# 2   Fz__weld__agg_linear_trend__attr_"rvalue"__chu...  2.555362
# 3    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  2.449630
# 4   Mz__dwell__augmented_dickey_fuller__attr_"test...  2.247095
# 5    Fy__dwell__fft_coefficient__attr_"abs"__coeff_59  2.208328
# 6    Fz__dwell__fft_coefficient__attr_"real"__coeff_4  2.204094
# 7   Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  2.153670
# 8   Mz__dwell__augmented_dickey_fuller__attr_"pval...  1.848237
# 9      Fx__weld__fft_coefficient__attr_"abs"__coeff_5  1.734066
# 10           Fx__dwell__ar_coefficient__coeff_0__k_10  1.720313
# 11  Fz__weld__change_quantiles__f_agg_"mean"__isab...  1.623811
# 12  Fy__dwell__fft_coefficient__attr_"real"__coeff_71  1.405891
# 13  Fy__weld__energy_ratio_by_chunks__num_segments...  1.331486
#
#                                               feature  type       p_value  \
# 0   Fx__change_quantiles__f_agg_"var"__isabs_True_...  real  7.126935e-10
# 1   Fy__change_quantiles__f_agg_"mean"__isabs_True...  real  3.179828e-07
# 2   Fz__agg_linear_trend__attr_"rvalue"__chunk_len...  real  7.167726e-07
# 3           Fx__fft_coefficient__attr_"abs"__coeff_11  real  1.565675e-10
# 4   Mz__augmented_dickey_fuller__attr_"teststat"__...  real  4.459153e-11
# 5           Fy__fft_coefficient__attr_"abs"__coeff_59  real  5.597517e-08
# 6           Fz__fft_coefficient__attr_"real"__coeff_4  real  2.398588e-07
# 7          Fz__fft_coefficient__attr_"angle"__coeff_4  real  1.840083e-12
# 8   Mz__augmented_dickey_fuller__attr_"pvalue"__au...  real  4.459153e-11
# 9            Fx__fft_coefficient__attr_"abs"__coeff_5  real  2.200460e-09
# 10                  Fx__ar_coefficient__coeff_0__k_10  real  2.866412e-08
# 11  Fz__change_quantiles__f_agg_"mean"__isabs_Fals...  real  2.891292e-07
# 12         Fy__fft_coefficient__attr_"real"__coeff_71  real  2.016897e-08
# 13  Fy__energy_ratio_by_chunks__num_segments_10__s...  real  1.267167e-08
#
#     relevant phase_type measure_type        stress_type
# 0       True       weld           Fx  stress_value_5052
# 1       True       weld           Fy  stress_value_5052
# 2       True       weld           Fz  stress_value_5052
# 3       True      dwell           Fx  stress_value_5052
# 4       True      dwell           Mz  stress_value_5052
# 5       True      dwell           Fy  stress_value_5052
# 6       True      dwell           Fz  stress_value_5052
# 7       True      dwell           Fz  stress_value_5052
# 8       True      dwell           Mz  stress_value_5052
# 9       True       weld           Fx  stress_value_5052
# 10      True      dwell           Fx  stress_value_5052
# 11      True       weld           Fz  stress_value_5052
# 12      True      dwell           Fy  stress_value_5052
# 13      True       weld           Fy  stress_value_5052

# %%
cols = ["sample_no"] + rels_selected_vif["feature_rename"].tolist()
selected_features_vif = selected_features[cols]
print(f"Shape of selected features before VIF final: {selected_features.shape}")
print(f"Shape of selected features after VIF final: {selected_features_vif.shape}")
# Out:
# Shape of selected features before VIF final: (54, 19)
# Shape of selected features after VIF final: (54, 15)

# %%
# Load location info
locs = pd.read_excel(DATA_DIR / "S04_loc_values.xlsx").rename(
    columns={
        "Location": "location",
        "Fx": "Fx_location",
        "Fy": "Fy_location",
        "Fz": "Fz_location",
        "Mz": "Mz_location",
    }
)
locs = locs.drop(columns=["loc_idx", "loc_time"])
locs
# Out:
#      sample_no  location  Fx_location  Fy_location  Fz_location  Mz_location
# 0            1         1    -0.077671     0.143026     1.244326     1.873865
# 1            1         2    -0.027450     0.207481     1.625039     4.615337
# 2            1         3    -0.038704     0.272508     1.799653     5.209334
# 3            1         4    -0.023484     0.278517     1.882699     5.764727
# 4            1         5    -0.038251     0.280276     1.955412     6.097497
# ..         ...       ...          ...          ...          ...          ...
# 373         54         3    -0.079764     0.196450     1.352393     5.512565
# 374         54         4    -0.091477     0.259717     1.529089     6.898179
# 375         54         5    -0.068128     0.241906     1.657737     7.940597
# 376         54         6    -0.066880     0.261006     1.712860     8.849661
# 377         54         7    -0.059665     0.232186     1.877377     9.613127
#
# [378 rows x 6 columns]

# %%
# Load combined data
combined1 = pd.read_excel(DATA_DIR / "S02_data_exp.xlsx")
display(combined1)
# Out:
#      sample_no  location  position     R   W   D  stress_value_5052  \
# 0            1         1  0.153846  1400  60  10               28.0
# 1            2         1  0.153846  1400  60  15               14.0
# 2            3         1  0.153846  1400  60  20               10.0
# 3            4         1  0.153846  1400  70  10               10.0
# 4            5         1  0.153846  1400  70  15                6.0
# ..         ...       ...       ...   ...  ..  ..                ...
# 373         50         7  0.846154  1600  70  15                4.0
# 374         51         7  0.846154  1600  70  20                0.0
# 375         52         7  0.846154  1600  80  10               -2.0
# 376         53         7  0.846154  1600  80  15               10.0
# 377         54         7  0.846154  1600  80  20               15.0
#
#      stress_value_6061  stress_value_center
# 0                 51.0                 12.0
# 1                -21.0                 17.0
# 2                 35.0                 12.0
# 3                -10.0                 20.0
# 4                 41.0                 14.0
# ..                 ...                  ...
# 373              -23.0                  2.0
# 374               -1.0                  2.0
# 375              -41.0                  5.0
# 376              -90.0                  1.0
# 377               10.0                  4.0
#
# [378 rows x 9 columns]

# %%
combined2 = combined1.merge(locs, on=["sample_no", "location"])
combined2
# Out:
#      sample_no  location  position     R   W   D  stress_value_5052  \
# 0            1         1  0.153846  1400  60  10               28.0
# 1            2         1  0.153846  1400  60  15               14.0
# 2            3         1  0.153846  1400  60  20               10.0
# 3            4         1  0.153846  1400  70  10               10.0
# 4            5         1  0.153846  1400  70  15                6.0
# ..         ...       ...       ...   ...  ..  ..                ...
# 373         50         7  0.846154  1600  70  15                4.0
# 374         51         7  0.846154  1600  70  20                0.0
# 375         52         7  0.846154  1600  80  10               -2.0
# 376         53         7  0.846154  1600  80  15               10.0
# 377         54         7  0.846154  1600  80  20               15.0
#
#      stress_value_6061  stress_value_center  Fx_location  Fy_location  \
# 0                 51.0                 12.0    -0.077671     0.143026
# 1                -21.0                 17.0    -0.133276     0.164254
# 2                 35.0                 12.0    -0.059639     0.269418
# 3                -10.0                 20.0    -0.051020     0.211907
# 4                 41.0                 14.0    -0.100744     0.179582
# ..                 ...                  ...          ...          ...
# 373              -23.0                  2.0    -0.084714     0.284958
# 374               -1.0                  2.0    -0.094956     0.257101
# 375              -41.0                  5.0    -0.203323     0.173404
# 376              -90.0                  1.0    -0.099644     0.266207
# 377               10.0                  4.0    -0.059665     0.232186
#
#      Fz_location  Mz_location
# 0       1.244326     1.873865
# 1       1.203367    -1.054677
# 2       1.444542     2.940728
# 3       1.601667     3.661974
# 4       1.095031    -0.016799
# ..           ...          ...
# 373     1.905742     8.950274
# 374     1.669120     9.627879
# 375     1.671576     4.696642
# 376     1.686495    10.497974
# 377     1.877377     9.613127
#
# [378 rows x 13 columns]

# %%
combined3 = combined2.merge(selected_features, on=["sample_no"])
combined3
# Out:
#      sample_no  location  position     R   W   D  stress_value_5052  \
# 0            1         1  0.153846  1400  60  10               28.0
# 1            2         1  0.153846  1400  60  15               14.0
# 2            3         1  0.153846  1400  60  20               10.0
# 3            4         1  0.153846  1400  70  10               10.0
# 4            5         1  0.153846  1400  70  15                6.0
# ..         ...       ...       ...   ...  ..  ..                ...
# 373         50         7  0.846154  1600  70  15                4.0
# 374         51         7  0.846154  1600  70  20                0.0
# 375         52         7  0.846154  1600  80  10               -2.0
# 376         53         7  0.846154  1600  80  15               10.0
# 377         54         7  0.846154  1600  80  20               15.0
#
#      stress_value_6061  stress_value_center  Fx_location  ...  \
# 0                 51.0                 12.0    -0.077671  ...
# 1                -21.0                 17.0    -0.133276  ...
# 2                 35.0                 12.0    -0.059639  ...
# 3                -10.0                 20.0    -0.051020  ...
# 4                 41.0                 14.0    -0.100744  ...
# ..                 ...                  ...          ...  ...
# 373              -23.0                  2.0    -0.084714  ...
# 374               -1.0                  2.0    -0.094956  ...
# 375              -41.0                  5.0    -0.203323  ...
# 376              -90.0                  1.0    -0.099644  ...
# 377               10.0                  4.0    -0.059665  ...
#
#      Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2  \
# 0                                             0.006729
# 1                                             0.008800
# 2                                             0.006253
# 3                                             0.008120
# 4                                             0.008490
# ..                                                 ...
# 373                                           0.005643
# 374                                           0.006474
# 375                                           0.005295
# 376                                           0.003532
# 377                                           0.003051
#
#      Fx__weld__fft_coefficient__attr_"abs"__coeff_5  \
# 0                                         60.230153
# 1                                         64.371976
# 2                                         88.143882
# 3                                         32.083086
# 4                                         56.841945
# ..                                              ...
# 373                                       83.967538
# 374                                        8.788741
# 375                                       41.193473
# 376                                       27.703044
# 377                                        3.882642
#
#      Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5  \
# 0                                             0.113272
# 1                                             0.110881
# 2                                             0.107506
# 3                                             0.108980
# 4                                             0.111608
# ..                                                 ...
# 373                                           0.108628
# 374                                           0.106932
# 375                                           0.089559
# 376                                           0.103169
# 377                                           0.097829
#
#      Fy__weld__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0  \
# 0                                             0.142512
# 1                                             0.158888
# 2                                             0.149730
# 3                                             0.140542
# 4                                             0.116390
# ..                                                 ...
# 373                                           0.144391
# 374                                           0.128832
# 375                                           0.142455
# 376                                           0.118852
# 377                                           0.127533
#
#      Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                             0.000409
# 1                                             0.000723
# 2                                             0.000582
# 3                                            -0.000489
# 4                                             0.001675
# ..                                                 ...
# 373                                           0.000259
# 374                                           0.000801
# 375                                           0.000469
# 376                                          -0.000155
# 377                                           0.000046
#
#      Fz__weld__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"  \
# 0                                            -0.446735
# 1                                            -0.401224
# 2                                            -0.611343
# 3                                            -0.472874
# 4                                            -0.344166
# ..                                                 ...
# 373                                          -0.350354
# 374                                          -0.370529
# 375                                          -0.460999
# 376                                          -0.226563
# 377                                          -0.275157
#
#      Fz__weld__ratio_beyond_r_sigma__r_1  Fz__weld__ratio_beyond_r_sigma__r_2  \
# 0                               0.278363                             0.063841
# 1                               0.204523                             0.086839
# 2                               0.172679                             0.076763
# 3                               0.146626                             0.065057
# 4                               0.284189                             0.049533
# ..                                   ...                                  ...
# 373                             0.352746                             0.051059
# 374                             0.367193                             0.024856
# 375                             0.314019                             0.047995
# 376                             0.231258                             0.072198
# 377                             0.351143                             0.053225
#
#      Mz__weld__quantile__q_0.1  \
# 0                    -6.949290
# 1                    -5.712890
# 2                    -5.951800
# 3                    -4.033597
# 4                    -7.551309
# ..                         ...
# 373                  -6.994062
# 374                  -8.050406
# 375                 -18.062500
# 376                  -4.259820
# 377                  -3.650340
#
#      Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4
# 0                                             0.034026
# 1                                             0.021547
# 2                                             0.024692
# 3                                             0.032070
# 4                                             0.018795
# ..                                                 ...
# 373                                           0.024102
# 374                                           0.019972
# 375                                           0.024198
# 376                                           0.027400
# 377                                           0.036680
#
# [378 rows x 31 columns]

# %%
combined3
# Out:
#      sample_no  location  position     R   W   D  stress_value_5052  \
# 0            1         1  0.153846  1400  60  10               28.0
# 1            2         1  0.153846  1400  60  15               14.0
# 2            3         1  0.153846  1400  60  20               10.0
# 3            4         1  0.153846  1400  70  10               10.0
# 4            5         1  0.153846  1400  70  15                6.0
# ..         ...       ...       ...   ...  ..  ..                ...
# 373         50         7  0.846154  1600  70  15                4.0
# 374         51         7  0.846154  1600  70  20                0.0
# 375         52         7  0.846154  1600  80  10               -2.0
# 376         53         7  0.846154  1600  80  15               10.0
# 377         54         7  0.846154  1600  80  20               15.0
#
#      stress_value_6061  stress_value_center  Fx_location  ...  \
# 0                 51.0                 12.0    -0.077671  ...
# 1                -21.0                 17.0    -0.133276  ...
# 2                 35.0                 12.0    -0.059639  ...
# 3                -10.0                 20.0    -0.051020  ...
# 4                 41.0                 14.0    -0.100744  ...
# ..                 ...                  ...          ...  ...
# 373              -23.0                  2.0    -0.084714  ...
# 374               -1.0                  2.0    -0.094956  ...
# 375              -41.0                  5.0    -0.203323  ...
# 376              -90.0                  1.0    -0.099644  ...
# 377               10.0                  4.0    -0.059665  ...
#
#      Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2  \
# 0                                             0.006729
# 1                                             0.008800
# 2                                             0.006253
# 3                                             0.008120
# 4                                             0.008490
# ..                                                 ...
# 373                                           0.005643
# 374                                           0.006474
# 375                                           0.005295
# 376                                           0.003532
# 377                                           0.003051
#
#      Fx__weld__fft_coefficient__attr_"abs"__coeff_5  \
# 0                                         60.230153
# 1                                         64.371976
# 2                                         88.143882
# 3                                         32.083086
# 4                                         56.841945
# ..                                              ...
# 373                                       83.967538
# 374                                        8.788741
# 375                                       41.193473
# 376                                       27.703044
# 377                                        3.882642
#
#      Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5  \
# 0                                             0.113272
# 1                                             0.110881
# 2                                             0.107506
# 3                                             0.108980
# 4                                             0.111608
# ..                                                 ...
# 373                                           0.108628
# 374                                           0.106932
# 375                                           0.089559
# 376                                           0.103169
# 377                                           0.097829
#
#      Fy__weld__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0  \
# 0                                             0.142512
# 1                                             0.158888
# 2                                             0.149730
# 3                                             0.140542
# 4                                             0.116390
# ..                                                 ...
# 373                                           0.144391
# 374                                           0.128832
# 375                                           0.142455
# 376                                           0.118852
# 377                                           0.127533
#
#      Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                             0.000409
# 1                                             0.000723
# 2                                             0.000582
# 3                                            -0.000489
# 4                                             0.001675
# ..                                                 ...
# 373                                           0.000259
# 374                                           0.000801
# 375                                           0.000469
# 376                                          -0.000155
# 377                                           0.000046
#
#      Fz__weld__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"  \
# 0                                            -0.446735
# 1                                            -0.401224
# 2                                            -0.611343
# 3                                            -0.472874
# 4                                            -0.344166
# ..                                                 ...
# 373                                          -0.350354
# 374                                          -0.370529
# 375                                          -0.460999
# 376                                          -0.226563
# 377                                          -0.275157
#
#      Fz__weld__ratio_beyond_r_sigma__r_1  Fz__weld__ratio_beyond_r_sigma__r_2  \
# 0                               0.278363                             0.063841
# 1                               0.204523                             0.086839
# 2                               0.172679                             0.076763
# 3                               0.146626                             0.065057
# 4                               0.284189                             0.049533
# ..                                   ...                                  ...
# 373                             0.352746                             0.051059
# 374                             0.367193                             0.024856
# 375                             0.314019                             0.047995
# 376                             0.231258                             0.072198
# 377                             0.351143                             0.053225
#
#      Mz__weld__quantile__q_0.1  \
# 0                    -6.949290
# 1                    -5.712890
# 2                    -5.951800
# 3                    -4.033597
# 4                    -7.551309
# ..                         ...
# 373                  -6.994062
# 374                  -8.050406
# 375                 -18.062500
# 376                  -4.259820
# 377                  -3.650340
#
#      Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4
# 0                                             0.034026
# 1                                             0.021547
# 2                                             0.024692
# 3                                             0.032070
# 4                                             0.018795
# ..                                                 ...
# 373                                           0.024102
# 374                                           0.019972
# 375                                           0.024198
# 376                                           0.027400
# 377                                           0.036680
#
# [378 rows x 31 columns]

# %%
colsG = ["sample_no", "location"]
colsY = ["stress_value_5052", "stress_value_6061", "stress_value_center"]
combined3X = combined3.drop(columns=colsG + colsY)
combined3X
# Out:
#      position     R   W   D  Fx_location  Fy_location  Fz_location  \
# 0    0.153846  1400  60  10    -0.077671     0.143026     1.244326
# 1    0.153846  1400  60  15    -0.133276     0.164254     1.203367
# 2    0.153846  1400  60  20    -0.059639     0.269418     1.444542
# 3    0.153846  1400  70  10    -0.051020     0.211907     1.601667
# 4    0.153846  1400  70  15    -0.100744     0.179582     1.095031
# ..        ...   ...  ..  ..          ...          ...          ...
# 373  0.846154  1600  70  15    -0.084714     0.284958     1.905742
# 374  0.846154  1600  70  20    -0.094956     0.257101     1.669120
# 375  0.846154  1600  80  10    -0.203323     0.173404     1.671576
# 376  0.846154  1600  80  15    -0.099644     0.266207     1.686495
# 377  0.846154  1600  80  20    -0.059665     0.232186     1.877377
#
#      Mz_location  Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  \
# 0       1.873865                                          1.910672
# 1      -1.054677                                          1.497020
# 2       2.940728                                          0.999252
# 3       3.661974                                          0.905469
# 4      -0.016799                                          8.439772
# ..           ...                                               ...
# 373     8.950274                                          3.389169
# 374     9.627879                                          1.694796
# 375     4.696642                                          1.366042
# 376    10.497974                                          0.781104
# 377     9.613127                                          2.594343
#
#      Fx__dwell__ar_coefficient__coeff_0__k_10  ...  \
# 0                                    0.007489  ...
# 1                                    0.013134  ...
# 2                                    0.009040  ...
# 3                                    0.005442  ...
# 4                                    0.005019  ...
# ..                                        ...  ...
# 373                                  0.004357  ...
# 374                                  0.001533  ...
# 375                                  0.001576  ...
# 376                                 -0.004785  ...
# 377                                 -0.001762  ...
#
#      Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2  \
# 0                                             0.006729
# 1                                             0.008800
# 2                                             0.006253
# 3                                             0.008120
# 4                                             0.008490
# ..                                                 ...
# 373                                           0.005643
# 374                                           0.006474
# 375                                           0.005295
# 376                                           0.003532
# 377                                           0.003051
#
#      Fx__weld__fft_coefficient__attr_"abs"__coeff_5  \
# 0                                         60.230153
# 1                                         64.371976
# 2                                         88.143882
# 3                                         32.083086
# 4                                         56.841945
# ..                                              ...
# 373                                       83.967538
# 374                                        8.788741
# 375                                       41.193473
# 376                                       27.703044
# 377                                        3.882642
#
#      Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5  \
# 0                                             0.113272
# 1                                             0.110881
# 2                                             0.107506
# 3                                             0.108980
# 4                                             0.111608
# ..                                                 ...
# 373                                           0.108628
# 374                                           0.106932
# 375                                           0.089559
# 376                                           0.103169
# 377                                           0.097829
#
#      Fy__weld__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0  \
# 0                                             0.142512
# 1                                             0.158888
# 2                                             0.149730
# 3                                             0.140542
# 4                                             0.116390
# ..                                                 ...
# 373                                           0.144391
# 374                                           0.128832
# 375                                           0.142455
# 376                                           0.118852
# 377                                           0.127533
#
#      Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                             0.000409
# 1                                             0.000723
# 2                                             0.000582
# 3                                            -0.000489
# 4                                             0.001675
# ..                                                 ...
# 373                                           0.000259
# 374                                           0.000801
# 375                                           0.000469
# 376                                          -0.000155
# 377                                           0.000046
#
#      Fz__weld__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"  \
# 0                                            -0.446735
# 1                                            -0.401224
# 2                                            -0.611343
# 3                                            -0.472874
# 4                                            -0.344166
# ..                                                 ...
# 373                                          -0.350354
# 374                                          -0.370529
# 375                                          -0.460999
# 376                                          -0.226563
# 377                                          -0.275157
#
#      Fz__weld__ratio_beyond_r_sigma__r_1  Fz__weld__ratio_beyond_r_sigma__r_2  \
# 0                               0.278363                             0.063841
# 1                               0.204523                             0.086839
# 2                               0.172679                             0.076763
# 3                               0.146626                             0.065057
# 4                               0.284189                             0.049533
# ..                                   ...                                  ...
# 373                             0.352746                             0.051059
# 374                             0.367193                             0.024856
# 375                             0.314019                             0.047995
# 376                             0.231258                             0.072198
# 377                             0.351143                             0.053225
#
#      Mz__weld__quantile__q_0.1  \
# 0                    -6.949290
# 1                    -5.712890
# 2                    -5.951800
# 3                    -4.033597
# 4                    -7.551309
# ..                         ...
# 373                  -6.994062
# 374                  -8.050406
# 375                 -18.062500
# 376                  -4.259820
# 377                  -3.650340
#
#      Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4
# 0                                             0.034026
# 1                                             0.021547
# 2                                             0.024692
# 3                                             0.032070
# 4                                             0.018795
# ..                                                 ...
# 373                                           0.024102
# 374                                           0.019972
# 375                                           0.024198
# 376                                           0.027400
# 377                                           0.036680
#
# [378 rows x 26 columns]

# %%
# Test VIF on combined data

threshold_vif = 20
target_max_vif = 5
actual_max_vif = np.inf

while actual_max_vif > target_max_vif:
    threshold_vif -= 1
    dfX = combined3X.copy()

    # Initial VIF calculation
    print(f"Shape of selected features before VIF: {dfX.shape}")
    dfX_dropped, vif, drop_list = calculate_vif(dfX, threshold=threshold_vif)
    print(f"Shape of selected features after VIF(1): {dfX_dropped.shape}")

    # Second VIF calculation after dropping high VIF features
    dfX = dfX_dropped.copy()
    dfX_dropped, vif, drop_list = calculate_vif(dfX, threshold=threshold_vif)
    print(f"Shape of selected features after VIF(2): {dfX_dropped.shape}")
    actual_max_vif = vif["VIF"].max()
    print(f"Current max VIF: {actual_max_vif} at threshold: {threshold_vif}")

    print("-----")
# Out:
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 23)
# Shape of selected features after VIF(2): (378, 23)
# Current max VIF: 6.22064377015975 at threshold: 19
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 23)
# Shape of selected features after VIF(2): (378, 23)
# Current max VIF: 6.22064377015975 at threshold: 18
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 17
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 16
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 15
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 14
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 13
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 12
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 11
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 10
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 9
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 8
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 22)
# Shape of selected features after VIF(2): (378, 22)
# Current max VIF: 6.190489138337215 at threshold: 7
# -----
# Shape of selected features before VIF: (378, 26)
# Shape of selected features after VIF(1): (378, 20)
# Shape of selected features after VIF(2): (378, 20)
# Current max VIF: 4.270135812362646 at threshold: 6
# -----

# %%
vif
# Out:
#                                        feature_rename       VIF
# 15  Fx__weld__change_quantiles__f_agg_"var"__isabs...  4.270136
# 6                                         Fz_location  3.331890
# 18  Fy__weld__change_quantiles__f_agg_"mean"__isab...  3.288097
# 20  Fz__weld__agg_linear_trend__attr_"rvalue"__chu...  3.287007
# 12   Fz__dwell__fft_coefficient__attr_"real"__coeff_4  2.925117
# 11  Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  2.852854
# 7    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  2.808927
# 13  Mz__dwell__augmented_dickey_fuller__attr_"test...  2.704683
# 10   Fy__dwell__fft_coefficient__attr_"abs"__coeff_59  2.376432
# 1                                            position  2.188598
# 2                                                   R  2.131096
# 14  Mz__dwell__augmented_dickey_fuller__attr_"pval...  2.126023
# 5                                         Fx_location  2.084760
# 16     Fx__weld__fft_coefficient__attr_"abs"__coeff_5  2.079376
# 19  Fz__weld__change_quantiles__f_agg_"mean"__isab...  1.912508
# 4                                                   D  1.895512
# 8            Fx__dwell__ar_coefficient__coeff_0__k_10  1.841430
# 9   Fy__dwell__fft_coefficient__attr_"real"__coeff_71  1.459012
# 17  Fy__weld__energy_ratio_by_chunks__num_segments...  1.441169
# 3                                                   W  1.367507

# %%
rels_selected_vif_2 = vif.merge(
    rels_selected,
    left_on="feature_rename",
    right_on="feature_rename",
    how="left",
    suffixes=("", "_y"),
)
rels_selected_vif_2 = rels_selected_vif_2.drop(
    columns=[c for c in vif.columns if c.endswith("_y")]
)
display(rels_selected_vif_2)
# Out:
#                                        feature_rename       VIF  \
# 0   Fx__weld__change_quantiles__f_agg_"var"__isabs...  3.088283
# 1   Fy__weld__change_quantiles__f_agg_"mean"__isab...  2.987018
# 2   Fz__weld__agg_linear_trend__attr_"rvalue"__chu...  2.555362
# 3    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  2.449630
# 4   Mz__dwell__augmented_dickey_fuller__attr_"test...  2.247095
# 5    Fy__dwell__fft_coefficient__attr_"abs"__coeff_59  2.208328
# 6    Fz__dwell__fft_coefficient__attr_"real"__coeff_4  2.204094
# 7   Fz__dwell__fft_coefficient__attr_"angle"__coeff_4  2.153670
# 8   Mz__dwell__augmented_dickey_fuller__attr_"pval...  1.848237
# 9      Fx__weld__fft_coefficient__attr_"abs"__coeff_5  1.734066
# 10           Fx__dwell__ar_coefficient__coeff_0__k_10  1.720313
# 11  Fz__weld__change_quantiles__f_agg_"mean"__isab...  1.623811
# 12  Fy__dwell__fft_coefficient__attr_"real"__coeff_71  1.405891
# 13  Fy__weld__energy_ratio_by_chunks__num_segments...  1.331486
#
#                                               feature  type       p_value  \
# 0   Fx__change_quantiles__f_agg_"var"__isabs_True_...  real  7.126935e-10
# 1   Fy__change_quantiles__f_agg_"mean"__isabs_True...  real  3.179828e-07
# 2   Fz__agg_linear_trend__attr_"rvalue"__chunk_len...  real  7.167726e-07
# 3           Fx__fft_coefficient__attr_"abs"__coeff_11  real  1.565675e-10
# 4   Mz__augmented_dickey_fuller__attr_"teststat"__...  real  4.459153e-11
# 5           Fy__fft_coefficient__attr_"abs"__coeff_59  real  5.597517e-08
# 6           Fz__fft_coefficient__attr_"real"__coeff_4  real  2.398588e-07
# 7          Fz__fft_coefficient__attr_"angle"__coeff_4  real  1.840083e-12
# 8   Mz__augmented_dickey_fuller__attr_"pvalue"__au...  real  4.459153e-11
# 9            Fx__fft_coefficient__attr_"abs"__coeff_5  real  2.200460e-09
# 10                  Fx__ar_coefficient__coeff_0__k_10  real  2.866412e-08
# 11  Fz__change_quantiles__f_agg_"mean"__isabs_Fals...  real  2.891292e-07
# 12         Fy__fft_coefficient__attr_"real"__coeff_71  real  2.016897e-08
# 13  Fy__energy_ratio_by_chunks__num_segments_10__s...  real  1.267167e-08
#
#     relevant phase_type measure_type        stress_type  \
# 0       True       weld           Fx  stress_value_5052
# 1       True       weld           Fy  stress_value_5052
# 2       True       weld           Fz  stress_value_5052
# 3       True      dwell           Fx  stress_value_5052
# 4       True      dwell           Mz  stress_value_5052
# 5       True      dwell           Fy  stress_value_5052
# 6       True      dwell           Fz  stress_value_5052
# 7       True      dwell           Fz  stress_value_5052
# 8       True      dwell           Mz  stress_value_5052
# 9       True       weld           Fx  stress_value_5052
# 10      True      dwell           Fx  stress_value_5052
# 11      True       weld           Fz  stress_value_5052
# 12      True      dwell           Fy  stress_value_5052
# 13      True       weld           Fy  stress_value_5052
#
#                                             feature_y type_y     p_value_y  \
# 0   Fx__change_quantiles__f_agg_"var"__isabs_True_...   real  7.126935e-10
# 1   Fy__change_quantiles__f_agg_"mean"__isabs_True...   real  3.179828e-07
# 2   Fz__agg_linear_trend__attr_"rvalue"__chunk_len...   real  7.167726e-07
# 3           Fx__fft_coefficient__attr_"abs"__coeff_11   real  1.565675e-10
# 4   Mz__augmented_dickey_fuller__attr_"teststat"__...   real  4.459153e-11
# 5           Fy__fft_coefficient__attr_"abs"__coeff_59   real  5.597517e-08
# 6           Fz__fft_coefficient__attr_"real"__coeff_4   real  2.398588e-07
# 7          Fz__fft_coefficient__attr_"angle"__coeff_4   real  1.840083e-12
# 8   Mz__augmented_dickey_fuller__attr_"pvalue"__au...   real  4.459153e-11
# 9            Fx__fft_coefficient__attr_"abs"__coeff_5   real  2.200460e-09
# 10                  Fx__ar_coefficient__coeff_0__k_10   real  2.866412e-08
# 11  Fz__change_quantiles__f_agg_"mean"__isabs_Fals...   real  2.891292e-07
# 12         Fy__fft_coefficient__attr_"real"__coeff_71   real  2.016897e-08
# 13  Fy__energy_ratio_by_chunks__num_segments_10__s...   real  1.267167e-08
#
#     relevant_y phase_type_y measure_type_y      stress_type_y
# 0         True         weld             Fx  stress_value_5052
# 1         True         weld             Fy  stress_value_5052
# 2         True         weld             Fz  stress_value_5052
# 3         True        dwell             Fx  stress_value_5052
# 4         True        dwell             Mz  stress_value_5052
# 5         True        dwell             Fy  stress_value_5052
# 6         True        dwell             Fz  stress_value_5052
# 7         True        dwell             Fz  stress_value_5052
# 8         True        dwell             Mz  stress_value_5052
# 9         True         weld             Fx  stress_value_5052
# 10        True        dwell             Fx  stress_value_5052
# 11        True         weld             Fz  stress_value_5052
# 12        True        dwell             Fy  stress_value_5052
# 13        True         weld             Fy  stress_value_5052

# %%
cols = colsG + vif["feature_rename"].sort_values().tolist() + colsY
combined4 = combined3[cols] 
combined4
# Out:
#      sample_no  location   D  Fx__dwell__ar_coefficient__coeff_0__k_10  \
# 0            1         1  10                                  0.007489
# 1            2         1  15                                  0.013134
# 2            3         1  20                                  0.009040
# 3            4         1  10                                  0.005442
# 4            5         1  15                                  0.005019
# ..         ...       ...  ..                                       ...
# 373         50         7  15                                  0.004357
# 374         51         7  20                                  0.001533
# 375         52         7  10                                  0.001576
# 376         53         7  15                                 -0.004785
# 377         54         7  20                                 -0.001762
#
#      Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  \
# 0                                            1.910672
# 1                                            1.497020
# 2                                            0.999252
# 3                                            0.905469
# 4                                            8.439772
# ..                                                ...
# 373                                          3.389169
# 374                                          1.694796
# 375                                          1.366042
# 376                                          0.781104
# 377                                          2.594343
#
#      Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2  \
# 0                                             0.006729
# 1                                             0.008800
# 2                                             0.006253
# 3                                             0.008120
# 4                                             0.008490
# ..                                                 ...
# 373                                           0.005643
# 374                                           0.006474
# 375                                           0.005295
# 376                                           0.003532
# 377                                           0.003051
#
#      Fx__weld__fft_coefficient__attr_"abs"__coeff_5  Fx_location  \
# 0                                         60.230153    -0.077671
# 1                                         64.371976    -0.133276
# 2                                         88.143882    -0.059639
# 3                                         32.083086    -0.051020
# 4                                         56.841945    -0.100744
# ..                                              ...          ...
# 373                                       83.967538    -0.084714
# 374                                        8.788741    -0.094956
# 375                                       41.193473    -0.203323
# 376                                       27.703044    -0.099644
# 377                                        3.882642    -0.059665
#
#      Fy__dwell__fft_coefficient__attr_"abs"__coeff_59  \
# 0                                            0.309552
# 1                                            0.436635
# 2                                            1.023505
# 3                                            1.788437
# 4                                            4.068030
# ..                                                ...
# 373                                          1.690158
# 374                                          0.798427
# 375                                          0.326939
# 376                                          0.497165
# 377                                          1.106528
#
#      Fy__dwell__fft_coefficient__attr_"real"__coeff_71  ...  \
# 0                                            -1.545507  ...
# 1                                             0.786300  ...
# 2                                             0.550453  ...
# 3                                            -0.536916  ...
# 4                                             3.543262  ...
# ..                                                 ...  ...
# 373                                          -0.026647  ...
# 374                                          -0.462940  ...
# 375                                           0.139781  ...
# 376                                          -0.344797  ...
# 377                                           0.315407  ...
#
#      Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                             0.000409
# 1                                             0.000723
# 2                                             0.000582
# 3                                            -0.000489
# 4                                             0.001675
# ..                                                 ...
# 373                                           0.000259
# 374                                           0.000801
# 375                                           0.000469
# 376                                          -0.000155
# 377                                           0.000046
#
#      Fz_location  \
# 0       1.244326
# 1       1.203367
# 2       1.444542
# 3       1.601667
# 4       1.095031
# ..           ...
# 373     1.905742
# 374     1.669120
# 375     1.671576
# 376     1.686495
# 377     1.877377
#
#      Mz__dwell__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"  \
# 0                                             0.000004
# 1                                             0.000026
# 2                                             0.008110
# 3                                             0.038451
# 4                                             0.000125
# ..                                                 ...
# 373                                           0.000025
# 374                                           0.000013
# 375                                           0.013144
# 376                                           0.351520
# 377                                           0.006967
#
#      Mz__dwell__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"     R  \
# 0                                            -5.345424                   1400
# 1                                            -4.966068                   1400
# 2                                            -3.495263                   1400
# 3                                            -2.963456                   1400
# 4                                            -4.608391                   1400
# ..                                                 ...                    ...
# 373                                          -4.975763                   1600
# 374                                          -5.111042                   1600
# 375                                          -3.340967                   1600
# 376                                          -1.859140                   1600
# 377                                          -3.542205                   1600
#
#       W  position  stress_value_5052  stress_value_6061  stress_value_center
# 0    60  0.153846               28.0               51.0                 12.0
# 1    60  0.153846               14.0              -21.0                 17.0
# 2    60  0.153846               10.0               35.0                 12.0
# 3    70  0.153846               10.0              -10.0                 20.0
# 4    70  0.153846                6.0               41.0                 14.0
# ..   ..       ...                ...                ...                  ...
# 373  70  0.846154                4.0              -23.0                  2.0
# 374  70  0.846154                0.0               -1.0                  2.0
# 375  80  0.846154               -2.0              -41.0                  5.0
# 376  80  0.846154               10.0              -90.0                  1.0
# 377  80  0.846154               15.0               10.0                  4.0
#
# [378 rows x 25 columns]

# %%
rels_selected_vif_2.to_excel("S01_af_feature_list.xlsx", index=False)
combined4.to_excel("S01_combined_data.xlsx", index=False)
