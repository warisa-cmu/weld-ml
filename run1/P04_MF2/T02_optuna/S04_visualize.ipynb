# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performances.xlsx")

# %%
df
# Out:
#      random_state  test_size model      Y  MSE Train (No Val)  MSE Test  \
# 0               1        0.3   DTR    Y-1            0.797372  1.026082
# 1               1        0.3   DTR    Y-2            0.990211  0.843115
# 2               1        0.3   DTR    Y-3            0.663902  0.595727
# 3               1        0.3   DTR  Y-All            0.817162  0.821642
# 4               2        0.3   DTR    Y-1            0.710389  0.639833
# ..            ...        ...   ...    ...                 ...       ...
# 135             4        0.3  XGBR  Y-All            0.621316  0.764811
# 136             5        0.3  XGBR    Y-1            0.480041  0.962132
# 137             5        0.3  XGBR    Y-2            0.746258  0.837939
# 138             5        0.3  XGBR    Y-3            0.464968  0.551687
# 139             5        0.3  XGBR  Y-All            0.563756  0.783920
#
#      MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0               1.606550   1.585984           0.202628  0.197331
# 1               1.124610   1.411830           0.009789 -0.028159
# 2               1.437843   1.444925           0.336098  0.301604
# 3               1.389667   1.480913           0.182838  0.156925
# 4               1.967820   2.029980           0.289611  0.266677
# ..                   ...        ...                ...       ...
# 135             1.503229   1.667758           0.378684  0.229886
# 136            38.616488   1.413767           0.519959  0.174984
# 137             1.205986   2.286590           0.253742 -0.094462
# 138             1.139634   1.078026           0.535032  0.419558
# 139            13.654036   1.592794           0.436244  0.166693
#
# [140 rows x 10 columns]

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
