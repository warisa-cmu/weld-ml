# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performances.xlsx")

# %%
df
# Out:
#      random_state  test_size model      Y  MSE Train (No Val)  MSE Test  \
# 0               1        0.3   DTR    Y-1            0.825568  1.161215
# 1               1        0.3   DTR    Y-2            0.975725  0.896896
# 2               1        0.3   DTR    Y-3            0.657763  0.514228
# 3               1        0.3   DTR  Y-All            0.819685  0.857446
# 4               2        0.3   DTR    Y-1            0.845332  0.730911
# ..            ...        ...   ...    ...                 ...       ...
# 135             4        0.3  XGBR  Y-All            0.415410  0.754033
# 136             5        0.3  XGBR    Y-1            0.494583  0.942772
# 137             5        0.3  XGBR    Y-2            0.795212  0.857134
# 138             5        0.3  XGBR    Y-3            0.489519  0.564928
# 139             5        0.3  XGBR  Y-All            0.593105  0.788278
#
#      MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0               1.843868   1.777475           0.174432  0.091622
# 1               1.200117   2.424370           0.024275 -0.093742
# 2               1.412642   1.356773           0.342237  0.397148
# 3               1.485542   1.852873           0.180315  0.131676
# 4               2.097635   1.613134           0.154668  0.162292
# ..                   ...        ...                ...       ...
# 135             1.613107   2.214565           0.584590  0.244075
# 136            35.432208   1.360018           0.505417  0.191585
# 137             1.203867   2.448128           0.204788 -0.119533
# 138             1.201281   1.163631           0.510481  0.405627
# 139            12.612452   1.657259           0.406895  0.159227
#
# [140 rows x 10 columns]

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
