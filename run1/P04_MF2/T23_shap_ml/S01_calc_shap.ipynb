# %%
import ast
import pickle
import re
from pathlib import Path

import pandas as pd
from sklearn.preprocessing import StandardScaler

from run1.lib.classes_ml import DataHandler
from run1.lib.directory import get_directory
from run1.lib.optuna_ml import OptunaUtil
from run1.lib.shap import ShapUtil

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file
# Get data directory
directory = get_directory(CURRENT_DIR, verbose=True)
DATA_PATH = directory["DATA_PATH"]
STUDY_ML_PATH = directory["STUDY_ML_PATH"]
# Out:
# Code is running in a Jupyter environment.
# ROOT_DIR: c:\Users\admin\Coding\research\weld-ml
# DATA_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P04_MF2\T01_af_features
# DATA_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P04_MF2\T01_af_features\S01_combined_data.xlsx
# STUDY_ML_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P04_MF2\T02_optuna
# STUDY_ML_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P04_MF2\T02_optuna\S02_combine_study.xlsx
# STUDY_TABPFN_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P04_MF2\T11_tabPFN
# STUDY_TABPFN_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P04_MF2\T11_tabPFN\S01_calculate_performance.xlsx

# %%
# Load study info
study_info = pd.read_excel(STUDY_ML_PATH)
study_info["model_params"] = study_info["model_params"].apply(ast.literal_eval)

# Load experimental data
_df = pd.read_excel(DATA_PATH)
print(f"df.shape: {_df.shape}")
# Out:
# df.shape: (378, 25)

# %%
# Select columns for features and targets
colsY = [c for c in _df.columns if re.search(r"stress_value", c)]
colsX = [c for c in _df.columns if c not in ["sample_no", "location", *colsY]]

# Select feature columns based on predefined names
colsY = [c for c in colsY if c in ["stress_value_center"]]

_dfY = _df[colsY]
_dfX = _df[colsX]
print("Selected feature columns:", colsX)
print("Selected target columns:", colsY)
print(f"dfX.shape: {_dfX.shape}")
print(f"dfY.shape: {_dfY.shape}")
# Out:
# Selected feature columns: ['D', 'Fx__dwell__ar_coefficient__coeff_0__k_10', 'Fx__dwell__fft_coefficient__attr_"abs"__coeff_11', 'Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2', 'Fx__weld__fft_coefficient__attr_"abs"__coeff_5', 'Fx_location', 'Fy__dwell__fft_coefficient__attr_"abs"__coeff_59', 'Fy__dwell__fft_coefficient__attr_"real"__coeff_71', 'Fy__weld__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0', 'Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5', 'Fz__dwell__fft_coefficient__attr_"angle"__coeff_4', 'Fz__dwell__fft_coefficient__attr_"real"__coeff_4', 'Fz__weld__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"', 'Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4', 'Fz_location', 'Mz__dwell__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"', 'Mz__dwell__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"', 'R', 'W', 'position']
# Selected target columns: ['stress_value_center']
# dfX.shape: (378, 20)
# dfY.shape: (378, 1)

# %%
# %% Extract features and targets
_X = _dfX.values
_Y = _dfY.values
print(f"_X.shape: {_X.shape}")
print(f"_Y.shape: {_Y.shape}")
# Out:
# _X.shape: (378, 20)
# _Y.shape: (378, 1)

# %%
# Create DataHandler instance
data_handler = DataHandler(
    _X=_X,
    _Y=_Y,
    scalerX=StandardScaler(),
    scalerY=StandardScaler(),
    colsX=colsX,
    colsY=colsY,
)

# %%
study_info
# Out:
#                 study_name                dt model  n_trials  random_state  \
# 0    study_DTR_RS-1_TS-0_3  2026-02-03_22-53   DTR        50             1
# 1    study_DTR_RS-2_TS-0_3  2026-02-03_22-53   DTR        50             2
# 2    study_DTR_RS-3_TS-0_3  2026-02-03_22-53   DTR        50             3
# 3    study_DTR_RS-4_TS-0_3  2026-02-03_22-53   DTR        50             4
# 4    study_DTR_RS-5_TS-0_3  2026-02-03_22-53   DTR        50             5
# 5     study_EN_RS-1_TS-0_3  2026-02-03_22-53    EN        50             1
# 6     study_EN_RS-2_TS-0_3  2026-02-03_22-53    EN        50             2
# 7     study_EN_RS-3_TS-0_3  2026-02-03_22-53    EN        50             3
# 8     study_EN_RS-4_TS-0_3  2026-02-03_22-53    EN        50             4
# 9     study_EN_RS-5_TS-0_3  2026-02-03_22-53    EN        50             5
# 10   study_GBR_RS-1_TS-0_3  2026-02-03_22-53   GBR        50             1
# 11   study_GBR_RS-2_TS-0_3  2026-02-03_22-53   GBR        50             2
# 12   study_GBR_RS-3_TS-0_3  2026-02-03_22-53   GBR        50             3
# 13   study_GBR_RS-4_TS-0_3  2026-02-03_22-53   GBR        50             4
# 14   study_GBR_RS-5_TS-0_3  2026-02-03_22-53   GBR        50             5
# 15   study_KNR_RS-1_TS-0_3  2026-02-03_22-53   KNR        50             1
# 16   study_KNR_RS-2_TS-0_3  2026-02-03_22-53   KNR        50             2
# 17   study_KNR_RS-3_TS-0_3  2026-02-03_22-53   KNR        50             3
# 18   study_KNR_RS-4_TS-0_3  2026-02-03_22-53   KNR        50             4
# 19   study_KNR_RS-5_TS-0_3  2026-02-03_22-53   KNR        50             5
# 20   study_RFR_RS-1_TS-0_3  2026-02-03_22-53   RFR        50             1
# 21   study_RFR_RS-2_TS-0_3  2026-02-03_22-53   RFR        50             2
# 22   study_RFR_RS-3_TS-0_3  2026-02-03_22-53   RFR        50             3
# 23   study_RFR_RS-4_TS-0_3  2026-02-03_22-53   RFR        50             4
# 24   study_RFR_RS-5_TS-0_3  2026-02-03_22-53   RFR        50             5
# 25   study_SVR_RS-1_TS-0_3  2026-02-03_22-53   SVR        50             1
# 26   study_SVR_RS-2_TS-0_3  2026-02-03_22-53   SVR        50             2
# 27   study_SVR_RS-3_TS-0_3  2026-02-03_22-53   SVR        50             3
# 28   study_SVR_RS-4_TS-0_3  2026-02-03_22-53   SVR        50             4
# 29   study_SVR_RS-5_TS-0_3  2026-02-03_22-53   SVR        50             5
# 30  study_XGBR_RS-1_TS-0_3  2026-02-03_22-53  XGBR        50             1
# 31  study_XGBR_RS-2_TS-0_3  2026-02-03_22-53  XGBR        50             2
# 32  study_XGBR_RS-3_TS-0_3  2026-02-03_22-53  XGBR        50             3
# 33  study_XGBR_RS-4_TS-0_3  2026-02-03_22-53  XGBR        50             4
# 34  study_XGBR_RS-5_TS-0_3  2026-02-03_22-53  XGBR        50             5
#
#     test_size                                         best_param  best_value  \
# 0         0.3  {'criterion': 'squared_error', 'splitter': 'ra...   -0.139346
# 1         0.3  {'criterion': 'squared_error', 'splitter': 'ra...   -0.109533
# 2         0.3  {'criterion': 'absolute_error', 'splitter': 'r...   -0.099489
# 3         0.3  {'criterion': 'squared_error', 'splitter': 'ra...   -0.161086
# 4         0.3  {'criterion': 'friedman_mse', 'splitter': 'ran...   -0.157235
# 5         0.3  {'alpha': 0.08529802715173362, 'l1_ratio': 0.4...   -0.148314
# 6         0.3  {'alpha': 0.06571140688552143, 'l1_ratio': 0.8...   -0.139557
# 7         0.3  {'alpha': 0.09212379490393291, 'l1_ratio': 0.6...   -0.110966
# 8         0.3  {'alpha': 0.03890452034262176, 'l1_ratio': 0.8...   -0.165341
# 9         0.3  {'alpha': 0.03388469103413104, 'l1_ratio': 0.4...   -0.180867
# 10        0.3  {'n_estimators': 360, 'learning_rate': 0.00644...   -0.189288
# 11        0.3  {'n_estimators': 71, 'learning_rate': 0.036956...   -0.144946
# 12        0.3  {'n_estimators': 62, 'learning_rate': 0.030540...   -0.185349
# 13        0.3  {'n_estimators': 134, 'learning_rate': 0.02748...   -0.198749
# 14        0.3  {'n_estimators': 347, 'learning_rate': 0.01931...   -0.188974
# 15        0.3  {'n_neighbors': 21, 'weights': 'distance', 'al...   -0.117240
# 16        0.3  {'n_neighbors': 24, 'weights': 'distance', 'al...   -0.093560
# 17        0.3  {'n_neighbors': 39, 'weights': 'distance', 'al...   -0.103071
# 18        0.3  {'n_neighbors': 50, 'weights': 'distance', 'al...   -0.121293
# 19        0.3  {'n_neighbors': 36, 'weights': 'distance', 'al...   -0.123633
# 20        0.3  {'n_estimators': 172, 'max_depth': 7, 'min_sam...   -0.190946
# 21        0.3  {'n_estimators': 166, 'max_depth': 28, 'min_sa...   -0.144239
# 22        0.3  {'n_estimators': 100, 'max_depth': 57, 'min_sa...   -0.186098
# 23        0.3  {'n_estimators': 90, 'max_depth': 8, 'min_samp...   -0.178865
# 24        0.3  {'n_estimators': 60, 'max_depth': 5, 'min_samp...   -0.197709
# 25        0.3  {'kernel': 'linear', 'C': 0.006120054493321394...   -0.109329
# 26        0.3  {'kernel': 'sigmoid', 'C': 0.2415988903559071,...   -0.102142
# 27        0.3  {'kernel': 'linear', 'C': 0.005966580444372677...   -0.090839
# 28        0.3  {'kernel': 'rbf', 'C': 0.37275190587150353, 'e...   -0.130013
# 29        0.3  {'kernel': 'linear', 'C': 0.012708183589980318...   -0.154886
# 30        0.3  {'n_estimators': 154, 'max_depth': 12, 'learni...   -0.189817
# 31        0.3  {'n_estimators': 237, 'max_depth': 2, 'learnin...   -0.140271
# 32        0.3  {'n_estimators': 311, 'max_depth': 11, 'learni...   -0.185986
# 33        0.3  {'n_estimators': 230, 'max_depth': 10, 'learni...   -0.195082
# 34        0.3  {'n_estimators': 229, 'max_depth': 8, 'learnin...   -0.201031
#
#     total_trial  mse_mean   mse_std  mape_mean   mape_std   r2_mean    r2_std  \
# 0            80  0.846010  0.067927   1.451561   0.288350  0.139346  0.027745
# 1            80  0.875347  0.065682   1.887708   0.378771  0.109533  0.025279
# 2            80  0.876141  0.120888   1.817804   0.353386  0.099489  0.020083
# 3            80  0.834001  0.086591   1.901808   0.320215  0.161086  0.064964
# 4            80  0.826376  0.055954  17.544031  16.477837  0.157235  0.041788
# 5            80  0.836978  0.037242   1.474846   0.297348  0.148314  0.024760
# 6            80  0.848324  0.099716   1.619539   0.285157  0.139557  0.015875
# 7            80  0.866507  0.117218   1.477669   0.202124  0.110966  0.013944
# 8            80  0.819703  0.032863   1.677411   0.357119  0.165341  0.031745
# 9            80  0.800976  0.019510  11.570833  10.272896  0.180867  0.015216
# 10           80  0.797301  0.047907   1.722424   0.554368  0.189288  0.022052
# 11           80  0.844064  0.102059   1.758178   0.333370  0.144946  0.040886
# 12           80  0.790586  0.091764   1.492380   0.248741  0.185349  0.023523
# 13           80  0.789098  0.059153   1.873684   0.394312  0.198749  0.045296
# 14           80  0.791589  0.029516  18.630571  28.043380  0.188974  0.009293
# 15           80  0.867111  0.048672   1.557569   0.433473  0.117240  0.017491
# 16           80  0.893242  0.115547   1.758428   0.202085  0.093560  0.057530
# 17           80  0.876707  0.120588   1.463419   0.105695  0.103071  0.054896
# 18           80  0.869838  0.068177   1.569594   0.244679  0.121293  0.017028
# 19           80  0.863818  0.042421  18.967107  23.887208  0.123633  0.026001
# 20           80  0.795427  0.072886   1.631269   0.488150  0.190946  0.049066
# 21           80  0.844227  0.108063   1.832807   0.335130  0.144239  0.034814
# 22           80  0.787087  0.085069   1.764787   0.423217  0.186098  0.024709
# 23           80  0.806919  0.058024   2.055956   0.685308  0.178865  0.051301
# 24           80  0.783847  0.029774  17.449966  22.487250  0.197709  0.031403
# 25           80  0.875623  0.057828   1.418690   0.218700  0.109329  0.029415
# 26           80  0.885138  0.102213   1.575863   0.177790  0.102142  0.029362
# 27           80  0.887841  0.109971   1.727068   0.382507  0.090839  0.016342
# 28           80  0.856882  0.042470   1.673595   0.298074  0.130013  0.022259
# 29           80  0.831516  0.042596  12.912057  13.302529  0.154886  0.031947
# 30           80  0.798113  0.071323   1.524671   0.446117  0.189817  0.038849
# 31           80  0.849400  0.114095   1.664286   0.294425  0.140271  0.042646
# 32           80  0.791160  0.100352   1.448806   0.214673  0.185986  0.022601
# 33           76  0.794789  0.067745   1.862960   0.253490  0.195082  0.038160
# 34           60  0.781947  0.014281  15.033675  21.623964  0.201031  0.022359
#
#                                          model_params
# 0   {'criterion': 'squared_error', 'splitter': 'ra...
# 1   {'criterion': 'squared_error', 'splitter': 'ra...
# 2   {'criterion': 'absolute_error', 'splitter': 'r...
# 3   {'criterion': 'squared_error', 'splitter': 'ra...
# 4   {'criterion': 'friedman_mse', 'splitter': 'ran...
# 5   {'alpha': 0.08529802715173362, 'l1_ratio': 0.4...
# 6   {'alpha': 0.06571140688552143, 'l1_ratio': 0.8...
# 7   {'alpha': 0.09212379490393291, 'l1_ratio': 0.6...
# 8   {'alpha': 0.03890452034262176, 'l1_ratio': 0.8...
# 9   {'alpha': 0.03388469103413104, 'l1_ratio': 0.4...
# 10  {'n_estimators': 360, 'learning_rate': 0.00644...
# 11  {'n_estimators': 71, 'learning_rate': 0.036956...
# 12  {'n_estimators': 62, 'learning_rate': 0.030540...
# 13  {'n_estimators': 134, 'learning_rate': 0.02748...
# 14  {'n_estimators': 347, 'learning_rate': 0.01931...
# 15  {'n_neighbors': 21, 'weights': 'distance', 'al...
# 16  {'n_neighbors': 24, 'weights': 'distance', 'al...
# 17  {'n_neighbors': 39, 'weights': 'distance', 'al...
# 18  {'n_neighbors': 50, 'weights': 'distance', 'al...
# 19  {'n_neighbors': 36, 'weights': 'distance', 'al...
# 20  {'n_estimators': 172, 'max_depth': 7, 'min_sam...
# 21  {'n_estimators': 166, 'max_depth': 28, 'min_sa...
# 22  {'n_estimators': 100, 'max_depth': 57, 'min_sa...
# 23  {'n_estimators': 90, 'max_depth': 8, 'min_samp...
# 24  {'n_estimators': 60, 'max_depth': 5, 'min_samp...
# 25  {'kernel': 'linear', 'C': 0.006120054493321394...
# 26  {'kernel': 'sigmoid', 'C': 0.2415988903559071,...
# 27  {'kernel': 'linear', 'C': 0.005966580444372677...
# 28  {'kernel': 'rbf', 'C': 0.37275190587150353, 'g...
# 29  {'kernel': 'linear', 'C': 0.012708183589980318...
# 30  {'n_estimators': 154, 'max_depth': 12, 'learni...
# 31  {'n_estimators': 237, 'max_depth': 2, 'learnin...
# 32  {'n_estimators': 311, 'max_depth': 11, 'learni...
# 33  {'n_estimators': 230, 'max_depth': 10, 'learni...
# 34  {'n_estimators': 229, 'max_depth': 8, 'learnin...

# %%
# Get the best study info for each model based on r2_mean
study_info_best = study_info.groupby("model").apply(
    lambda df: df.sort_values("r2_mean", ascending=False).head(1), include_groups=False
)
study_info_best = study_info_best.reset_index().drop(columns=["level_1"])
study_info_best
# Out:
#   model              study_name                dt  n_trials  random_state  \
# 0   DTR   study_DTR_RS-4_TS-0_3  2026-02-03_22-53        50             4
# 1    EN    study_EN_RS-5_TS-0_3  2026-02-03_22-53        50             5
# 2   GBR   study_GBR_RS-4_TS-0_3  2026-02-03_22-53        50             4
# 3   KNR   study_KNR_RS-5_TS-0_3  2026-02-03_22-53        50             5
# 4   RFR   study_RFR_RS-5_TS-0_3  2026-02-03_22-53        50             5
# 5   SVR   study_SVR_RS-5_TS-0_3  2026-02-03_22-53        50             5
# 6  XGBR  study_XGBR_RS-5_TS-0_3  2026-02-03_22-53        50             5
#
#    test_size                                         best_param  best_value  \
# 0        0.3  {'criterion': 'squared_error', 'splitter': 'ra...   -0.161086
# 1        0.3  {'alpha': 0.03388469103413104, 'l1_ratio': 0.4...   -0.180867
# 2        0.3  {'n_estimators': 134, 'learning_rate': 0.02748...   -0.198749
# 3        0.3  {'n_neighbors': 36, 'weights': 'distance', 'al...   -0.123633
# 4        0.3  {'n_estimators': 60, 'max_depth': 5, 'min_samp...   -0.197709
# 5        0.3  {'kernel': 'linear', 'C': 0.012708183589980318...   -0.154886
# 6        0.3  {'n_estimators': 229, 'max_depth': 8, 'learnin...   -0.201031
#
#    total_trial  mse_mean   mse_std  mape_mean   mape_std   r2_mean    r2_std  \
# 0           80  0.834001  0.086591   1.901808   0.320215  0.161086  0.064964
# 1           80  0.800976  0.019510  11.570833  10.272896  0.180867  0.015216
# 2           80  0.789098  0.059153   1.873684   0.394312  0.198749  0.045296
# 3           80  0.863818  0.042421  18.967107  23.887208  0.123633  0.026001
# 4           80  0.783847  0.029774  17.449966  22.487250  0.197709  0.031403
# 5           80  0.831516  0.042596  12.912057  13.302529  0.154886  0.031947
# 6           60  0.781947  0.014281  15.033675  21.623964  0.201031  0.022359
#
#                                         model_params
# 0  {'criterion': 'squared_error', 'splitter': 'ra...
# 1  {'alpha': 0.03388469103413104, 'l1_ratio': 0.4...
# 2  {'n_estimators': 134, 'learning_rate': 0.02748...
# 3  {'n_neighbors': 36, 'weights': 'distance', 'al...
# 4  {'n_estimators': 60, 'max_depth': 5, 'min_samp...
# 5  {'kernel': 'linear', 'C': 0.012708183589980318...
# 6  {'n_estimators': 229, 'max_depth': 8, 'learnin...

# %%
# filt = ~study_info_best["model"].isin(["KNR"])
# study_info_best = study_info_best[filt]
# study_info_best

# %%
import numpy as np

shaps = []
infos = []
for idx, study in study_info_best.iterrows():
    # idx = 1
    # study = study_info_best.iloc[idx]
    model = study["model"]
    model_params = study["model_params"]

    # These parameters are used so that I can recover the same StandardScaler and train-test split as in the Optuna study
    random_state = study["random_state"]
    test_size = study["test_size"]

    print(
        f"Processing study {idx + 1}/{len(study_info)}: model={model}, random_state={random_state}, test_size={test_size}"
    )
    data_handler.split_and_scale(random_state=random_state, test_size=test_size)
    df_X_train, df_Y_train = data_handler.get_train(as_dataframe=True)
    df_X_test, df_Y_test = data_handler.get_test(as_dataframe=True)

    # Combine train and test sets
    df_X_comb = pd.concat([df_X_train, df_X_test], axis=0)
    df_Y_comb = pd.concat([df_Y_train, df_Y_test], axis=0)
    reg = OptunaUtil.get_model(model_name=model, **model_params)

    # Fit the model on the combined dataset for SHAP analysis. Use the underlying estimator instead of the MultiOutputRegressor
    estimator = reg.estimator
    estimator.fit(df_X_comb, df_Y_comb.values.ravel())
    explainer = ShapUtil.get_shap_explainer(
        model_name=model, estimator=estimator, X=df_X_comb, check_additivity=True
    )
    shap_values = explainer(df_X_comb)

    # Save info
    info = dict(
        model=model,
        model_params=model_params,
        test_size=test_size,
        random_state=random_state,
    )
    infos.append(info)

    # Store SHAP values
    shaps.append(
        dict(
            **info,
            shap_values=shap_values,
        )
    )
# Out:
# Processing study 1/35: model=DTR, random_state=4, test_size=0.3
# Processing study 2/35: model=EN, random_state=5, test_size=0.3
# Processing study 3/35: model=GBR, random_state=4, test_size=0.3
# PermutationExplainer explainer: 379it [00:23,  9.10it/s]
# c:\Users\admin\Coding\research\weld-ml\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\admin\Coding\research\weld-ml\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Processing study 4/35: model=KNR, random_state=5, test_size=0.3
# PermutationExplainer explainer: 379it [01:06,  4.90it/s]
# Processing study 5/35: model=RFR, random_state=5, test_size=0.3
# PermutationExplainer explainer: 379it [00:42,  6.81it/s]
# Processing study 6/35: model=SVR, random_state=5, test_size=0.3
# PermutationExplainer explainer: 379it [00:33,  7.87it/s]
# Processing study 7/35: model=XGBR, random_state=5, test_size=0.3
# PermutationExplainer explainer: 379it [02:56,  2.03it/s]

# %%
with open("S01_shap_calc.pkl", "wb") as f:
    pickle.dump(dict(shaps=shaps, infos=infos), f)
