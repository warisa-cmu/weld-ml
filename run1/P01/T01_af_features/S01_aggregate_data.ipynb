# %%
import itertools
import os
import pickle
import re
from pathlib import Path

import pandas as pd

# %%
# Set maximum number of features to select per group
MAX_FEATURES = 1

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = (
    BASE_DIR.parent.parent.parent
)  # Adjust as necessary to reach the project root
DATA_DIR = ROOT_DIR / "run1" / "data"

# %%
rels = pd.read_excel(DATA_DIR / "S03_af_feature_relevances.xlsx")
rels
# Out:
#                                            feature      type       p_value  \
# 0        Fx__fft_coefficient__attr_"abs"__coeff_11      real  1.565675e-10
# 1                Fx__ar_coefficient__coeff_0__k_10      real  2.866412e-08
# 2                        Fx__variation_coefficient      real  1.952901e-07
# 3        Fx__fft_coefficient__attr_"abs"__coeff_51      real  5.246075e-07
# 4      Fx__fft_coefficient__attr_"angle"__coeff_75      real  1.000460e-06
# ...                                            ...       ...           ...
# 18763                     Mz__value_count__value_1  constant           NaN
# 18764                    Mz__value_count__value_-1  constant           NaN
# 18765                Mz__ratio_beyond_r_sigma__r_6  constant           NaN
# 18766                Mz__ratio_beyond_r_sigma__r_7  constant           NaN
# 18767               Mz__ratio_beyond_r_sigma__r_10  constant           NaN
#
#        relevant phase_type measure_type          stress_type
# 0          True      dwell           Fx    stress_value_5052
# 1          True      dwell           Fx    stress_value_5052
# 2          True      dwell           Fx    stress_value_5052
# 3          True      dwell           Fx    stress_value_5052
# 4          True      dwell           Fx    stress_value_5052
# ...         ...        ...          ...                  ...
# 18763     False       weld           Mz  stress_value_center
# 18764     False       weld           Mz  stress_value_center
# 18765     False       weld           Mz  stress_value_center
# 18766     False       weld           Mz  stress_value_center
# 18767     False       weld           Mz  stress_value_center
#
# [18768 rows x 7 columns]

# %%
# Filter to only relevant features
rel = rels[rels["relevant"]]
print(f"Shape of relevant features: {rel.shape}")
rel.groupby(by=["stress_type", "measure_type", "phase_type"]).size()
# Out:
# Shape of relevant features: (717, 7)
# stress_type          measure_type  phase_type
# stress_value_5052    Fx            dwell         155
#                                    weld           71
#                      Fy            dwell         159
#                                    weld           86
#                      Fz            dwell          50
#                                    weld            6
#                      Mz            dwell          93
#                                    weld           90
# stress_value_center  Fz            weld            7
# dtype: int64

# %%
def rename_feature(cur_feature_name: str, phase_type: str) -> str:
    sp = cur_feature_name.split("__")
    sp.insert(1, phase_type)
    new_feature_name = "__".join(sp)
    return new_feature_name


# cur_feature_name = 'Fx__fft_coefficient__attr_"abs"__coeff_11'
# sp = cur_feature_name.split("__")
# sp.insert(1, "weld")
# new_feature_name = "__".join(sp)
# print(new_feature_name)

# %%
phase_types = ["dwell", "weld"]
measure_types = ["Fx", "Fy", "Fz", "Mz"]
stress_types = ["stress_value_5052", "stress_value_6061", "stress_value_center"]
iter_list = list(itertools.product(phase_types, measure_types, stress_types))
df_arr = []
for phase_type, measure_type, stress_type in iter_list:
    filt1 = rels["phase_type"] == phase_type
    filt2 = rels["measure_type"] == measure_type
    filt3 = rels["stress_type"] == stress_type
    rel = rels[filt1 & filt2 & filt3].sort_values(by="p_value", ascending=True)

    rel["feature_rename"] = rel["feature"].apply(
        lambda x: rename_feature(x, phase_type)
    )

    # Select top N features
    rel_top = rel.head(MAX_FEATURES)

    df_arr.append(rel_top)

rels_selected = pd.concat(df_arr, axis=0).reset_index(drop=True)
rels_selected
# Out:
#                                               feature  type       p_value  \
# 0           Fx__fft_coefficient__attr_"abs"__coeff_11  real  1.565675e-10
# 1                                 Fx__quantile__q_0.7  real  5.089553e-04
# 2                  Fx__partial_autocorrelation__lag_6  real  8.023118e-05
# 3          Fy__fft_coefficient__attr_"real"__coeff_71  real  2.016897e-08
# 4                        Fy__last_location_of_minimum  real  2.455827e-05
# 5   Fy__change_quantiles__f_agg_"mean"__isabs_True...  real  3.033195e-04
# 6          Fz__fft_coefficient__attr_"angle"__coeff_4  real  1.840083e-12
# 7         Fz__fft_coefficient__attr_"angle"__coeff_68  real  7.103279e-03
# 8                 Fz__approximate_entropy__m_2__r_0.7  real  8.385676e-05
# 9   Mz__augmented_dickey_fuller__attr_"teststat"__...  real  4.459153e-11
# 10         Mz__fft_coefficient__attr_"real"__coeff_62  real  3.507448e-04
# 11  Mz__change_quantiles__f_agg_"mean"__isabs_True...  real  4.528558e-04
# 12  Fx__change_quantiles__f_agg_"var"__isabs_True_...  real  7.126935e-10
# 13         Fx__fft_coefficient__attr_"real"__coeff_31  real  6.693554e-04
# 14          Fx__fft_coefficient__attr_"abs"__coeff_58  real  1.984632e-04
# 15  Fy__energy_ratio_by_chunks__num_segments_10__s...  real  1.267167e-08
# 16         Fy__fft_coefficient__attr_"imag"__coeff_61  real  1.696179e-04
# 17         Fy__fft_coefficient__attr_"real"__coeff_51  real  1.848164e-04
# 18  Fz__change_quantiles__f_agg_"mean"__isabs_Fals...  real  2.891292e-07
# 19         Fz__fft_coefficient__attr_"real"__coeff_84  real  5.143383e-03
# 20                      Fz__ratio_beyond_r_sigma__r_1  real  3.404616e-07
# 21                                Mz__quantile__q_0.1  real  7.393388e-09
# 22        Mz__fft_coefficient__attr_"angle"__coeff_15  real  1.257684e-04
# 23          Mz__fft_coefficient__attr_"abs"__coeff_58  real  5.592435e-05
#
#     relevant phase_type measure_type          stress_type  \
# 0       True      dwell           Fx    stress_value_5052
# 1      False      dwell           Fx    stress_value_6061
# 2      False      dwell           Fx  stress_value_center
# 3       True      dwell           Fy    stress_value_5052
# 4      False      dwell           Fy    stress_value_6061
# 5      False      dwell           Fy  stress_value_center
# 6       True      dwell           Fz    stress_value_5052
# 7      False      dwell           Fz    stress_value_6061
# 8      False      dwell           Fz  stress_value_center
# 9       True      dwell           Mz    stress_value_5052
# 10     False      dwell           Mz    stress_value_6061
# 11     False      dwell           Mz  stress_value_center
# 12      True       weld           Fx    stress_value_5052
# 13     False       weld           Fx    stress_value_6061
# 14     False       weld           Fx  stress_value_center
# 15      True       weld           Fy    stress_value_5052
# 16     False       weld           Fy    stress_value_6061
# 17     False       weld           Fy  stress_value_center
# 18      True       weld           Fz    stress_value_5052
# 19     False       weld           Fz    stress_value_6061
# 20      True       weld           Fz  stress_value_center
# 21      True       weld           Mz    stress_value_5052
# 22     False       weld           Mz    stress_value_6061
# 23     False       weld           Mz  stress_value_center
#
#                                        feature_rename
# 0    Fx__dwell__fft_coefficient__attr_"abs"__coeff_11
# 1                          Fx__dwell__quantile__q_0.7
# 2           Fx__dwell__partial_autocorrelation__lag_6
# 3   Fy__dwell__fft_coefficient__attr_"real"__coeff_71
# 4                 Fy__dwell__last_location_of_minimum
# 5   Fy__dwell__change_quantiles__f_agg_"mean"__isa...
# 6   Fz__dwell__fft_coefficient__attr_"angle"__coeff_4
# 7   Fz__dwell__fft_coefficient__attr_"angle"__coef...
# 8          Fz__dwell__approximate_entropy__m_2__r_0.7
# 9   Mz__dwell__augmented_dickey_fuller__attr_"test...
# 10  Mz__dwell__fft_coefficient__attr_"real"__coeff_62
# 11  Mz__dwell__change_quantiles__f_agg_"mean"__isa...
# 12  Fx__weld__change_quantiles__f_agg_"var"__isabs...
# 13   Fx__weld__fft_coefficient__attr_"real"__coeff_31
# 14    Fx__weld__fft_coefficient__attr_"abs"__coeff_58
# 15  Fy__weld__energy_ratio_by_chunks__num_segments...
# 16   Fy__weld__fft_coefficient__attr_"imag"__coeff_61
# 17   Fy__weld__fft_coefficient__attr_"real"__coeff_51
# 18  Fz__weld__change_quantiles__f_agg_"mean"__isab...
# 19   Fz__weld__fft_coefficient__attr_"real"__coeff_84
# 20                Fz__weld__ratio_beyond_r_sigma__r_1
# 21                          Mz__weld__quantile__q_0.1
# 22  Mz__weld__fft_coefficient__attr_"angle"__coeff_15
# 23    Mz__weld__fft_coefficient__attr_"abs"__coeff_58

# %%
# Check for duplicates
filt = rels_selected.duplicated(subset=["feature", "phase_type"])
display(rels_selected[filt])

# Remove duplicates if any
rels_selected = rels_selected[~filt]
# Out:
# Empty DataFrame
# Columns: [feature, type, p_value, relevant, phase_type, measure_type, stress_type, feature_rename]
# Index: []

# %%
# Summary of relevant features selected
rels_selected["relevant"].value_counts()
# Out:
# relevant
# False    15
# True      9
# Name: count, dtype: int64

# %%
# Load features
_filts = os.listdir(DATA_DIR)
files = [f for f in _filts if f.startswith("S01_af_features_") and f.endswith(".xlsx")]
_load = []
for file in files:
    measure = re.match(r"S01_af_features_(\w+)\.xlsx", file).group(1)
    _load.append(dict(filename=file, measure=measure))
    print(f"Loading features for: {measure}")
load = pd.DataFrame(_load)
load
# Out:
# Loading features for: Fx
# Loading features for: Fy
# Loading features for: Fz
# Loading features for: Mz
#                   filename measure
# 0  S01_af_features_Fx.xlsx      Fx
# 1  S01_af_features_Fy.xlsx      Fy
# 2  S01_af_features_Fz.xlsx      Fz
# 3  S01_af_features_Mz.xlsx      Mz

# %%
# Load features
features_dict = {}
for idx, row in load.iterrows():
    measure = row["measure"]
    file = row["filename"]
    filepath = DATA_DIR / file
    print(f"Loading features for: {measure}, file: {file}")

    ext_dwell = pd.read_excel(
        filepath,
        sheet_name="af_dwell",
    )
    ext_weld = pd.read_excel(filepath, sheet_name="af_weld")
    # Store in dictionary
    data = {
        "dwell": ext_dwell,
        "weld": ext_weld,
    }
    features_dict[measure] = data
# Out:
# Loading features for: Fx, file: S01_af_features_Fx.xlsx
# Loading features for: Fy, file: S01_af_features_Fy.xlsx
# Loading features for: Fz, file: S01_af_features_Fz.xlsx
# Loading features for: Mz, file: S01_af_features_Mz.xlsx

# %%
_selected_features = {}
for idx, row in rels_selected.iterrows():
    phase_type = row["phase_type"]
    measure_type = row["measure_type"]
    stress_type = row["stress_type"]
    feature_name = row["feature"]
    feature_rename = row["feature_rename"]
    # print(
    #     f"Phase: {phase_type}, Measure: {measure_type}, Stress: {stress_type}, Feature: {feature_name}"
    # )
    # Extract feature values
    features_value = features_dict[measure_type][phase_type][feature_name].values
    # Store in selected features dictionary
    _selected_features[feature_rename] = features_value

# Convert to DataFrame
selected_features = pd.DataFrame(_selected_features)

# Add sample number column
selected_features.insert(loc=0, column="sample_no", value=features_dict["Fx"]["dwell"]["sample_no"])

# %%
# Load location info
locs = pd.read_excel(DATA_DIR / "S04_loc_values.xlsx").rename(
    columns={
        "Location": "location",
        "Fx": "Fx_location",
        "Fy": "Fy_location",
        "Fz": "Fz_location",
        "Mz": "Mz_location",
    }
)
locs = locs.drop(columns=["loc_idx", "loc_time"])
locs
# Out:
#      sample_no  location  Fx_location  Fy_location  Fz_location  Mz_location
# 0            1         1    -0.077671     0.143026     1.244326     1.873865
# 1            1         2    -0.027450     0.207481     1.625039     4.615337
# 2            1         3    -0.038704     0.272508     1.799653     5.209334
# 3            1         4    -0.023484     0.278517     1.882699     5.764727
# 4            1         5    -0.038251     0.280276     1.955412     6.097497
# ..         ...       ...          ...          ...          ...          ...
# 373         54         3    -0.079764     0.196450     1.352393     5.512565
# 374         54         4    -0.091477     0.259717     1.529089     6.898179
# 375         54         5    -0.068128     0.241906     1.657737     7.940597
# 376         54         6    -0.066880     0.261006     1.712860     8.849661
# 377         54         7    -0.059665     0.232186     1.877377     9.613127
#
# [378 rows x 6 columns]

# %%
# Load combined data
combined1 = pd.read_excel(DATA_DIR / "S02_data_exp.xlsx")
display(combined1)
# Out:
#      sample_no  location  position     R   W   D  stress_value_5052  \
# 0            1         1  0.153846  1400  60  10               28.0
# 1            2         1  0.153846  1400  60  15               14.0
# 2            3         1  0.153846  1400  60  20               10.0
# 3            4         1  0.153846  1400  70  10               10.0
# 4            5         1  0.153846  1400  70  15                6.0
# ..         ...       ...       ...   ...  ..  ..                ...
# 373         50         7  0.846154  1600  70  15                4.0
# 374         51         7  0.846154  1600  70  20                0.0
# 375         52         7  0.846154  1600  80  10               -2.0
# 376         53         7  0.846154  1600  80  15               10.0
# 377         54         7  0.846154  1600  80  20               15.0
#
#      stress_value_6061  stress_value_center
# 0                 51.0                 12.0
# 1                -21.0                 17.0
# 2                 35.0                 12.0
# 3                -10.0                 20.0
# 4                 41.0                 14.0
# ..                 ...                  ...
# 373              -23.0                  2.0
# 374               -1.0                  2.0
# 375              -41.0                  5.0
# 376              -90.0                  1.0
# 377               10.0                  4.0
#
# [378 rows x 9 columns]

# %%
combined2 = combined1.merge(locs, on=["sample_no", "location"])
combined2
# Out:
#      sample_no  location  position     R   W   D  stress_value_5052  \
# 0            1         1  0.153846  1400  60  10               28.0
# 1            2         1  0.153846  1400  60  15               14.0
# 2            3         1  0.153846  1400  60  20               10.0
# 3            4         1  0.153846  1400  70  10               10.0
# 4            5         1  0.153846  1400  70  15                6.0
# ..         ...       ...       ...   ...  ..  ..                ...
# 373         50         7  0.846154  1600  70  15                4.0
# 374         51         7  0.846154  1600  70  20                0.0
# 375         52         7  0.846154  1600  80  10               -2.0
# 376         53         7  0.846154  1600  80  15               10.0
# 377         54         7  0.846154  1600  80  20               15.0
#
#      stress_value_6061  stress_value_center  Fx_location  Fy_location  \
# 0                 51.0                 12.0    -0.077671     0.143026
# 1                -21.0                 17.0    -0.133276     0.164254
# 2                 35.0                 12.0    -0.059639     0.269418
# 3                -10.0                 20.0    -0.051020     0.211907
# 4                 41.0                 14.0    -0.100744     0.179582
# ..                 ...                  ...          ...          ...
# 373              -23.0                  2.0    -0.084714     0.284958
# 374               -1.0                  2.0    -0.094956     0.257101
# 375              -41.0                  5.0    -0.203323     0.173404
# 376              -90.0                  1.0    -0.099644     0.266207
# 377               10.0                  4.0    -0.059665     0.232186
#
#      Fz_location  Mz_location
# 0       1.244326     1.873865
# 1       1.203367    -1.054677
# 2       1.444542     2.940728
# 3       1.601667     3.661974
# 4       1.095031    -0.016799
# ..           ...          ...
# 373     1.905742     8.950274
# 374     1.669120     9.627879
# 375     1.671576     4.696642
# 376     1.686495    10.497974
# 377     1.877377     9.613127
#
# [378 rows x 13 columns]

# %%
combined3 = combined2.merge(selected_features, on=["sample_no"])
combined3
# Out:
#      sample_no  location  position     R   W   D  stress_value_5052  \
# 0            1         1  0.153846  1400  60  10               28.0
# 1            2         1  0.153846  1400  60  15               14.0
# 2            3         1  0.153846  1400  60  20               10.0
# 3            4         1  0.153846  1400  70  10               10.0
# 4            5         1  0.153846  1400  70  15                6.0
# ..         ...       ...       ...   ...  ..  ..                ...
# 373         50         7  0.846154  1600  70  15                4.0
# 374         51         7  0.846154  1600  70  20                0.0
# 375         52         7  0.846154  1600  80  10               -2.0
# 376         53         7  0.846154  1600  80  15               10.0
# 377         54         7  0.846154  1600  80  20               15.0
#
#      stress_value_6061  stress_value_center  Fx_location  ...  \
# 0                 51.0                 12.0    -0.077671  ...
# 1                -21.0                 17.0    -0.133276  ...
# 2                 35.0                 12.0    -0.059639  ...
# 3                -10.0                 20.0    -0.051020  ...
# 4                 41.0                 14.0    -0.100744  ...
# ..                 ...                  ...          ...  ...
# 373              -23.0                  2.0    -0.084714  ...
# 374               -1.0                  2.0    -0.094956  ...
# 375              -41.0                  5.0    -0.203323  ...
# 376              -90.0                  1.0    -0.099644  ...
# 377               10.0                  4.0    -0.059665  ...
#
#      Fx__weld__fft_coefficient__attr_"abs"__coeff_58  \
# 0                                          18.493524
# 1                                          21.514172
# 2                                           6.610517
# 3                                           2.214507
# 4                                          13.253272
# ..                                               ...
# 373                                        20.968411
# 374                                        22.920228
# 375                                        13.516468
# 376                                         9.979603
# 377                                         2.719349
#
#      Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5  \
# 0                                             0.113272
# 1                                             0.110881
# 2                                             0.107506
# 3                                             0.108980
# 4                                             0.111608
# ..                                                 ...
# 373                                           0.108628
# 374                                           0.106932
# 375                                           0.089559
# 376                                           0.103169
# 377                                           0.097829
#
#      Fy__weld__fft_coefficient__attr_"imag"__coeff_61  \
# 0                                           -0.245535
# 1                                            5.438227
# 2                                            7.985972
# 3                                            6.712190
# 4                                            3.894138
# ..                                                ...
# 373                                         15.052543
# 374                                          1.971530
# 375                                          6.184885
# 376                                          7.514874
# 377                                          8.252573
#
#      Fy__weld__fft_coefficient__attr_"real"__coeff_51  \
# 0                                           -5.950581
# 1                                           -8.704837
# 2                                           -5.337497
# 3                                           -7.740446
# 4                                            8.372584
# ..                                                ...
# 373                                          4.172921
# 374                                          6.294789
# 375                                         -3.004381
# 376                                          1.595205
# 377                                        -12.517070
#
#      Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                             0.000409
# 1                                             0.000723
# 2                                             0.000582
# 3                                            -0.000489
# 4                                             0.001675
# ..                                                 ...
# 373                                           0.000259
# 374                                           0.000801
# 375                                           0.000469
# 376                                          -0.000155
# 377                                           0.000046
#
#      Fz__weld__fft_coefficient__attr_"real"__coeff_84  \
# 0                                           -4.184069
# 1                                            1.622507
# 2                                           -3.515585
# 3                                            1.585279
# 4                                           -6.302522
# ..                                                ...
# 373                                         -2.624641
# 374                                         -4.264308
# 375                                         -5.987022
# 376                                          4.261066
# 377                                          2.757487
#
#      Fz__weld__ratio_beyond_r_sigma__r_1  Mz__weld__quantile__q_0.1  \
# 0                               0.278363                  -6.949290
# 1                               0.204523                  -5.712890
# 2                               0.172679                  -5.951800
# 3                               0.146626                  -4.033597
# 4                               0.284189                  -7.551309
# ..                                   ...                        ...
# 373                             0.352746                  -6.994062
# 374                             0.367193                  -8.050406
# 375                             0.314019                 -18.062500
# 376                             0.231258                  -4.259820
# 377                             0.351143                  -3.650340
#
#      Mz__weld__fft_coefficient__attr_"angle"__coeff_15  \
# 0                                            93.404989
# 1                                            40.096726
# 2                                           149.473672
# 3                                            75.561565
# 4                                            85.348076
# ..                                                 ...
# 373                                          87.390014
# 374                                          65.122289
# 375                                          58.113275
# 376                                          68.126310
# 377                                          65.337141
#
#      Mz__weld__fft_coefficient__attr_"abs"__coeff_58
# 0                                         770.788243
# 1                                         358.604392
# 2                                         292.417343
# 3                                         311.972632
# 4                                         601.144018
# ..                                               ...
# 373                                       823.146921
# 374                                       979.362101
# 375                                       663.567303
# 376                                       499.039605
# 377                                       541.993149
#
# [378 rows x 37 columns]

# %%
colsY = ["stress_value_5052", "stress_value_6061", "stress_value_center"]
colsX = [c for c in combined3.columns if c not in colsY]
combined4 = combined3[colsX + colsY]
combined4
# Out:
#      sample_no  location  position     R   W   D  Fx_location  Fy_location  \
# 0            1         1  0.153846  1400  60  10    -0.077671     0.143026
# 1            2         1  0.153846  1400  60  15    -0.133276     0.164254
# 2            3         1  0.153846  1400  60  20    -0.059639     0.269418
# 3            4         1  0.153846  1400  70  10    -0.051020     0.211907
# 4            5         1  0.153846  1400  70  15    -0.100744     0.179582
# ..         ...       ...       ...   ...  ..  ..          ...          ...
# 373         50         7  0.846154  1600  70  15    -0.084714     0.284958
# 374         51         7  0.846154  1600  70  20    -0.094956     0.257101
# 375         52         7  0.846154  1600  80  10    -0.203323     0.173404
# 376         53         7  0.846154  1600  80  15    -0.099644     0.266207
# 377         54         7  0.846154  1600  80  20    -0.059665     0.232186
#
#      Fz_location  Mz_location  ...  \
# 0       1.244326     1.873865  ...
# 1       1.203367    -1.054677  ...
# 2       1.444542     2.940728  ...
# 3       1.601667     3.661974  ...
# 4       1.095031    -0.016799  ...
# ..           ...          ...  ...
# 373     1.905742     8.950274  ...
# 374     1.669120     9.627879  ...
# 375     1.671576     4.696642  ...
# 376     1.686495    10.497974  ...
# 377     1.877377     9.613127  ...
#
#      Fy__weld__fft_coefficient__attr_"real"__coeff_51  \
# 0                                           -5.950581
# 1                                           -8.704837
# 2                                           -5.337497
# 3                                           -7.740446
# 4                                            8.372584
# ..                                                ...
# 373                                          4.172921
# 374                                          6.294789
# 375                                         -3.004381
# 376                                          1.595205
# 377                                        -12.517070
#
#      Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                             0.000409
# 1                                             0.000723
# 2                                             0.000582
# 3                                            -0.000489
# 4                                             0.001675
# ..                                                 ...
# 373                                           0.000259
# 374                                           0.000801
# 375                                           0.000469
# 376                                          -0.000155
# 377                                           0.000046
#
#      Fz__weld__fft_coefficient__attr_"real"__coeff_84  \
# 0                                           -4.184069
# 1                                            1.622507
# 2                                           -3.515585
# 3                                            1.585279
# 4                                           -6.302522
# ..                                                ...
# 373                                         -2.624641
# 374                                         -4.264308
# 375                                         -5.987022
# 376                                          4.261066
# 377                                          2.757487
#
#      Fz__weld__ratio_beyond_r_sigma__r_1  Mz__weld__quantile__q_0.1  \
# 0                               0.278363                  -6.949290
# 1                               0.204523                  -5.712890
# 2                               0.172679                  -5.951800
# 3                               0.146626                  -4.033597
# 4                               0.284189                  -7.551309
# ..                                   ...                        ...
# 373                             0.352746                  -6.994062
# 374                             0.367193                  -8.050406
# 375                             0.314019                 -18.062500
# 376                             0.231258                  -4.259820
# 377                             0.351143                  -3.650340
#
#      Mz__weld__fft_coefficient__attr_"angle"__coeff_15  \
# 0                                            93.404989
# 1                                            40.096726
# 2                                           149.473672
# 3                                            75.561565
# 4                                            85.348076
# ..                                                 ...
# 373                                          87.390014
# 374                                          65.122289
# 375                                          58.113275
# 376                                          68.126310
# 377                                          65.337141
#
#      Mz__weld__fft_coefficient__attr_"abs"__coeff_58  stress_value_5052  \
# 0                                         770.788243               28.0
# 1                                         358.604392               14.0
# 2                                         292.417343               10.0
# 3                                         311.972632               10.0
# 4                                         601.144018                6.0
# ..                                               ...                ...
# 373                                       823.146921                4.0
# 374                                       979.362101                0.0
# 375                                       663.567303               -2.0
# 376                                       499.039605               10.0
# 377                                       541.993149               15.0
#
#      stress_value_6061  stress_value_center
# 0                 51.0                 12.0
# 1                -21.0                 17.0
# 2                 35.0                 12.0
# 3                -10.0                 20.0
# 4                 41.0                 14.0
# ..                 ...                  ...
# 373              -23.0                  2.0
# 374               -1.0                  2.0
# 375              -41.0                  5.0
# 376              -90.0                  1.0
# 377               10.0                  4.0
#
# [378 rows x 37 columns]

# %%
rels_selected.to_excel(f"S01_af_feature_list_MF{MAX_FEATURES}.xlsx", index=False)
combined4.to_excel(f"S01_aggregate_data_MF{MAX_FEATURES}.xlsx", index=False)
