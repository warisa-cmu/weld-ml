# %%
import ast
import pickle
import re
from pathlib import Path

import pandas as pd
from sklearn.preprocessing import StandardScaler

from run1.lib.classes_ml import DataHandler
from run1.lib.directory import get_directory
from run1.lib.optuna_ml import OptunaUtil
from run1.lib.shap import ShapUtil

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file
# Get data directory
directory = get_directory(CURRENT_DIR, verbose=True)
DATA_PATH = directory["DATA_PATH"]
STUDY_ML_PATH = directory["STUDY_ML_PATH"]
# Out:
# Code is running in a Jupyter environment.
# ROOT_DIR: c:\Users\admin\Coding\research\weld-ml
# DATA_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T01_af_features
# DATA_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T01_af_features\S01_combined_data.xlsx
# STUDY_ML_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T02_optuna
# STUDY_ML_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T02_optuna\S02_combine_study.xlsx
# STUDY_TABPFN_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T11_tabPFN
# STUDY_TABPFN_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T11_tabPFN\S01_calculate_performance.xlsx

# %%
# Load study info
study_info = pd.read_excel(STUDY_ML_PATH)
study_info["model_params"] = study_info["model_params"].apply(ast.literal_eval)

# Load experimental data
_df = pd.read_excel(DATA_PATH)
print(f"df.shape: {_df.shape}")
# Out:
# df.shape: (378, 61)

# %%
# Select columns for features and targets
colsY = [c for c in _df.columns if re.search(r"stress_value", c)]
colsX = [c for c in _df.columns if c not in ["sample_no", "location", *colsY]]

# Select feature columns based on predefined names
colsY = [c for c in colsY if c in ["stress_value_center"]]

_dfY = _df[colsY]
_dfX = _df[colsX]
print("Selected feature columns:", colsX)
print("Selected target columns:", colsY)
print(f"dfX.shape: {_dfX.shape}")
print(f"dfY.shape: {_dfY.shape}")
# Out:
# Selected feature columns: ['position', 'R', 'W', 'D', 'Fx_location', 'Fy_location', 'Fz_location', 'Mz_location', 'Fx__dwell__fft_coefficient__attr_"abs"__coeff_11', 'Fx__dwell__ar_coefficient__coeff_0__k_10', 'Fx__dwell__quantile__q_0.7', 'Fx__dwell__fft_coefficient__attr_"real"__coeff_62', 'Fx__dwell__partial_autocorrelation__lag_6', 'Fx__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Fy__dwell__fft_coefficient__attr_"real"__coeff_71', 'Fy__dwell__fft_coefficient__attr_"abs"__coeff_59', 'Fy__dwell__last_location_of_minimum', 'Fy__dwell__first_location_of_minimum', 'Fy__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Fy__dwell__autocorrelation__lag_3', 'Fz__dwell__fft_coefficient__attr_"angle"__coeff_4', 'Fz__dwell__fft_coefficient__attr_"real"__coeff_4', 'Fz__dwell__fft_coefficient__attr_"angle"__coeff_68', 'Fz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0', 'Fz__dwell__approximate_entropy__m_2__r_0.7', 'Fz__dwell__approximate_entropy__m_2__r_0.9', 'Mz__dwell__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"', 'Mz__dwell__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"', 'Mz__dwell__fft_coefficient__attr_"real"__coeff_62', 'Mz__dwell__fft_coefficient__attr_"real"__coeff_42', 'Mz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Mz__dwell__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2', 'Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2', 'Fx__weld__fft_coefficient__attr_"abs"__coeff_5', 'Fx__weld__fft_coefficient__attr_"real"__coeff_31', 'Fx__weld__fft_coefficient__attr_"angle"__coeff_31', 'Fx__weld__fft_coefficient__attr_"abs"__coeff_58', 'Fx__weld__fft_coefficient__attr_"imag"__coeff_21', 'Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5', 'Fy__weld__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0', 'Fy__weld__fft_coefficient__attr_"imag"__coeff_61', 'Fy__weld__fft_coefficient__attr_"abs"__coeff_61', 'Fy__weld__fft_coefficient__attr_"real"__coeff_51', 'Fy__weld__ar_coefficient__coeff_5__k_10', 'Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4', 'Fz__weld__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"', 'Fz__weld__fft_coefficient__attr_"real"__coeff_84', 'Fz__weld__fft_coefficient__attr_"real"__coeff_85', 'Fz__weld__ratio_beyond_r_sigma__r_1', 'Fz__weld__ratio_beyond_r_sigma__r_2', 'Mz__weld__quantile__q_0.1', 'Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4', 'Mz__weld__fft_coefficient__attr_"angle"__coeff_15', 'Mz__weld__last_location_of_maximum', 'Mz__weld__fft_coefficient__attr_"abs"__coeff_58', 'Mz__weld__fft_coefficient__attr_"abs"__coeff_83']
# Selected target columns: ['stress_value_center']
# dfX.shape: (378, 56)
# dfY.shape: (378, 1)

# %%
# %% Extract features and targets
_X = _dfX.values
_Y = _dfY.values
print(f"_X.shape: {_X.shape}")
print(f"_Y.shape: {_Y.shape}")
# Out:
# _X.shape: (378, 56)
# _Y.shape: (378, 1)

# %%
# Create DataHandler instance
data_handler = DataHandler(
    _X=_X,
    _Y=_Y,
    scalerX=StandardScaler(),
    scalerY=StandardScaler(),
    colsX=colsX,
    colsY=colsY,
)

# %%
study_info
# Out:
#                 study_name                dt model  n_trials  random_state  \
# 0    study_DTR_RS-1_TS-0_3  2026-01-29_17-14   DTR         1             1
# 1    study_DTR_RS-2_TS-0_3  2026-01-29_17-14   DTR         1             2
# 2    study_DTR_RS-3_TS-0_3  2026-01-29_17-14   DTR         1             3
# 3    study_DTR_RS-4_TS-0_3  2026-01-29_17-14   DTR         1             4
# 4    study_DTR_RS-5_TS-0_3  2026-01-29_17-14   DTR         1             5
# 5     study_EN_RS-1_TS-0_3  2026-01-29_17-14    EN         1             1
# 6     study_EN_RS-2_TS-0_3  2026-01-29_17-14    EN         1             2
# 7     study_EN_RS-3_TS-0_3  2026-01-29_17-14    EN         1             3
# 8     study_EN_RS-4_TS-0_3  2026-01-29_17-14    EN         1             4
# 9     study_EN_RS-5_TS-0_3  2026-01-29_17-14    EN         1             5
# 10   study_GBR_RS-1_TS-0_3  2026-01-29_17-14   GBR         1             1
# 11   study_GBR_RS-2_TS-0_3  2026-01-29_17-14   GBR         1             2
# 12   study_GBR_RS-3_TS-0_3  2026-01-29_17-14   GBR         1             3
# 13   study_GBR_RS-4_TS-0_3  2026-01-29_17-14   GBR         1             4
# 14   study_GBR_RS-5_TS-0_3  2026-01-29_17-14   GBR         1             5
# 15   study_KNR_RS-1_TS-0_3  2026-01-29_17-14   KNR         1             1
# 16   study_KNR_RS-2_TS-0_3  2026-01-29_17-14   KNR         1             2
# 17   study_KNR_RS-3_TS-0_3  2026-01-29_17-14   KNR         1             3
# 18   study_KNR_RS-4_TS-0_3  2026-01-29_17-14   KNR         1             4
# 19   study_KNR_RS-5_TS-0_3  2026-01-29_17-14   KNR         1             5
# 20   study_RFR_RS-1_TS-0_3  2026-01-29_17-14   RFR         1             1
# 21   study_RFR_RS-2_TS-0_3  2026-01-29_17-14   RFR         1             2
# 22   study_RFR_RS-3_TS-0_3  2026-01-29_17-14   RFR         1             3
# 23   study_RFR_RS-4_TS-0_3  2026-01-29_17-14   RFR         1             4
# 24   study_RFR_RS-5_TS-0_3  2026-01-29_17-14   RFR         1             5
# 25   study_SVR_RS-1_TS-0_3  2026-01-29_17-14   SVR         1             1
# 26   study_SVR_RS-2_TS-0_3  2026-01-29_17-14   SVR         1             2
# 27   study_SVR_RS-3_TS-0_3  2026-01-29_17-14   SVR         1             3
# 28   study_SVR_RS-4_TS-0_3  2026-01-29_17-14   SVR         1             4
# 29   study_SVR_RS-5_TS-0_3  2026-01-29_17-14   SVR         1             5
# 30  study_XGBR_RS-1_TS-0_3  2026-01-29_17-14  XGBR         1             1
# 31  study_XGBR_RS-2_TS-0_3  2026-01-29_17-14  XGBR         1             2
# 32  study_XGBR_RS-3_TS-0_3  2026-01-29_17-14  XGBR         1             3
# 33  study_XGBR_RS-4_TS-0_3  2026-01-29_17-14  XGBR         1             4
# 34  study_XGBR_RS-5_TS-0_3  2026-01-29_17-14  XGBR         1             5
#
#     test_size                                         best_param  best_value  \
# 0         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.017166
# 1         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.012265
# 2         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...    0.027131
# 3         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.022317
# 4         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.009735
# 5         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.050521
# 6         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.076614
# 7         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.071113
# 8         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.034530
# 9         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...   -0.025992
# 10        0.3  {'n_estimators': 118, 'learning_rate': 0.63512...    0.331870
# 11        0.3  {'n_estimators': 118, 'learning_rate': 0.63512...    0.500204
# 12        0.3  {'n_estimators': 118, 'learning_rate': 0.63512...    0.376003
# 13        0.3  {'n_estimators': 118, 'learning_rate': 0.63512...    0.345030
# 14        0.3  {'n_estimators': 118, 'learning_rate': 0.63512...    0.243537
# 15        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.067461
# 16        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.018484
# 17        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.020067
# 18        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.048223
# 19        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.069198
# 20        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.178945
# 21        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.140602
# 22        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.137079
# 23        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.172386
# 24        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.166814
# 25        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.014213
# 26        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.026008
# 27        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.025776
# 28        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...   -0.005248
# 29        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...   -0.003400
# 30        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.067570
# 31        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...    0.016735
# 32        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.049430
# 33        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.073026
# 34        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.083821
#
#     total_trial  mse_mean   mse_std  mape_mean   mape_std   r2_mean    r2_std  \
# 0             1  0.966295  0.048622   1.621212   0.429574  0.017166  0.006515
# 1             1  0.968677  0.108174   1.805419   0.332943  0.012265  0.071710
# 2             1  1.004886  0.115896   1.744065   0.090434 -0.027131  0.044853
# 3             1  0.962534  0.074204   1.743513   0.169511  0.022317  0.037264
# 4             1  0.968498  0.074488  19.075460  17.723960  0.009735  0.046996
# 5             1  1.032262  0.069856   1.585923   0.390798 -0.050521  0.050102
# 6             1  1.058368  0.117748   1.908094   0.271009 -0.076614  0.045717
# 7             1  1.036521  0.079935   1.912367   0.347258 -0.071113  0.071830
# 8             1  1.013405  0.041367   2.594135   1.165559 -0.034530  0.089661
# 9             1  0.959600  0.057493  12.964309  11.432652  0.025992  0.056964
# 10            1  1.303390  0.087320   2.974507   1.229477 -0.331870  0.085217
# 11            1  1.462396  0.135871   3.686679   0.851608 -0.500204  0.129820
# 12            1  1.298629  0.050211   2.953834   0.347295 -0.376003  0.211077
# 13            1  1.310914  0.091116   4.555804   2.953740 -0.345030  0.092003
# 14            1  1.205870  0.043977  40.365125  54.169215 -0.243537  0.030373
# 15            1  0.912982  0.046179   1.437208   0.294730  0.067461  0.027627
# 16            1  0.963757  0.113644   1.801189   0.192963  0.018484  0.073877
# 17            1  0.956224  0.094202   1.693706   0.347789  0.020067  0.065004
# 18            1  0.938963  0.053053   1.843492   0.425433  0.048223  0.023669
# 19            1  0.915800  0.047114  13.513571  14.246245  0.069198  0.038995
# 20            1  0.808052  0.070217   1.608309   0.453406  0.178945  0.034870
# 21            1  0.847286  0.120429   1.929773   0.248101  0.140602  0.068161
# 22            1  0.840444  0.099888   1.739597   0.454196  0.137079  0.017758
# 23            1  0.815130  0.040332   1.911148   0.387469  0.172386  0.033142
# 24            1  0.813930  0.054788  15.061332  18.340867  0.166814  0.028000
# 25            1  0.996145  0.070125   1.013824   0.019314 -0.014213  0.036298
# 26            1  1.008824  0.102388   1.169091   0.088583 -0.026008  0.036971
# 27            1  1.002635  0.121034   1.100232   0.073131 -0.025776  0.024607
# 28            1  0.987033  0.073066   1.109646   0.116544  0.005248  0.001448
# 29            1  0.983868  0.041360   2.555220   1.952416  0.003400  0.017552
# 30            1  0.915294  0.041864   2.055756   0.764003  0.067570  0.053348
# 31            1  1.000016  0.113020   2.531009   0.426431 -0.016735  0.071660
# 32            1  0.912627  0.065458   2.330175   0.369206  0.049430  0.070234
# 33            1  0.903898  0.053825   3.046883   1.231527  0.073026  0.066939
# 34            1  0.891025  0.029258  24.775407  36.735520  0.083821  0.050994
#
#                                          model_params
# 0   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 1   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 2   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 3   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 4   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 5   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 6   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 7   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 8   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 9   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 10  {'n_estimators': 118, 'learning_rate': 0.63512...
# 11  {'n_estimators': 118, 'learning_rate': 0.63512...
# 12  {'n_estimators': 118, 'learning_rate': 0.63512...
# 13  {'n_estimators': 118, 'learning_rate': 0.63512...
# 14  {'n_estimators': 118, 'learning_rate': 0.63512...
# 15  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 16  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 17  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 18  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 19  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 20  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 21  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 22  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 23  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 24  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 25  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 26  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 27  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 28  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 29  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 30  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 31  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 32  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 33  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 34  {'n_estimators': 118, 'max_depth': 12, 'learni...

# %%
# Get the best study info for each model based on r2_mean
study_info_best = study_info.groupby("model").apply(
    lambda df: df.sort_values("r2_mean", ascending=False).head(1), include_groups=False
)
study_info_best = study_info_best.reset_index().drop(columns=["level_1"])
study_info_best
# Out:
#   model              study_name                dt  n_trials  random_state  \
# 0   DTR   study_DTR_RS-4_TS-0_3  2026-01-29_17-14         1             4
# 1    EN    study_EN_RS-5_TS-0_3  2026-01-29_17-14         1             5
# 2   GBR   study_GBR_RS-5_TS-0_3  2026-01-29_17-14         1             5
# 3   KNR   study_KNR_RS-5_TS-0_3  2026-01-29_17-14         1             5
# 4   RFR   study_RFR_RS-1_TS-0_3  2026-01-29_17-14         1             1
# 5   SVR   study_SVR_RS-4_TS-0_3  2026-01-29_17-14         1             4
# 6  XGBR  study_XGBR_RS-5_TS-0_3  2026-01-29_17-14         1             5
#
#    test_size                                         best_param  best_value  \
# 0        0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.022317
# 1        0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...   -0.025992
# 2        0.3  {'n_estimators': 118, 'learning_rate': 0.63512...    0.243537
# 3        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.069198
# 4        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.178945
# 5        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...   -0.005248
# 6        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.083821
#
#    total_trial  mse_mean   mse_std  mape_mean   mape_std   r2_mean    r2_std  \
# 0            1  0.962534  0.074204   1.743513   0.169511  0.022317  0.037264
# 1            1  0.959600  0.057493  12.964309  11.432652  0.025992  0.056964
# 2            1  1.205870  0.043977  40.365125  54.169215 -0.243537  0.030373
# 3            1  0.915800  0.047114  13.513571  14.246245  0.069198  0.038995
# 4            1  0.808052  0.070217   1.608309   0.453406  0.178945  0.034870
# 5            1  0.987033  0.073066   1.109646   0.116544  0.005248  0.001448
# 6            1  0.891025  0.029258  24.775407  36.735520  0.083821  0.050994
#
#                                         model_params
# 0  {'criterion': 'friedman_mse', 'splitter': 'bes...
# 1  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 2  {'n_estimators': 118, 'learning_rate': 0.63512...
# 3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 4  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 5  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 6  {'n_estimators': 118, 'max_depth': 12, 'learni...

# %%
shaps = []
infos = []
for idx, study in study_info_best.iterrows():
    # idx = 1
    # study = study_info_best.iloc[idx]
    model = study["model"]
    model_params = study["model_params"]

    # These parameters are used so that I can recover the same StandardScaler and train-test split as in the Optuna study
    random_state = study["random_state"]
    test_size = study["test_size"]

    print(
        f"Processing study {idx + 1}/{len(study_info)}: model={model}, random_state={random_state}, test_size={test_size}"
    )
    data_handler.split_and_scale(random_state=random_state, test_size=test_size)
    df_X_train, df_Y_train = data_handler.get_train(as_dataframe=True)
    df_X_test, df_Y_test = data_handler.get_test(as_dataframe=True)

    # Combine train and test sets
    df_X_comb = pd.concat([df_X_train, df_X_test], axis=0)
    df_Y_comb = pd.concat([df_Y_train, df_Y_test], axis=0)
    reg = OptunaUtil.get_model(model_name=model, **model_params)

    # Fit the model on the combined dataset for SHAP analysis. Use the underlying estimator instead of the MultiOutputRegressor
    estimator = reg.estimator
    estimator.fit(df_X_comb, df_Y_comb.values.ravel())
    explainer = ShapUtil.get_shap_explainer(
        model_name=model, estimator=estimator, X=df_X_comb
    )
    shap_values = explainer(df_X_comb)

    # Save info
    info = dict(
        model=model,
        model_params=model_params,
        test_size=test_size,
        random_state=random_state,
    )
    infos.append(info)
    
    # Store SHAP values
    shaps.append(
        dict(
            **info,
            shap_values=shap_values,
        )
    )
# Out:
# Processing study 1/35: model=DTR, random_state=4, test_size=0.3
# Processing study 2/35: model=EN, random_state=5, test_size=0.3
# PermutationExplainer explainer: 379it [00:19, 14.48it/s]
# Processing study 3/35: model=GBR, random_state=5, test_size=0.3
# Processing study 4/35: model=KNR, random_state=5, test_size=0.3
# c:\Users\admin\Coding\research\weld-ml\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\admin\Coding\research\weld-ml\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# PermutationExplainer explainer: 379it [01:25,  3.94it/s]
# Processing study 5/35: model=RFR, random_state=1, test_size=0.3
# Processing study 6/35: model=SVR, random_state=4, test_size=0.3
# PermutationExplainer explainer: 379it [03:43,  1.56it/s]
# Processing study 7/35: model=XGBR, random_state=5, test_size=0.3

# %%
with open("S01_shap_calc.pkl", "wb") as f:
    pickle.dump(dict(shaps=shaps, infos=infos), f)
