# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file

# %%
df = pd.read_excel(CURRENT_DIR / "S01_calculate_performance.xlsx")

# %%
df
# Out:
#     random_state  test_size   model      Y       MSE      MAPE        R2
# 0              1        0.3  TabPFN    Y-1  0.937721  1.597849  0.266453
# 1              1        0.3  TabPFN    Y-2  0.799035  4.021677  0.025596
# 2              1        0.3  TabPFN    Y-3  0.436989  1.203260  0.487699
# 3              1        0.3  TabPFN  Y-All  0.724582  2.274262  0.259916
# 4              2        0.3  TabPFN    Y-1  0.618776  1.744869  0.290811
# 5              2        0.3  TabPFN    Y-2  0.888658  1.285612  0.006599
# 6              2        0.3  TabPFN    Y-3  0.531726  1.232147  0.518305
# 7              2        0.3  TabPFN  Y-All  0.679720  1.420876  0.271905
# 8              3        0.3  TabPFN    Y-1  0.926971  2.373989  0.176236
# 9              3        0.3  TabPFN    Y-2  0.838370  2.017035  0.090252
# 10             3        0.3  TabPFN    Y-3  0.377521  1.044444  0.485907
# 11             3        0.3  TabPFN  Y-All  0.714288  1.811823  0.250798
# 12             4        0.3  TabPFN    Y-1  0.707704  3.098470  0.374256
# 13             4        0.3  TabPFN    Y-2  0.904484  1.065978  0.092597
# 14             4        0.3  TabPFN    Y-3  0.475644  1.258612  0.436690
# 15             4        0.3  TabPFN  Y-All  0.695944  1.807687  0.301181
# 16             5        0.3  TabPFN    Y-1  0.945810  1.439109  0.188980
# 17             5        0.3  TabPFN    Y-2  0.862690  2.589984 -0.126790
# 18             5        0.3  TabPFN    Y-3  0.489611  1.235793  0.484870
# 19             5        0.3  TabPFN  Y-All  0.766037  1.754962  0.182353

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
sns.boxplot(df_filt, x="model", y="R2", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
