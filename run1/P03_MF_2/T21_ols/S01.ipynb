# %%
import re
from pathlib import Path

import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

from run1.lib.classes_ml import DataHandler
from run1.lib.directory import get_directory

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file
# Get data directory
directory = get_directory(CURRENT_DIR, verbose=True)
DATA_PATH = directory["DATA_PATH"]
# Out:
# Code is running in a Jupyter environment.
# ROOT_DIR: c:\Users\admin\Coding\research\weld-ml
# DATA_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T01_af_features
# DATA_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T01_af_features\S01_combined_data.xlsx
# STUDY_ML_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T02_optuna
# STUDY_ML_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T02_optuna\S02_combine_study.xlsx
# STUDY_TABPFN_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T11_tabPFN
# STUDY_TABPFN_PATH: c:\Users\admin\Coding\research\weld-ml\run1\P03_MF_2\T11_tabPFN\S01_calculate_performance.xlsx

# %%
_df = pd.read_excel(DATA_PATH)
print(f"df.shape: {_df.shape}")
# Out:
# df.shape: (378, 61)

# %%
# Select columns for features and targets
colsY = [c for c in _df.columns if re.search(r"stress_value", c)]
colsX = [c for c in _df.columns if c not in ["sample_no", "location", *colsY]]

# Select feature columns based on predefined names
colsY = [c for c in colsY if c in ["stress_value_center"]]

_dfY = _df[colsY]
_dfX = _df[colsX]
print("Selected feature columns:", colsX)
print("Selected target columns:", colsY)
print(f"dfX.shape: {_dfX.shape}")
print(f"dfY.shape: {_dfY.shape}")
# Out:
# Selected feature columns: ['position', 'R', 'W', 'D', 'Fx_location', 'Fy_location', 'Fz_location', 'Mz_location', 'Fx__dwell__fft_coefficient__attr_"abs"__coeff_11', 'Fx__dwell__ar_coefficient__coeff_0__k_10', 'Fx__dwell__quantile__q_0.7', 'Fx__dwell__fft_coefficient__attr_"real"__coeff_62', 'Fx__dwell__partial_autocorrelation__lag_6', 'Fx__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Fy__dwell__fft_coefficient__attr_"real"__coeff_71', 'Fy__dwell__fft_coefficient__attr_"abs"__coeff_59', 'Fy__dwell__last_location_of_minimum', 'Fy__dwell__first_location_of_minimum', 'Fy__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Fy__dwell__autocorrelation__lag_3', 'Fz__dwell__fft_coefficient__attr_"angle"__coeff_4', 'Fz__dwell__fft_coefficient__attr_"real"__coeff_4', 'Fz__dwell__fft_coefficient__attr_"angle"__coeff_68', 'Fz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0', 'Fz__dwell__approximate_entropy__m_2__r_0.7', 'Fz__dwell__approximate_entropy__m_2__r_0.9', 'Mz__dwell__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"', 'Mz__dwell__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"', 'Mz__dwell__fft_coefficient__attr_"real"__coeff_62', 'Mz__dwell__fft_coefficient__attr_"real"__coeff_42', 'Mz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2', 'Mz__dwell__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2', 'Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2', 'Fx__weld__fft_coefficient__attr_"abs"__coeff_5', 'Fx__weld__fft_coefficient__attr_"real"__coeff_31', 'Fx__weld__fft_coefficient__attr_"angle"__coeff_31', 'Fx__weld__fft_coefficient__attr_"abs"__coeff_58', 'Fx__weld__fft_coefficient__attr_"imag"__coeff_21', 'Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5', 'Fy__weld__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0', 'Fy__weld__fft_coefficient__attr_"imag"__coeff_61', 'Fy__weld__fft_coefficient__attr_"abs"__coeff_61', 'Fy__weld__fft_coefficient__attr_"real"__coeff_51', 'Fy__weld__ar_coefficient__coeff_5__k_10', 'Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4', 'Fz__weld__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"', 'Fz__weld__fft_coefficient__attr_"real"__coeff_84', 'Fz__weld__fft_coefficient__attr_"real"__coeff_85', 'Fz__weld__ratio_beyond_r_sigma__r_1', 'Fz__weld__ratio_beyond_r_sigma__r_2', 'Mz__weld__quantile__q_0.1', 'Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4', 'Mz__weld__fft_coefficient__attr_"angle"__coeff_15', 'Mz__weld__last_location_of_maximum', 'Mz__weld__fft_coefficient__attr_"abs"__coeff_58', 'Mz__weld__fft_coefficient__attr_"abs"__coeff_83']
# Selected target columns: ['stress_value_center']
# dfX.shape: (378, 56)
# dfY.shape: (378, 1)

# %%
# %% Extract features and targets
_X = _dfX.values
_Y = _dfY.values
print(f"_X.shape: {_X.shape}")
print(f"_Y.shape: {_Y.shape}")
# Out:
# _X.shape: (378, 56)
# _Y.shape: (378, 1)

# %%
# Create DataHandler instance
data_handler = DataHandler(
    _X=_X,
    _Y=_Y,
    scalerX=StandardScaler(),
    scalerY=StandardScaler(),
    colsX=colsX,
    colsY=colsY,
)

# %%
idx = 1
random_state = 1
test_size = 0.0
data_handler.split_and_scale(random_state=random_state, test_size=test_size)
df_X_train, df_Y_train = data_handler.get_train(as_dataframe=True)
display(df_X_train.head())
display(df_Y_train.head())
# Out:
# No test set, using all data for training.
#        position         R         W         D  Fx_location  Fy_location  \
# 0 -5.000000e-01 -1.224745  0.000000 -1.224745    -0.777006    -0.464968
# 1 -4.810966e-16  1.224745  1.224745  0.000000    -0.032479    -0.377666
# 2 -1.000000e+00  0.000000 -1.224745 -1.224745     0.064000    -0.782369
# 3 -5.000000e-01  1.224745  1.224745  1.224745    -0.050435    -0.543303
# 4 -1.000000e+00  1.224745  0.000000 -1.224745    -0.117693    -0.393217
#
#    Fz_location  Mz_location  Fx__dwell__fft_coefficient__attr_"abs"__coeff_11  \
# 0    -0.805576    -0.423257                                         -0.212769
# 1     0.320237    -0.355252                                         -0.525585
# 2    -2.024732    -0.465982                                          0.203409
# 3    -0.166273    -0.374813                                         -0.053910
# 4    -1.237342    -0.468396                                         -0.531406
#
#    Fx__dwell__ar_coefficient__coeff_0__k_10  ...  \
# 0                                  0.165177  ...
# 1                                 -0.384221  ...
# 2                                  1.906263  ...
# 3                                 -0.056061  ...
# 4                                 -0.292844  ...
#
#    Fz__weld__fft_coefficient__attr_"real"__coeff_84  \
# 0                                         -0.865086
# 1                                          2.500901
# 2                                          1.139794
# 3                                          2.072971
# 4                                         -0.271261
#
#    Fz__weld__fft_coefficient__attr_"real"__coeff_85  \
# 0                                         -0.711205
# 1                                         -2.407599
# 2                                          0.962873
# 3                                         -2.038444
# 4                                          0.027573
#
#    Fz__weld__ratio_beyond_r_sigma__r_1  Fz__weld__ratio_beyond_r_sigma__r_2  \
# 0                             0.527619                            -0.671809
# 1                            -1.234720                             1.252146
# 2                             1.948740                            -2.009696
# 3                             0.615044                             0.194399
# 4                             0.606539                            -0.316606
#
#    Mz__weld__quantile__q_0.1  \
# 0                  -0.348236
# 1                  -0.315047
# 2                  -0.536800
# 3                  -0.294181
# 4                  -0.318095
#
#    Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4  \
# 0                                          -0.267888
# 1                                          -0.390596
# 2                                          -0.613814
# 3                                          -0.030634
# 4                                          -0.745745
#
#    Mz__weld__fft_coefficient__attr_"angle"__coeff_15  \
# 0                                           1.361784
# 1                                           0.163715
# 2                                          -2.594135
# 3                                           0.100716
# 4                                          -0.064711
#
#    Mz__weld__last_location_of_maximum  \
# 0                           -1.218256
# 1                            0.705080
# 2                            0.689238
# 3                            0.825404
# 4                            0.844101
#
#    Mz__weld__fft_coefficient__attr_"abs"__coeff_58  \
# 0                                         0.104113
# 1                                         0.052008
# 2                                         0.540846
# 3                                         0.194849
# 4                                         1.326479
#
#    Mz__weld__fft_coefficient__attr_"abs"__coeff_83
# 0                                        -0.267514
# 1                                        -0.431733
# 2                                         1.248460
# 3                                        -0.038822
# 4                                        -0.028616
#
# [5 rows x 56 columns]
#    stress_value_center
# 0            -1.088213
# 1             0.678466
# 2            -0.499320
# 3            -0.057650
# 4            -0.646543

# %%
# Analyze model summary (all predictors)
X = sm.add_constant(df_X_train)
model = sm.OLS(df_Y_train, X).fit()

# Get and print model summary
model_summary = model.summary()
print(model_summary)

# Get p-values and sort features by significance
df_table = model.summary2().tables[1]
df_table = df_table.sort_values(by="P>|t|", ascending=True)
display(df_table)
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stress_value_center   R-squared:                       0.510
# Model:                             OLS   Adj. R-squared:                  0.424
# Method:                  Least Squares   F-statistic:                     5.964
# Date:                 Thu, 29 Jan 2026   Prob (F-statistic):           8.80e-26
# Time:                         17:21:07   Log-Likelihood:                -401.56
# No. Observations:                  378   AIC:                             917.1
# Df Residuals:                      321   BIC:                             1141.
# Df Model:                           56
# Covariance Type:             nonrobust
# =========================================================================================================================================
#                                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 -4.109e-12      0.039  -1.05e-10      1.000      -0.077       0.077
# position                                                                 -1.0731      0.121     -8.867      0.000      -1.311      -0.835
# R                                                                        -3.1924      1.904     -1.677      0.095      -6.938       0.553
# W                                                                         0.2934      0.166      1.766      0.078      -0.033       0.620
# D                                                                         2.8479      1.368      2.082      0.038       0.157       5.539
# Fx_location                                                               0.1218      0.077      1.577      0.116      -0.030       0.274
# Fy_location                                                              -0.5754      0.365     -1.575      0.116      -1.294       0.143
# Fz_location                                                               0.5671      0.171      3.313      0.001       0.230       0.904
# Mz_location                                                               2.9008      0.773      3.754      0.000       1.381       4.421
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11                          0.0341      0.266      0.128      0.898      -0.489       0.557
# Fx__dwell__ar_coefficient__coeff_0__k_10                                  0.1179      0.295      0.400      0.689      -0.462       0.697
# Fx__dwell__quantile__q_0.7                                               -0.1376      0.605     -0.228      0.820      -1.327       1.052
# Fx__dwell__fft_coefficient__attr_"real"__coeff_62                         0.1070      1.594      0.067      0.947      -3.029       3.243
# Fx__dwell__partial_autocorrelation__lag_6                                 0.5326      0.444      1.201      0.231      -0.340       1.405
# Fx__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2     3.8601      7.009      0.551      0.582      -9.930      17.650
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71                        -0.0866      0.261     -0.332      0.740      -0.600       0.427
# Fy__dwell__fft_coefficient__attr_"abs"__coeff_59                         -0.4191      0.218     -1.924      0.055      -0.848       0.010
# Fy__dwell__last_location_of_minimum                                    3813.5270   1894.801      2.013      0.045      85.730    7541.324
# Fy__dwell__first_location_of_minimum                                  -3813.5119   1894.718     -2.013      0.045   -7541.145     -85.879
# Fy__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2     0.6885      1.318      0.522      0.602      -1.905       3.282
# Fy__dwell__autocorrelation__lag_3                                         3.0549      1.512      2.020      0.044       0.080       6.030
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4                         0.4737      0.646      0.733      0.464      -0.797       1.744
# Fz__dwell__fft_coefficient__attr_"real"__coeff_4                         -0.7975      0.362     -2.200      0.028      -1.511      -0.084
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68                       -0.5044      0.487     -1.036      0.301      -1.462       0.453
# Fz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0     0.9591      0.639      1.502      0.134      -0.297       2.215
# Fz__dwell__approximate_entropy__m_2__r_0.7                                2.1790      1.498      1.455      0.147      -0.768       5.126
# Fz__dwell__approximate_entropy__m_2__r_0.9                               -1.5686      1.107     -1.417      0.157      -3.746       0.609
# Mz__dwell__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"        0.1391      0.212      0.656      0.512      -0.278       0.556
# Mz__dwell__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"         -0.0416      0.194     -0.214      0.831      -0.424       0.340
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62                        -0.5464      1.494     -0.366      0.715      -3.486       2.393
# Mz__dwell__fft_coefficient__attr_"real"__coeff_42                         0.3834      0.329      1.165      0.245      -0.264       1.031
# Mz__dwell__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2    -2.7771      6.379     -0.435      0.664     -15.327       9.773
# Mz__dwell__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2    -1.3696      1.010     -1.356      0.176      -3.357       0.618
# Fx__weld__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2      -0.0131      0.196     -0.067      0.947      -0.398       0.372
# Fx__weld__fft_coefficient__attr_"abs"__coeff_5                            0.5969      0.276      2.166      0.031       0.055       1.139
# Fx__weld__fft_coefficient__attr_"real"__coeff_31                         -0.4986      0.396     -1.259      0.209      -1.278       0.281
# Fx__weld__fft_coefficient__attr_"angle"__coeff_31                        -0.0825      0.343     -0.240      0.810      -0.758       0.593
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58                           0.3898      0.248      1.572      0.117      -0.098       0.878
# Fx__weld__fft_coefficient__attr_"imag"__coeff_21                         -0.1570      0.304     -0.517      0.605      -0.754       0.440
# Fy__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_5       -0.2731      0.186     -1.469      0.143      -0.639       0.093
# Fy__weld__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0      0.2876      0.256      1.124      0.262      -0.216       0.791
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61                          0.1814      0.292      0.620      0.535      -0.394       0.757
# Fy__weld__fft_coefficient__attr_"abs"__coeff_61                          -0.0080      0.566     -0.014      0.989      -1.122       1.106
# Fy__weld__fft_coefficient__attr_"real"__coeff_51                         -0.2003      0.184     -1.086      0.278      -0.563       0.162
# Fy__weld__ar_coefficient__coeff_5__k_10                                  -0.8038      0.450     -1.787      0.075      -1.689       0.081
# Fz__weld__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4     0.2911      0.345      0.844      0.399      -0.387       0.970
# Fz__weld__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"       0.1358      0.407      0.333      0.739      -0.665       0.937
# Fz__weld__fft_coefficient__attr_"real"__coeff_84                         -0.0383      0.164     -0.234      0.815      -0.361       0.284
# Fz__weld__fft_coefficient__attr_"real"__coeff_85                         -0.4137      0.299     -1.384      0.167      -1.002       0.174
# Fz__weld__ratio_beyond_r_sigma__r_1                                      -0.0098      0.366     -0.027      0.979      -0.729       0.710
# Fz__weld__ratio_beyond_r_sigma__r_2                                       0.2151      0.545      0.395      0.693      -0.857       1.287
# Mz__weld__quantile__q_0.1                                                -2.3313      0.857     -2.721      0.007      -4.017      -0.645
# Mz__weld__energy_ratio_by_chunks__num_segments_10__segment_focus_4       -0.0959      0.573     -0.167      0.867      -1.223       1.032
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15                         0.3572      0.508      0.703      0.482      -0.642       1.356
# Mz__weld__last_location_of_maximum                                        0.4766      0.392      1.216      0.225      -0.294       1.247
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58                          -0.0779      0.166     -0.470      0.639      -0.404       0.248
# Mz__weld__fft_coefficient__attr_"abs"__coeff_83                           0.3896      0.323      1.207      0.228      -0.245       1.024
# ==============================================================================
# Omnibus:                        1.248   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.536   Jarque-Bera (JB):                1.208
# Skew:                           0.016   Prob(JB):                        0.547
# Kurtosis:                       2.725   Cond. No.                     2.05e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.05e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                            Coef.     Std.Err.  \
# position                                           -1.073089e+00     0.121020
# Mz_location                                         2.900816e+00     0.772725
# Fz_location                                         5.671343e-01     0.171183
# Mz__weld__quantile__q_0.1                          -2.331306e+00     0.856895
# Fz__dwell__fft_coefficient__attr_"real"__coeff_4   -7.974848e-01     0.362423
# Fx__weld__fft_coefficient__attr_"abs"__coeff_5      5.968616e-01     0.275606
# D                                                   2.847866e+00     1.367861
# Fy__dwell__autocorrelation__lag_3                   3.054920e+00     1.512282
# Fy__dwell__first_location_of_minimum               -3.813512e+03  1894.717860
# Fy__dwell__last_location_of_minimum                 3.813527e+03  1894.801294
# Fy__dwell__fft_coefficient__attr_"abs"__coeff_59   -4.191048e-01     0.217883
# Fy__weld__ar_coefficient__coeff_5__k_10            -8.038235e-01     0.449742
# W                                                   2.933965e-01     0.166134
# R                                                  -3.192438e+00     1.903877
# Fx_location                                         1.218438e-01     0.077241
# Fy_location                                        -5.753919e-01     0.365285
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58     3.898464e-01     0.248020
# Fz__dwell__change_quantiles__f_agg_"mean"__isab...  9.591396e-01     0.638582
# Fy__weld__energy_ratio_by_chunks__num_segments_... -2.730877e-01     0.185859
# Fz__dwell__approximate_entropy__m_2__r_0.7          2.178975e+00     1.497710
# Fz__dwell__approximate_entropy__m_2__r_0.9         -1.568574e+00     1.106789
# Fz__weld__fft_coefficient__attr_"real"__coeff_85   -4.137351e-01     0.298991
# Mz__dwell__change_quantiles__f_agg_"var"__isabs... -1.369631e+00     1.010389
# Fx__weld__fft_coefficient__attr_"real"__coeff_31   -4.986323e-01     0.396070
# Mz__weld__last_location_of_maximum                  4.765864e-01     0.391796
# Mz__weld__fft_coefficient__attr_"abs"__coeff_83     3.895519e-01     0.322657
# Fx__dwell__partial_autocorrelation__lag_6           5.326430e-01     0.443599
# Mz__dwell__fft_coefficient__attr_"real"__coeff_42   3.834070e-01     0.329156
# Fy__weld__change_quantiles__f_agg_"mean"__isabs...  2.876275e-01     0.255944
# Fy__weld__fft_coefficient__attr_"real"__coeff_51   -2.003131e-01     0.184384
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68 -5.044410e-01     0.486742
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...  2.910729e-01     0.344883
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4   4.736723e-01     0.645830
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15   3.572463e-01     0.507861
# Mz__dwell__augmented_dickey_fuller__attr_"tests...  1.390826e-01     0.211886
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61    1.814435e-01     0.292471
# Fx__dwell__change_quantiles__f_agg_"mean"__isab...  3.860139e+00     7.009232
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...  6.884980e-01     1.318191
# Fx__weld__fft_coefficient__attr_"imag"__coeff_21   -1.570389e-01     0.303606
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58    -7.789835e-02     0.165853
# Mz__dwell__change_quantiles__f_agg_"mean"__isab... -2.777107e+00     6.378871
# Fx__dwell__ar_coefficient__coeff_0__k_10            1.178502e-01     0.294511
# Fz__weld__ratio_beyond_r_sigma__r_2                 2.151344e-01     0.544731
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62  -5.463744e-01     1.494281
# Fz__weld__agg_linear_trend__attr_"rvalue"__chun...  1.357584e-01     0.407173
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71  -8.664619e-02     0.261064
# Fx__weld__fft_coefficient__attr_"angle"__coeff_31  -8.248182e-02     0.343440
# Fz__weld__fft_coefficient__attr_"real"__coeff_84   -3.833828e-02     0.163916
# Fx__dwell__quantile__q_0.7                         -1.375649e-01     0.604543
# Mz__dwell__augmented_dickey_fuller__attr_"pvalu... -4.156690e-02     0.194185
# Mz__weld__energy_ratio_by_chunks__num_segments_... -9.585509e-02     0.573121
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11    3.410656e-02     0.265724
# Fx__dwell__fft_coefficient__attr_"real"__coeff_62   1.069587e-01     1.594043
# Fx__weld__change_quantiles__f_agg_"var"__isabs_... -1.311826e-02     0.195862
# Fz__weld__ratio_beyond_r_sigma__r_1                -9.785818e-03     0.365800
# Fy__weld__fft_coefficient__attr_"abs"__coeff_61    -8.026105e-03     0.566296
# const                                              -4.109387e-12     0.039073
#
#                                                                t  \
# position                                           -8.867046e+00
# Mz_location                                         3.754007e+00
# Fz_location                                         3.313024e+00
# Mz__weld__quantile__q_0.1                          -2.720644e+00
# Fz__dwell__fft_coefficient__attr_"real"__coeff_4   -2.200424e+00
# Fx__weld__fft_coefficient__attr_"abs"__coeff_5      2.165632e+00
# D                                                   2.081985e+00
# Fy__dwell__autocorrelation__lag_3                   2.020073e+00
# Fy__dwell__first_location_of_minimum               -2.012707e+00
# Fy__dwell__last_location_of_minimum                 2.012626e+00
# Fy__dwell__fft_coefficient__attr_"abs"__coeff_59   -1.923527e+00
# Fy__weld__ar_coefficient__coeff_5__k_10            -1.787300e+00
# W                                                   1.766019e+00
# R                                                  -1.676809e+00
# Fx_location                                         1.577440e+00
# Fy_location                                        -1.575187e+00
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58     1.571832e+00
# Fz__dwell__change_quantiles__f_agg_"mean"__isab...  1.501984e+00
# Fy__weld__energy_ratio_by_chunks__num_segments_... -1.469328e+00
# Fz__dwell__approximate_entropy__m_2__r_0.7          1.454872e+00
# Fz__dwell__approximate_entropy__m_2__r_0.9         -1.417229e+00
# Fz__weld__fft_coefficient__attr_"real"__coeff_85   -1.383770e+00
# Mz__dwell__change_quantiles__f_agg_"var"__isabs... -1.355548e+00
# Fx__weld__fft_coefficient__attr_"real"__coeff_31   -1.258948e+00
# Mz__weld__last_location_of_maximum                  1.216415e+00
# Mz__weld__fft_coefficient__attr_"abs"__coeff_83     1.207325e+00
# Fx__dwell__partial_autocorrelation__lag_6           1.200731e+00
# Mz__dwell__fft_coefficient__attr_"real"__coeff_42   1.164818e+00
# Fy__weld__change_quantiles__f_agg_"mean"__isabs...  1.123789e+00
# Fy__weld__fft_coefficient__attr_"real"__coeff_51   -1.086392e+00
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68 -1.036363e+00
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...  8.439762e-01
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4   7.334320e-01
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15   7.034336e-01
# Mz__dwell__augmented_dickey_fuller__attr_"tests...  6.564039e-01
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61    6.203812e-01
# Fx__dwell__change_quantiles__f_agg_"mean"__isab...  5.507221e-01
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...  5.223052e-01
# Fx__weld__fft_coefficient__attr_"imag"__coeff_21   -5.172465e-01
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58    -4.696844e-01
# Mz__dwell__change_quantiles__f_agg_"mean"__isab... -4.353603e-01
# Fx__dwell__ar_coefficient__coeff_0__k_10            4.001552e-01
# Fz__weld__ratio_beyond_r_sigma__r_2                 3.949370e-01
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62  -3.656437e-01
# Fz__weld__agg_linear_trend__attr_"rvalue"__chun...  3.334167e-01
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71  -3.318959e-01
# Fx__weld__fft_coefficient__attr_"angle"__coeff_31  -2.401635e-01
# Fz__weld__fft_coefficient__attr_"real"__coeff_84   -2.338899e-01
# Fx__dwell__quantile__q_0.7                         -2.275521e-01
# Mz__dwell__augmented_dickey_fuller__attr_"pvalu... -2.140582e-01
# Mz__weld__energy_ratio_by_chunks__num_segments_... -1.672511e-01
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11    1.283532e-01
# Fx__dwell__fft_coefficient__attr_"real"__coeff_62   6.709900e-02
# Fx__weld__change_quantiles__f_agg_"var"__isabs_... -6.697719e-02
# Fz__weld__ratio_beyond_r_sigma__r_1                -2.675181e-02
# Fy__weld__fft_coefficient__attr_"abs"__coeff_61    -1.417298e-02
# const                                              -1.051718e-10
#
#                                                            P>|t|       [0.025  \
# position                                            5.308407e-17    -1.311181
# Mz_location                                         2.065432e-04     1.380571
# Fz_location                                         1.028305e-03     0.230352
# Mz__weld__quantile__q_0.1                           6.870623e-03    -4.017145
# Fz__dwell__fft_coefficient__attr_"real"__coeff_4    2.848877e-02    -1.510510
# Fx__weld__fft_coefficient__attr_"abs"__coeff_5      3.107536e-02     0.054639
# D                                                   3.813567e-02     0.156761
# Fy__dwell__autocorrelation__lag_3                   4.420612e-02     0.079685
# Fy__dwell__first_location_of_minimum                4.498020e-02 -7541.145150
# Fy__dwell__last_location_of_minimum                 4.498873e-02    85.729635
# Fy__dwell__fft_coefficient__attr_"abs"__coeff_59    5.529804e-02    -0.847765
# Fy__weld__ar_coefficient__coeff_5__k_10             7.483232e-02    -1.688637
# W                                                   7.834309e-02    -0.033453
# R                                                   9.455340e-02    -6.938090
# Fx_location                                         1.156793e-01    -0.030120
# Fy_location                                         1.161983e-01    -1.294047
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58     1.169746e-01    -0.098104
# Fz__dwell__change_quantiles__f_agg_"mean"__isab...  1.340842e-01    -0.297194
# Fy__weld__energy_ratio_by_chunks__num_segments_...  1.427233e-01    -0.638743
# Fz__dwell__approximate_entropy__m_2__r_0.7          1.466819e-01    -0.767591
# Fz__dwell__approximate_entropy__m_2__r_0.9          1.573859e-01    -3.746051
# Fz__weld__fft_coefficient__attr_"real"__coeff_85    1.673904e-01    -1.001965
# Mz__dwell__change_quantiles__f_agg_"var"__isabs...  1.761960e-01    -3.357452
# Fx__weld__fft_coefficient__attr_"real"__coeff_31    2.089637e-01    -1.277854
# Mz__weld__last_location_of_maximum                  2.247205e-01    -0.294226
# Mz__weld__fft_coefficient__attr_"abs"__coeff_83     2.281959e-01    -0.245238
# Fx__dwell__partial_autocorrelation__lag_6           2.307409e-01    -0.340086
# Mz__dwell__fft_coefficient__attr_"real"__coeff_42   2.449575e-01    -0.264169
# Fy__weld__change_quantiles__f_agg_"mean"__isabs...  2.619421e-01    -0.215913
# Fy__weld__fft_coefficient__attr_"real"__coeff_51    2.781207e-01    -0.563066
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68  3.008130e-01    -1.462048
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...  3.993112e-01    -0.387443
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4   4.638303e-01    -0.796921
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15   4.822955e-01    -0.641910
# Mz__dwell__augmented_dickey_fuller__attr_"tests...  5.120346e-01    -0.277777
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61    5.354470e-01    -0.393959
# Fx__dwell__change_quantiles__f_agg_"mean"__isab...  5.822072e-01    -9.929696
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...  6.018181e-01    -1.904887
# Fx__weld__fft_coefficient__attr_"imag"__coeff_21    6.053403e-01    -0.754347
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58     6.388994e-01    -0.404194
# Mz__dwell__change_quantiles__f_agg_"mean"__isab...  6.635935e-01   -15.326782
# Fx__dwell__ar_coefficient__coeff_0__k_10            6.893083e-01    -0.461566
# Fz__weld__ratio_beyond_r_sigma__r_2                 6.931517e-01    -0.856559
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62   7.148718e-01    -3.486195
# Fz__weld__agg_linear_trend__attr_"rvalue"__chun...  7.390375e-01    -0.665307
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71   7.401845e-01    -0.600260
# Fx__weld__fft_coefficient__attr_"angle"__coeff_31   8.103568e-01    -0.758160
# Fz__weld__fft_coefficient__attr_"real"__coeff_84    8.152195e-01    -0.360823
# Fx__dwell__quantile__q_0.7                          8.201394e-01    -1.326931
# Mz__dwell__augmented_dickey_fuller__attr_"pvalu...  8.306376e-01    -0.423603
# Mz__weld__energy_ratio_by_chunks__num_segments_...  8.672778e-01    -1.223403
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11    8.979499e-01    -0.488675
# Fx__dwell__fft_coefficient__attr_"real"__coeff_62   9.465447e-01    -3.029132
# Fx__weld__change_quantiles__f_agg_"var"__isabs_...  9.466416e-01    -0.398453
# Fz__weld__ratio_beyond_r_sigma__r_1                 9.786743e-01    -0.729455
# Fy__weld__fft_coefficient__attr_"abs"__coeff_61     9.887008e-01    -1.122147
# const                                               1.000000e+00    -0.076872
#
#                                                          0.975]
# position                                              -0.834997
# Mz_location                                            4.421062
# Fz_location                                            0.903917
# Mz__weld__quantile__q_0.1                             -0.645466
# Fz__dwell__fft_coefficient__attr_"real"__coeff_4      -0.084460
# Fx__weld__fft_coefficient__attr_"abs"__coeff_5         1.139084
# D                                                      5.538971
# Fy__dwell__autocorrelation__lag_3                      6.030155
# Fy__dwell__first_location_of_minimum                 -85.878634
# Fy__dwell__last_location_of_minimum                 7541.324442
# Fy__dwell__fft_coefficient__attr_"abs"__coeff_59       0.009555
# Fy__weld__ar_coefficient__coeff_5__k_10                0.080990
# W                                                      0.620246
# R                                                      0.553215
# Fx_location                                            0.273807
# Fy_location                                            0.143263
# Fx__weld__fft_coefficient__attr_"abs"__coeff_58        0.877797
# Fz__dwell__change_quantiles__f_agg_"mean"__isab...     2.215473
# Fy__weld__energy_ratio_by_chunks__num_segments_...     0.092568
# Fz__dwell__approximate_entropy__m_2__r_0.7             5.125542
# Fz__dwell__approximate_entropy__m_2__r_0.9             0.608903
# Fz__weld__fft_coefficient__attr_"real"__coeff_85       0.174495
# Mz__dwell__change_quantiles__f_agg_"var"__isabs...     0.618190
# Fx__weld__fft_coefficient__attr_"real"__coeff_31       0.280590
# Mz__weld__last_location_of_maximum                     1.247398
# Mz__weld__fft_coefficient__attr_"abs"__coeff_83        1.024342
# Fx__dwell__partial_autocorrelation__lag_6              1.405372
# Mz__dwell__fft_coefficient__attr_"real"__coeff_42      1.030983
# Fy__weld__change_quantiles__f_agg_"mean"__isabs...     0.791168
# Fy__weld__fft_coefficient__attr_"real"__coeff_51       0.162440
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_68     0.453166
# Fz__weld__change_quantiles__f_agg_"mean"__isabs...     0.969589
# Fz__dwell__fft_coefficient__attr_"angle"__coeff_4      1.744266
# Mz__weld__fft_coefficient__attr_"angle"__coeff_15      1.356402
# Mz__dwell__augmented_dickey_fuller__attr_"tests...     0.555943
# Fy__weld__fft_coefficient__attr_"imag"__coeff_61       0.756846
# Fx__dwell__change_quantiles__f_agg_"mean"__isab...    17.649974
# Fy__dwell__change_quantiles__f_agg_"mean"__isab...     3.281883
# Fx__weld__fft_coefficient__attr_"imag"__coeff_21       0.440269
# Mz__weld__fft_coefficient__attr_"abs"__coeff_58        0.248397
# Mz__dwell__change_quantiles__f_agg_"mean"__isab...     9.772567
# Fx__dwell__ar_coefficient__coeff_0__k_10               0.697266
# Fz__weld__ratio_beyond_r_sigma__r_2                    1.286828
# Mz__dwell__fft_coefficient__attr_"real"__coeff_62      2.393446
# Fz__weld__agg_linear_trend__attr_"rvalue"__chun...     0.936824
# Fy__dwell__fft_coefficient__attr_"real"__coeff_71      0.426967
# Fx__weld__fft_coefficient__attr_"angle"__coeff_31      0.593196
# Fz__weld__fft_coefficient__attr_"real"__coeff_84       0.284147
# Fx__dwell__quantile__q_0.7                             1.051801
# Mz__dwell__augmented_dickey_fuller__attr_"pvalu...     0.340469
# Mz__weld__energy_ratio_by_chunks__num_segments_...     1.031692
# Fx__dwell__fft_coefficient__attr_"abs"__coeff_11       0.556888
# Fx__dwell__fft_coefficient__attr_"real"__coeff_62      3.243049
# Fx__weld__change_quantiles__f_agg_"var"__isabs_...     0.372216
# Fz__weld__ratio_beyond_r_sigma__r_1                    0.709883
# Fy__weld__fft_coefficient__attr_"abs"__coeff_61        1.106094
# const                                                  0.076872
