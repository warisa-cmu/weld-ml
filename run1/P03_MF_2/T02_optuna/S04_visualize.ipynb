# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path

# %%
CURRENT_DIR = Path.cwd()  # Current directory of the running file

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performances.xlsx")

# %%
df
# Out:
#      random_state  test_size model      Y  MSE Train (No Val)  MSE Test  \
# 0               1        0.3   DTR    Y-1            0.786422  1.181183
# 1               1        0.3   DTR    Y-2            0.941016  0.806754
# 2               1        0.3   DTR    Y-3            0.876022  0.895374
# 3               1        0.3   DTR  Y-All            0.867820  0.961104
# 4               2        0.3   DTR    Y-1            0.863253  0.720875
# ..            ...        ...   ...    ...                 ...       ...
# 135             4        0.3  XGBR  Y-All            0.176469  0.796482
# 136             5        0.3  XGBR    Y-1            0.158872  1.049153
# 137             5        0.3  XGBR    Y-2            0.215143  1.208719
# 138             5        0.3  XGBR    Y-3            0.138058  0.566927
# 139             5        0.3  XGBR  Y-All            0.170691  0.941600
#
#      MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0               2.038765   1.996306           0.213578  0.076001
# 1               1.246368   3.987581           0.058984  0.016183
# 2               1.278863   1.318604           0.123978 -0.049685
# 3               1.521332   2.434163           0.132180  0.014166
# 4               1.992263   1.376161           0.136747  0.173795
# ..                   ...        ...                ...       ...
# 135             1.327319   2.347154           0.823531  0.203056
# 136            36.775187   1.657162           0.841128  0.100365
# 137             1.119698   4.005287           0.784857 -0.578751
# 138             0.863655   1.265315           0.861942  0.403524
# 139            12.919513   2.309255           0.829309 -0.024954
#
# [140 rows x 10 columns]

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
