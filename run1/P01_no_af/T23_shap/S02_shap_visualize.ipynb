# %%
import shap
import pickle
import pandas as pd

# %%
with open("S01_shap_calc.pkl", "rb") as f:
    data = pickle.load(f)
    shaps = data["shaps"]
    infos = data["infos"]

# %%
pd.DataFrame.from_dict(infos)
# Out:
#   model                                       model_params  test_size  \
# 0   DTR  {'criterion': 'friedman_mse', 'splitter': 'bes...        0.3
# 1    EN  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...        0.3
# 2   GBR  {'n_estimators': 76, 'learning_rate': 0.001648...        0.3
# 3   KNR  {'n_neighbors': 19, 'weights': 'uniform', 'alg...        0.3
# 4   RFR  {'n_estimators': 118, 'max_depth': 106, 'min_s...        0.3
# 5   SVR  {'kernel': 'linear', 'C': 7.451156502282094e-0...        0.3
# 6  XGBR  {'n_estimators': 118, 'max_depth': 12, 'learni...        0.3
#
#    random_state
# 0             1
# 1             5
# 2             4
# 3             4
# 4             4
# 5             4
# 6             4

# %%
idx = 6
shap_values = shaps[idx]["shap_values"]
model = shaps[idx]["model"]

print(f"Model: {model}")
# Out:
# Model: XGBR

# %%
# Plot SHAP values for the first instance
shap.plots.waterfall(shap_values[0])

# %%
# Plot SHAP summary plot
shap.plots.beeswarm(shap_values)

# %%
# Plot SHAP summary plot with features ordered by importance
shap.plots.beeswarm(shap_values, order=shap_values.abs.max(0))

# %%
# Plot SHAP bar plot
shap.plots.bar(shap_values)

# %%
# Plot SHAP summary plot with feature names
shap.summary_plot(shap_values)

# %%
shap.plots.beeswarm(shap_values.abs, color="shap_red")

# %%
shap.plots.violin(shap_values)

# %%
shap.plots.heatmap(shap_values)
# Out:
# <Axes: xlabel='Instances'>

# %%
shap.plots.heatmap(shap_values, instance_order=shap_values.sum(1))
# Out:
# <Axes: xlabel='Instances'>
