# %%
import ast
import re
from pathlib import Path
import pickle

import pandas as pd
from sklearn.preprocessing import StandardScaler

from run1.lib.classes_ml import DataHandler
from run1.lib.optuna_ml import OptunaUtil
from run1.lib.shap import ShapUtil

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = BASE_DIR.parent.parent.parent
DATA_DIR = ROOT_DIR / "run1" / "data"
STUDY_DIR = ROOT_DIR / "run1" / "P01_no_af" / "T01_optuna"
CURRENT_DIR = BASE_DIR
print(f"CURRENT_DIR: {CURRENT_DIR}")
print(f"DATA_DIR: {DATA_DIR}")
print(f"STUDY_DIR: {STUDY_DIR}")
# Out:
# CURRENT_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P01_no_af\T23_shap
# DATA_DIR: c:\Users\admin\Coding\research\weld-ml\run1\data
# STUDY_DIR: c:\Users\admin\Coding\research\weld-ml\run1\P01_no_af\T01_optuna

# %%
# Load study info
study_info_filename = "S02_combine_study.xlsx"
study_info = pd.read_excel(STUDY_DIR / study_info_filename)
study_info["model_params"] = study_info["model_params"].apply(ast.literal_eval)

# Load experimental data
_df = pd.read_excel(DATA_DIR / "S02_data_exp.xlsx")
print(f"df.shape: {_df.shape}")
# Out:
# df.shape: (378, 9)

# %%
# Select columns for features and targets
colsY = [c for c in _df.columns if re.search(r"stress_value", c)]

# Select feature columns based on predefined names
colsY = [c for c in colsY if c in ["stress_value_center"]]

# Predefined feature columns
colsX = [c for c in _df.columns if c in ["R", "W", "D", "position"]]
_dfY = _df[colsY]
_dfX = _df[colsX]
print("Selected feature columns:", colsX)
print("Selected target columns:", colsY)
print(f"dfX.shape: {_dfX.shape}")
print(f"dfY.shape: {_dfY.shape}")
# Out:
# Selected feature columns: ['position', 'R', 'W', 'D']
# Selected target columns: ['stress_value_center']
# dfX.shape: (378, 4)
# dfY.shape: (378, 1)

# %%
# %% Extract features and targets
_X = _dfX.values
_Y = _dfY.values
print(f"_X.shape: {_X.shape}")
print(f"_Y.shape: {_Y.shape}")
# Out:
# _X.shape: (378, 4)
# _Y.shape: (378, 1)

# %%
# Create DataHandler instance
data_handler = DataHandler(
    _X=_X,
    _Y=_Y,
    scalerX=StandardScaler(),
    scalerY=StandardScaler(),
    colsX=colsX,
    colsY=colsY,
)

# %%
study_info
# Out:
#                 study_name                dt model  n_trials  random_state  \
# 0    study_DTR_RS-1_TS-0_3  2026-01-28_15-19   DTR         1             1
# 1    study_DTR_RS-2_TS-0_3  2026-01-28_15-19   DTR         1             2
# 2    study_DTR_RS-3_TS-0_3  2026-01-28_15-19   DTR         1             3
# 3    study_DTR_RS-4_TS-0_3  2026-01-28_15-19   DTR         1             4
# 4    study_DTR_RS-5_TS-0_3  2026-01-28_15-19   DTR         1             5
# 5     study_EN_RS-1_TS-0_3  2026-01-28_15-19    EN         1             1
# 6     study_EN_RS-2_TS-0_3  2026-01-28_15-19    EN         1             2
# 7     study_EN_RS-3_TS-0_3  2026-01-28_15-19    EN         1             3
# 8     study_EN_RS-4_TS-0_3  2026-01-28_15-19    EN         1             4
# 9     study_EN_RS-5_TS-0_3  2026-01-28_15-19    EN         1             5
# 10   study_GBR_RS-1_TS-0_3  2026-01-28_15-19   GBR         1             1
# 11   study_GBR_RS-2_TS-0_3  2026-01-28_15-19   GBR         1             2
# 12   study_GBR_RS-3_TS-0_3  2026-01-28_15-19   GBR         1             3
# 13   study_GBR_RS-4_TS-0_3  2026-01-28_15-19   GBR         1             4
# 14   study_GBR_RS-5_TS-0_3  2026-01-28_15-19   GBR         1             5
# 15   study_KNR_RS-1_TS-0_3  2026-01-28_15-19   KNR         1             1
# 16   study_KNR_RS-2_TS-0_3  2026-01-28_15-19   KNR         1             2
# 17   study_KNR_RS-3_TS-0_3  2026-01-28_15-19   KNR         1             3
# 18   study_KNR_RS-4_TS-0_3  2026-01-28_15-19   KNR         1             4
# 19   study_KNR_RS-5_TS-0_3  2026-01-28_15-19   KNR         1             5
# 20   study_RFR_RS-1_TS-0_3  2026-01-28_15-19   RFR         1             1
# 21   study_RFR_RS-2_TS-0_3  2026-01-28_15-19   RFR         1             2
# 22   study_RFR_RS-3_TS-0_3  2026-01-28_15-19   RFR         1             3
# 23   study_RFR_RS-4_TS-0_3  2026-01-28_15-19   RFR         1             4
# 24   study_RFR_RS-5_TS-0_3  2026-01-28_15-19   RFR         1             5
# 25   study_SVR_RS-1_TS-0_3  2026-01-28_15-19   SVR         1             1
# 26   study_SVR_RS-2_TS-0_3  2026-01-28_15-19   SVR         1             2
# 27   study_SVR_RS-3_TS-0_3  2026-01-28_15-19   SVR         1             3
# 28   study_SVR_RS-4_TS-0_3  2026-01-28_15-19   SVR         1             4
# 29   study_SVR_RS-5_TS-0_3  2026-01-28_15-19   SVR         1             5
# 30  study_XGBR_RS-1_TS-0_3  2026-01-28_15-19  XGBR         1             1
# 31  study_XGBR_RS-2_TS-0_3  2026-01-28_15-19  XGBR         1             2
# 32  study_XGBR_RS-3_TS-0_3  2026-01-28_15-19  XGBR         1             3
# 33  study_XGBR_RS-4_TS-0_3  2026-01-28_15-19  XGBR         1             4
# 34  study_XGBR_RS-5_TS-0_3  2026-01-28_15-19  XGBR         1             5
#
#     test_size                                         best_param  best_value  \
# 0         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.086123
# 1         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.051307
# 2         0.3  {'criterion': 'absolute_error', 'splitter': 'r...   -0.049025
# 3         0.3  {'criterion': 'absolute_error', 'splitter': 'r...   -0.082220
# 4         0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.073278
# 5         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.029026
# 6         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.026222
# 7         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.052901
# 8         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.009735
# 9         0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.005825
# 10        0.3  {'n_estimators': 76, 'learning_rate': 0.001648...    0.001466
# 11        0.3  {'n_estimators': 76, 'learning_rate': 0.001648...    0.018350
# 12        0.3  {'n_estimators': 76, 'learning_rate': 0.001648...    0.013056
# 13        0.3  {'n_estimators': 76, 'learning_rate': 0.001648...   -0.016851
# 14        0.3  {'n_estimators': 76, 'learning_rate': 0.001648...   -0.009888
# 15        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.070857
# 16        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.009078
# 17        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.008947
# 18        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.082493
# 19        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.050595
# 20        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.097079
# 21        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.083851
# 22        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.072004
# 23        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.112790
# 24        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.108954
# 25        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.028772
# 26        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.040373
# 27        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.040016
# 28        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.007415
# 29        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.018972
# 30        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.093340
# 31        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.084937
# 32        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.060728
# 33        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.122445
# 34        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.116915
#
#     total_trial  mse_mean   mse_std  mape_mean   mape_std   r2_mean    r2_std  \
# 0             6  0.896066  0.047836   1.502360   0.315104  0.086123  0.022041
# 1             5  0.930573  0.071420   1.731294   0.292716  0.051307  0.032413
# 2             5  0.927986  0.126566   1.724843   0.339879  0.049025  0.010178
# 3             5  0.911722  0.091865   1.569615   0.292636  0.082220  0.067790
# 4             5  0.912384  0.054152  12.568603  11.040725  0.073278  0.058696
# 5             1  1.011097  0.068451   1.111043   0.034699 -0.029026  0.027787
# 6             1  1.008390  0.096378   1.301510   0.104215 -0.026222  0.028176
# 7             1  1.031090  0.141004   1.332102   0.203464 -0.052901  0.025337
# 8             1  1.002447  0.090162   1.200530   0.117793 -0.009735  0.019297
# 9             1  0.992530  0.029870   5.890901   8.037083 -0.005825  0.016340
# 10            3  0.983513  0.071277   1.010805   0.012586 -0.001466  0.037943
# 11            3  1.001209  0.098723   1.164890   0.090703 -0.018350  0.037927
# 12            3  0.990637  0.126069   1.134805   0.096349 -0.013056  0.021169
# 13            3  0.977015  0.076141   1.073809   0.071166  0.016851  0.010099
# 14            3  0.977450  0.035491   2.305103   1.316918  0.009888  0.019919
# 15            1  0.911066  0.048604   1.391217   0.314289  0.070857  0.033094
# 16            1  0.973836  0.091620   1.576626   0.172618  0.009078  0.012784
# 17            1  0.967659  0.151875   1.482301   0.062958  0.008947  0.029421
# 18            1  0.910965  0.089471   1.623037   0.426968  0.082493  0.039093
# 19            1  0.936284  0.037422  12.208681  11.567403  0.050595  0.018626
# 20            3  0.885602  0.057379   1.241700   0.177001  0.097079  0.026616
# 21            3  0.901752  0.077969   1.470056   0.219778  0.083851  0.011951
# 22            3  0.907353  0.137098   1.418747   0.211786  0.072004  0.019280
# 23            3  0.879850  0.069949   1.339074   0.136253  0.112790  0.031400
# 24            3  0.879629  0.039536   8.547499   7.326179  0.108954  0.032300
# 25            1  1.010345  0.072357   1.006783   0.024678 -0.028772  0.037411
# 26            1  1.022822  0.101058   1.159551   0.092381 -0.040373  0.037231
# 27            1  1.016231  0.124704   1.122254   0.094351 -0.040016  0.023709
# 28            1  1.000296  0.075689   1.076004   0.085703 -0.007415  0.003851
# 29            1  1.006093  0.041057   2.372368   1.733949 -0.018972  0.020827
# 30            3  0.887936  0.064932   1.430836   0.282971  0.093340  0.052967
# 31            3  0.899581  0.066126   1.606873   0.234996  0.084937  0.027008
# 32            3  0.916974  0.153707   1.490561   0.187824  0.060728  0.034915
# 33            3  0.868020  0.074160   1.609095   0.320927  0.122445  0.043932
# 34            3  0.869688  0.035959  11.490578  10.408227  0.116915  0.031224
#
#                                          model_params
# 0   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 1   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 2   {'criterion': 'absolute_error', 'splitter': 'r...
# 3   {'criterion': 'absolute_error', 'splitter': 'r...
# 4   {'criterion': 'friedman_mse', 'splitter': 'bes...
# 5   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 6   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 7   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 8   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 9   {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 10  {'n_estimators': 76, 'learning_rate': 0.001648...
# 11  {'n_estimators': 76, 'learning_rate': 0.001648...
# 12  {'n_estimators': 76, 'learning_rate': 0.001648...
# 13  {'n_estimators': 76, 'learning_rate': 0.001648...
# 14  {'n_estimators': 76, 'learning_rate': 0.001648...
# 15  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 16  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 17  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 18  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 19  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 20  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 21  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 22  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 23  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 24  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 25  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 26  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 27  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 28  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 29  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 30  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 31  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 32  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 33  {'n_estimators': 118, 'max_depth': 12, 'learni...
# 34  {'n_estimators': 118, 'max_depth': 12, 'learni...

# %%
# Get the best study info for each model based on r2_mean
study_info_best = study_info.groupby("model").apply(
    lambda df: df.sort_values("r2_mean", ascending=False).head(1), include_groups=False
)
study_info_best = study_info_best.reset_index().drop(columns=["level_1"])
study_info_best
# Out:
#   model              study_name                dt  n_trials  random_state  \
# 0   DTR   study_DTR_RS-1_TS-0_3  2026-01-28_15-19         1             1
# 1    EN    study_EN_RS-5_TS-0_3  2026-01-28_15-19         1             5
# 2   GBR   study_GBR_RS-4_TS-0_3  2026-01-28_15-19         1             4
# 3   KNR   study_KNR_RS-4_TS-0_3  2026-01-28_15-19         1             4
# 4   RFR   study_RFR_RS-4_TS-0_3  2026-01-28_15-19         1             4
# 5   SVR   study_SVR_RS-4_TS-0_3  2026-01-28_15-19         1             4
# 6  XGBR  study_XGBR_RS-4_TS-0_3  2026-01-28_15-19         1             4
#
#    test_size                                         best_param  best_value  \
# 0        0.3  {'criterion': 'friedman_mse', 'splitter': 'bes...   -0.086123
# 1        0.3  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...    0.005825
# 2        0.3  {'n_estimators': 76, 'learning_rate': 0.001648...   -0.016851
# 3        0.3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...   -0.082493
# 4        0.3  {'n_estimators': 118, 'max_depth': 106, 'min_s...   -0.112790
# 5        0.3  {'kernel': 'linear', 'C': 7.451156502282094e-0...    0.007415
# 6        0.3  {'n_estimators': 118, 'max_depth': 12, 'learni...   -0.122445
#
#    total_trial  mse_mean   mse_std  mape_mean  mape_std   r2_mean    r2_std  \
# 0            6  0.896066  0.047836   1.502360  0.315104  0.086123  0.022041
# 1            1  0.992530  0.029870   5.890901  8.037083 -0.005825  0.016340
# 2            3  0.977015  0.076141   1.073809  0.071166  0.016851  0.010099
# 3            1  0.910965  0.089471   1.623037  0.426968  0.082493  0.039093
# 4            3  0.879850  0.069949   1.339074  0.136253  0.112790  0.031400
# 5            1  1.000296  0.075689   1.076004  0.085703 -0.007415  0.003851
# 6            3  0.868020  0.074160   1.609095  0.320927  0.122445  0.043932
#
#                                         model_params
# 0  {'criterion': 'friedman_mse', 'splitter': 'bes...
# 1  {'alpha': 5.5641802254313645e-05, 'l1_ratio': ...
# 2  {'n_estimators': 76, 'learning_rate': 0.001648...
# 3  {'n_neighbors': 19, 'weights': 'uniform', 'alg...
# 4  {'n_estimators': 118, 'max_depth': 106, 'min_s...
# 5  {'kernel': 'linear', 'C': 7.451156502282094e-0...
# 6  {'n_estimators': 118, 'max_depth': 12, 'learni...

# %%
shaps = []
infos = []
for idx, study in study_info_best.iterrows():
    # idx = 1
    # study = study_info_best.iloc[idx]
    model = study["model"]
    model_params = study["model_params"]

    # These parameters are used so that I can recover the same StandardScaler and train-test split as in the Optuna study
    random_state = study["random_state"]
    test_size = study["test_size"]

    print(
        f"Processing study {idx + 1}/{len(study_info)}: model={model}, random_state={random_state}, test_size={test_size}"
    )
    data_handler.split_and_scale(random_state=random_state, test_size=test_size)
    df_X_train, df_Y_train = data_handler.get_train(as_dataframe=True)
    df_X_test, df_Y_test = data_handler.get_test(as_dataframe=True)

    # Combine train and test sets
    df_X_comb = pd.concat([df_X_train, df_X_test], axis=0)
    df_Y_comb = pd.concat([df_Y_train, df_Y_test], axis=0)
    reg = OptunaUtil.get_model(model_name=model, **model_params)

    # Fit the model on the combined dataset for SHAP analysis. Use the underlying estimator instead of the MultiOutputRegressor
    estimator = reg.estimator
    estimator.fit(df_X_comb, df_Y_comb.values.ravel())
    explainer = ShapUtil.get_shap_explainer(
        model_name=model, estimator=estimator, X=df_X_comb
    )
    shap_values = explainer(df_X_comb)

    # Save info
    info = dict(
        model=model,
        model_params=model_params,
        test_size=test_size,
        random_state=random_state,
    )
    infos.append(info)
    
    # Store SHAP values
    shaps.append(
        dict(
            **info,
            shap_values=shap_values,
        )
    )
# Out:
# Processing study 1/35: model=DTR, random_state=1, test_size=0.3
# Processing study 2/35: model=EN, random_state=5, test_size=0.3
# Processing study 3/35: model=GBR, random_state=4, test_size=0.3
# Processing study 4/35: model=KNR, random_state=4, test_size=0.3
# Processing study 5/35: model=RFR, random_state=4, test_size=0.3
# Processing study 6/35: model=SVR, random_state=4, test_size=0.3
# Processing study 7/35: model=XGBR, random_state=4, test_size=0.3

# %%
with open("S01_shap_calc.pkl", "wb") as f:
    pickle.dump(dict(shaps=shaps, infos=infos), f)
