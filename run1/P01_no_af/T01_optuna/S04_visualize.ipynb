# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = BASE_DIR.parent.parent.parent
DATA_DIR = ROOT_DIR / "run1" / "data"
CURRENT_DIR = BASE_DIR

# %%
df = pd.read_excel(CURRENT_DIR / "S03_calculate_performance.xlsx")

# %%
df
# Out:
#      random_state  test_size model      Y  MSE Train (No Val)  MSE Test  \
# 0               1        0.3   DTR    Y-1            0.834222  1.352757
# 1               1        0.3   DTR    Y-2            0.940578  0.875643
# 2               1        0.3   DTR    Y-3            0.629355  0.589701
# 3               1        0.3   DTR  Y-All            0.801385  0.939367
# 4               2        0.3   DTR    Y-1            0.899984  0.835787
# ..            ...        ...   ...    ...                 ...       ...
# 135             4        0.3  XGBR  Y-All            0.795931  0.888383
# 136             5        0.3  XGBR    Y-1            0.845635  1.145347
# 137             5        0.3  XGBR    Y-2            0.927651  0.829881
# 138             5        0.3  XGBR    Y-3            0.624151  0.596506
# 139             5        0.3  XGBR  Y-All            0.799146  0.857245
#
#      MAPE Train (No Val)  MAPE Test  R2 Train (No Val)   R2 Test
# 0               1.598289   2.159778           0.165778 -0.058215
# 1               1.145072   2.892960           0.059422 -0.067825
# 2               1.467231   1.471173           0.370645  0.308668
# 3               1.403531   2.174637           0.198615  0.060876
# 4               1.664658   1.248199           0.100016  0.042092
# ..                   ...        ...                ...       ...
# 135             1.514879   1.376981           0.204069  0.114062
# 136            25.552592   1.400550           0.154365  0.017879
# 137             1.378923   1.352933           0.072349 -0.083937
# 138             1.429787   0.958682           0.375849  0.372403
# 139             9.453768   1.237388           0.200854  0.102115
#
# [140 rows x 10 columns]

# %%
filt = df["Y"] != "Y-All"
df_filt = df[filt]

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(df_filt, x="model", y="R2 Test", hue="Y", ax=ax)
ax.set_ylim(-0.15, 0.6)
# Out:
# (-0.15, 0.6)
