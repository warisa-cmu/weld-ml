# %%
from pathlib import Path
import shutil

# %%
BASE_DIR = Path.cwd()  # Current directory of the running file
ROOT_DIR = BASE_DIR.parent.parent  # Adjust as necessary to reach the project root
WORK_DIR_SOURCE = ROOT_DIR / "src" / "P02_data" / "T07_af_all"
WORK_DIR_DEST = ROOT_DIR / "run1" / "data"
print(WORK_DIR_SOURCE)
print(WORK_DIR_DEST)
# Out:
# c:\Users\admin\Coding\research\weld-ml\src\P02_data\T07_af_all
# c:\Users\admin\Coding\research\weld-ml\run1\data

# %%
# Copy
source_file = WORK_DIR_SOURCE / "S01_info_locs.xlsx"
destination_file = WORK_DIR_DEST / "S04_loc_values.xlsx"
shutil.copy(source_file, destination_file)
# Out:
# WindowsPath('c:/Users/admin/Coding/research/weld-ml/run1/data/S04_loc_values.xlsx')
